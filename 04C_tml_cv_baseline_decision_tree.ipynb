# %% [markdown]
# # 04_tml_cv_baseline
#
# We will use the train/test data generated from *00_create_dataset.ipynb* and use basic machine learning models to generate a baseline reference of model performance on our data. We will then decide on how to improve the various models after this
#
# Following feedback from interim presentation, cross validation will be implemented. That is, we will import the train set, split it into train-val, and run all of our notebooks. Then evaluation on the test set will only be implemented on the selected top models

# %%
''' data and math '''
import pandas as pd
import numpy as np

''' plotting images '''
from matplotlib import pyplot as plt
# %matplotlib inline

''' traversing directories '''
import os
from pathlib import Path

''' utilities '''
from tqdm import tqdm

''' metrics '''
from sklearn.metrics import accuracy_score
from sklearn.metrics import confusion_matrix
from sklearn.metrics import roc_auc_score
from sklearn.metrics import roc_curve

# %%
''' used to reference the root directory, for directory traversal ''' 
from google.colab import drive
drive.mount('/content/gdrive', force_remount=True)
mount_dir = '/content/gdrive'
root_dir = Path('/content/gdrive/My Drive/it3011_project')
# Out:
# Mounted at /content/gdrive

# %% [markdown]
# # Loading data

# %%
# load data
train = pd.read_csv(root_dir/"data/train_no_na.csv")
test = pd.read_csv(root_dir/"data/test_no_na.csv")
print("data loaded")
# Out:
# data loaded

# %%
# check shape
print(train.shape)
print(test.shape)
# Out:
# (279331, 138)
# (120163, 138)

# %%
# create train/val/test sets
features = [feature for feature in test.keys() if "feature" in feature]
x_train = train.loc[:, features].values
y_train = train.loc[:,['action']].values.flatten()
x_test = test.loc[:, features].values
y_test = test.loc[:,['action']].values.flatten()
print("train/test set created")
# Out:
# train/test set created

# %%
# scaling data to make it easier for models to train
from sklearn.preprocessing import StandardScaler

scaler = StandardScaler().fit(x_train)
x_train = scaler.transform(x_train)

# test set scaled on the same scaler as train, because models are fitted on the train distributions and not test distributions
x_test = scaler.transform(x_test)

# %% [markdown]
# # Helper functions

# %%
# constants
SEED = 42

# cross validation
from sklearn.model_selection import KFold
kf = KFold(n_splits=10, random_state=SEED, shuffle=True)

# %%
# create the utility score, which takes in the prediction value and the ground truth action and generates a score
# link: https://www.kaggle.com/c/jane-street-market-prediction/overview/evaluation

# data: original train/test data    action: the y-value. can either be y_pred or original values too, if we want the max score attainable
def utility_score(data, action): 
  dates_set = set(data.date.values)
  dates = data.loc[:, ['date']].values.flatten()
  weights = data.loc[:, ['weight']].values.flatten()
  resps = data.loc[:, ['resp']].values.flatten()
  actions = action.flatten()

  i = len(dates_set)
  p_i = []

  for date in dates_set:
    indices = np.where(dates == date)[0]
    p_i_temp = 0
    for j in indices:
      p_i_temp = p_i_temp + weights[j] * resps[j] * actions[j]
    p_i.append(p_i_temp)
  
  p_i_squared = [p_i1*p_i2 for p_i1,p_i2 in zip(p_i,p_i)]
  t = ( sum(p_i) / np.sqrt(sum(p_i_squared)) ) * np.sqrt(250/i)
  u = min(max(t, 0), 6) * sum(p_i)

  return u

def max_train_utility_score(data=train, action=y_train):
  return utility_score(data, action)

def max_test_utility_score(data=test, action=y_test):
  return utility_score(data, action)

# %%
def model_scores(model, test, x_test, y_test):
  y_pred = model.predict(x_test) 
  
  # # get some scores from helpers
  utility = utility_score(test, y_pred)
  accuracy =  accuracy_score(y_test, y_pred)

  # # confusion matrix
  # print("confusion matrix")
  cm = confusion_matrix(y_test, y_pred)
  true_pos = cm[1][1]
  true_neg = cm[0][0]
  false_pos = cm[0][1]
  false_neg = cm[1][0]

  # # plot confusion matrix
  # fig, ax = plt.subplots(figsize=(3, 3))
  # ax.imshow(cm)
  # ax.grid(False)
  # ax.xaxis.set(ticks=(0, 1), ticklabels=('Predicted 0s', 'Predicted 1s'))
  # ax.yaxis.set(ticks=(0, 1), ticklabels=('Actual 0s', 'Actual 1s'))
  # ax.set_ylim(1.5, -0.5)
  # for i in range(2):
  #     for j in range(2):
  #         ax.text(j, i, cm[i, j], ha='center', va='center', color='red')
  # plt.show()  

  # # AUC-ROC
  # print("AUC_ROC")
  logit_roc_auc = roc_auc_score(y_test, model.predict(x_test))

  # # plot auc-roc
  # fpr, tpr, thresholds = roc_curve(y_test, model.predict_proba(x_test)[:,1])
  # plt.figure()
  # plt.plot(fpr, tpr, label='Logistic Regression (area = %0.2f)' % logit_roc_auc)
  # plt.plot([0, 1], [0, 1],'r--')
  # plt.xlim([0.0, 1.0])
  # plt.ylim([0.0, 1.05])
  # plt.xlabel('False Positive Rate')
  # plt.ylabel('True Positive Rate')
  # plt.title('Receiver operating characteristic')
  # plt.legend(loc="lower right")
  # plt.show()

  return utility, accuracy, logit_roc_auc, true_pos, true_neg, false_pos, false_neg

# %%
import datetime
import csv

def save_scores(output_filename, workbook_name, model_name, model_params, utility, accuracy, true_pos, true_neg, false_pos, false_neg, logit_roc_auc):
  # create output file if not exists
  try:
    f = open(root_dir/output_filename)
  except IOError:
    with open (root_dir/output_filename, 'a') as csvfile:
      headers = ["workbook_name", "model_name", "model_params", "utility", "accuracy", "logit_roc_auc", "true_pos", "true_neg", "false_pos", "false_neg", "timestamp"]
      writer = csv.DictWriter(csvfile, delimiter=',', lineterminator='\n',fieldnames=headers)
      writer.writeheader() 
      print("created output file")  
    csvfile.close()

  # output file exists, append
  timestamp = datetime.datetime.now().strftime("%d/%m/%Y %H:%M:%S")
  
  ''' create another df that looks just like the excel file and concat with ''' 
  new_scores = pd.DataFrame(np.array([[workbook_name, model_name, model_params, utility, accuracy, logit_roc_auc, true_pos, true_neg, false_pos, false_neg, timestamp]]),
                   columns=["workbook_name", "model_name", "model_params", "utility", "accuracy", "logit_roc_auc", "true_pos", "true_neg", "false_pos", "false_neg", "timestamp"],
                  )

  new_scores.to_csv(root_dir/output_filename, mode='a', header=False, index=False)
  print("saved model metrics")

# %% [markdown]
# # Decision Tree model

# %%
# import model
from sklearn.tree import DecisionTreeClassifier
from sklearn import tree

# settings to vary
max_depths = [2,4,8,16,32,64]
splitters = ['best', 'random']
max_features = [None, 'sqrt', 'log2']

# %%
# iterate over settings for the model
for max_depth in max_depths:
  for splitter in splitters:
    for max_feature in max_features:
      output_filename = "CV_SCORES_AVE.csv"
      workbook_name = "04C_tml_cv_baseline_decision_tree"
      model_name = "Decision Tree model"
      model_params = f"max_depth={max_depth}, splitter={splitter}, max_feature={max_feature}"
      
      print("")
      print("model_name: ", model_name)
      print("model_params: ", model_params)
      
      # cross validation
      cv_scores = []

      for i, (train_idx, val_idx) in enumerate(kf.split(x_train)):
        # train-val data (for utility score calculation) 
        train_cv, val_cv = train.iloc[train_idx], train.iloc[val_idx]
        # train-val features 
        x_train_cv, x_val_cv, y_train_cv, y_val_cv = x_train[train_idx], x_train[val_idx], y_train[train_idx], y_train[val_idx]

        print(f"training model fold {i+1}")
        model = DecisionTreeClassifier(
          max_depth=max_depth, 
          splitter=splitter,
          max_features=max_feature
        )
        # tree.plot_tree(model)

        model.fit(x_train_cv, y_train_cv)
        model_score = model_scores(model, test=val_cv, x_test=x_val_cv, y_test=y_val_cv)
        cv_scores.append(model_score)
      
      # mean of cv scores
      cv_scores_ave = [sum(ele) / len(cv_scores) for ele in zip(*cv_scores)]
      print("cv_scores key: utility, accuracy, logit_roc_auc, true_pos, true_neg, false_pos, false_neg")
      print("cv_scores_ave: ", cv_scores_ave)

      # save average scores
      save_scores(output_filename, workbook_name, model_name, model_params, *cv_scores_ave)
# Out:
# model_name:  Decision Tree model
# model_params:  max_depth=2, splitter=best, max_feature=None
# training model fold 1
# training model fold 2
# training model fold 3
# training model fold 4
# training model fold 5
# training model fold 6
# training model fold 7
# training model fold 8
# training model fold 9
# training model fold 10
# cv_scores key: utility, accuracy, logit_roc_auc, true_pos, true_neg, false_pos, false_neg
# cv_scores_ave:  [76.92129515923676, 0.5118765808275015, 0.5165896534683034, 4064.6, 10233.7, 3446.5, 10188.3]
# saved model metrics
#
# model_name:  Decision Tree model
# model_params:  max_depth=2, splitter=best, max_feature=sqrt
# training model fold 1
# training model fold 2
# training model fold 3
# training model fold 4
# training model fold 5
# training model fold 6
# training model fold 7
# training model fold 8
# training model fold 9
# training model fold 10
# cv_scores key: utility, accuracy, logit_roc_auc, true_pos, true_neg, false_pos, false_neg
# cv_scores_ave:  [47.822566226804966, 0.5188360646834222, 0.5146745814637989, 10345.8, 4146.9, 9533.3, 3907.1]
# saved model metrics
#
# model_name:  Decision Tree model
# model_params:  max_depth=2, splitter=best, max_feature=log2
# training model fold 1
# training model fold 2
# training model fold 3
# training model fold 4
# training model fold 5
# training model fold 6
# training model fold 7
# training model fold 8
# training model fold 9
# training model fold 10
# cv_scores key: utility, accuracy, logit_roc_auc, true_pos, true_neg, false_pos, false_neg
# cv_scores_ave:  [67.77484811694593, 0.5160150311960539, 0.5139406969507505, 9265.5, 5148.4, 8531.8, 4987.4]
# saved model metrics
#
# model_name:  Decision Tree model
# model_params:  max_depth=2, splitter=random, max_feature=None
# training model fold 1
# training model fold 2
# training model fold 3
# training model fold 4
# training model fold 5
# training model fold 6
# training model fold 7
# training model fold 8
# training model fold 9
# training model fold 10
# cv_scores key: utility, accuracy, logit_roc_auc, true_pos, true_neg, false_pos, false_neg
# cv_scores_ave:  [40.9260221802907, 0.5179804519047642, 0.5134890151608974, 10867.3, 3601.5, 10078.7, 3385.6]
# saved model metrics
#
# model_name:  Decision Tree model
# model_params:  max_depth=2, splitter=random, max_feature=sqrt
# training model fold 1
# training model fold 2
# training model fold 3
# training model fold 4
# training model fold 5
# training model fold 6
# training model fold 7
# training model fold 8
# training model fold 9
# training model fold 10
# cv_scores key: utility, accuracy, logit_roc_auc, true_pos, true_neg, false_pos, false_neg
# cv_scores_ave:  [21.985079167396627, 0.5113360009435172, 0.5033040909550939, 12793.8, 1489.4, 12190.8, 1459.1]
# saved model metrics
#
# model_name:  Decision Tree model
# model_params:  max_depth=2, splitter=random, max_feature=log2
# training model fold 1
# training model fold 2
# training model fold 3
# training model fold 4
# training model fold 5
# training model fold 6
# training model fold 7
# training model fold 8
# training model fold 9
# training model fold 10
# cv_scores key: utility, accuracy, logit_roc_auc, true_pos, true_neg, false_pos, false_neg
# cv_scores_ave:  [15.479230094691582, 0.5104911240487333, 0.5023416206223497, 12982.9, 1276.7, 12403.5, 1270.0]
# saved model metrics
#
# model_name:  Decision Tree model
# model_params:  max_depth=4, splitter=best, max_feature=None
# training model fold 1
# training model fold 2
# training model fold 3
# training model fold 4
# training model fold 5
# training model fold 6
# training model fold 7
# training model fold 8
# training model fold 9
# training model fold 10
# cv_scores key: utility, accuracy, logit_roc_auc, true_pos, true_neg, false_pos, false_neg
# cv_scores_ave:  [95.19842521732811, 0.5159326759322431, 0.5197917418897984, 4518.3, 9893.3, 3786.9, 9734.6]
# saved model metrics
#
# model_name:  Decision Tree model
# model_params:  max_depth=4, splitter=best, max_feature=sqrt
# training model fold 1
# training model fold 2
# training model fold 3
# training model fold 4
# training model fold 5
# training model fold 6
# training model fold 7
# training model fold 8
# training model fold 9
# training model fold 10
# cv_scores key: utility, accuracy, logit_roc_auc, true_pos, true_neg, false_pos, false_neg
# cv_scores_ave:  [87.85022957575168, 0.5243385063427877, 0.5228898544186251, 8610.5, 6035.9, 7644.3, 5642.4]
# saved model metrics
#
# model_name:  Decision Tree model
# model_params:  max_depth=4, splitter=best, max_feature=log2
# training model fold 1
# training model fold 2
# training model fold 3
# training model fold 4
# training model fold 5
# training model fold 6
# training model fold 7
# training model fold 8
# training model fold 9
# training model fold 10
# cv_scores key: utility, accuracy, logit_roc_auc, true_pos, true_neg, false_pos, false_neg
# cv_scores_ave:  [112.86155701639363, 0.5236260865712199, 0.521693896487511, 8884.2, 5742.3, 7937.9, 5368.7]
# saved model metrics
#
# model_name:  Decision Tree model
# model_params:  max_depth=4, splitter=random, max_feature=None
# training model fold 1
# training model fold 2
# training model fold 3
# training model fold 4
# training model fold 5
# training model fold 6
# training model fold 7
# training model fold 8
# training model fold 9
# training model fold 10
# cv_scores key: utility, accuracy, logit_roc_auc, true_pos, true_neg, false_pos, false_neg
# cv_scores_ave:  [125.30938422831578, 0.5240019752796001, 0.5213147538045977, 9328.0, 5309.0, 8371.2, 4924.9]
# saved model metrics
#
# model_name:  Decision Tree model
# model_params:  max_depth=4, splitter=random, max_feature=sqrt
# training model fold 1
# training model fold 2
# training model fold 3
# training model fold 4
# training model fold 5
# training model fold 6
# training model fold 7
# training model fold 8
# training model fold 9
# training model fold 10
# cv_scores key: utility, accuracy, logit_roc_auc, true_pos, true_neg, false_pos, false_neg
# cv_scores_ave:  [33.29723836303171, 0.5139815746908488, 0.507144545713562, 12182.6, 2174.5, 11505.7, 2070.3]
# saved model metrics
#
# model_name:  Decision Tree model
# model_params:  max_depth=4, splitter=random, max_feature=log2
# training model fold 1
# training model fold 2
# training model fold 3
# training model fold 4
# training model fold 5
# training model fold 6
# training model fold 7
# training model fold 8
# training model fold 9
# training model fold 10
# cv_scores key: utility, accuracy, logit_roc_auc, true_pos, true_neg, false_pos, false_neg
# cv_scores_ave:  [30.285716611853264, 0.511769175595181, 0.5054638805980579, 11703.2, 2592.1, 11088.1, 2549.7]
# saved model metrics
#
# model_name:  Decision Tree model
# model_params:  max_depth=8, splitter=best, max_feature=None
# training model fold 1
# training model fold 2
# training model fold 3
# training model fold 4
# training model fold 5
# training model fold 6
# training model fold 7
# training model fold 8
# training model fold 9
# training model fold 10
# cv_scores key: utility, accuracy, logit_roc_auc, true_pos, true_neg, false_pos, false_neg
# cv_scores_ave:  [306.4244773878886, 0.5325795980307193, 0.5321725709966987, 7922.9, 6953.7, 6726.5, 6330.0]
# saved model metrics
#
# model_name:  Decision Tree model
# model_params:  max_depth=8, splitter=best, max_feature=sqrt
# training model fold 1
# training model fold 2
# training model fold 3
# training model fold 4
# training model fold 5
# training model fold 6
# training model fold 7
# training model fold 8
# training model fold 9
# training model fold 10
# cv_scores key: utility, accuracy, logit_roc_auc, true_pos, true_neg, false_pos, false_neg
# cv_scores_ave:  [408.97948833951585, 0.5404161862976999, 0.5401721824077079, 7798.5, 7297.0, 6383.2, 6454.4]
# saved model metrics
#
# model_name:  Decision Tree model
# model_params:  max_depth=8, splitter=best, max_feature=log2
# training model fold 1
# training model fold 2
# training model fold 3
# training model fold 4
# training model fold 5
# training model fold 6
# training model fold 7
# training model fold 8
# training model fold 9
# training model fold 10
# cv_scores key: utility, accuracy, logit_roc_auc, true_pos, true_neg, false_pos, false_neg
# cv_scores_ave:  [320.1384084821266, 0.536947194607428, 0.5360054193853702, 8280.2, 6718.4, 6961.8, 5972.7]
# saved model metrics
#
# model_name:  Decision Tree model
# model_params:  max_depth=8, splitter=random, max_feature=None
# training model fold 1
# training model fold 2
# training model fold 3
# training model fold 4
# training model fold 5
# training model fold 6
# training model fold 7
# training model fold 8
# training model fold 9
# training model fold 10
# cv_scores key: utility, accuracy, logit_roc_auc, true_pos, true_neg, false_pos, false_neg
# cv_scores_ave:  [380.577169369482, 0.5397932760127614, 0.5385504146297746, 8404.4, 6673.7, 7006.5, 5848.5]
# saved model metrics
#
# model_name:  Decision Tree model
# model_params:  max_depth=8, splitter=random, max_feature=sqrt
# training model fold 1
# training model fold 2
# training model fold 3
# training model fold 4
# training model fold 5
# training model fold 6
# training model fold 7
# training model fold 8
# training model fold 9
# training model fold 10
# cv_scores key: utility, accuracy, logit_roc_auc, true_pos, true_neg, false_pos, false_neg
# cv_scores_ave:  [49.732363288251065, 0.5204792922511645, 0.5163377758706055, 10167.1, 4371.5, 9308.7, 4085.8]
# saved model metrics
#
# model_name:  Decision Tree model
# model_params:  max_depth=8, splitter=random, max_feature=log2
# training model fold 1
# training model fold 2
# training model fold 3
# training model fold 4
# training model fold 5
# training model fold 6
# training model fold 7
# training model fold 8
# training model fold 9
# training model fold 10
# cv_scores key: utility, accuracy, logit_roc_auc, true_pos, true_neg, false_pos, false_neg
# cv_scores_ave:  [55.27610910715166, 0.5185460999558439, 0.5127344756408039, 11247.9, 3236.7, 10443.5, 3005.0]
# saved model metrics
#
# model_name:  Decision Tree model
# model_params:  max_depth=16, splitter=best, max_feature=None
# training model fold 1
# training model fold 2
# training model fold 3
# training model fold 4
# training model fold 5
# training model fold 6
# training model fold 7
# training model fold 8
# training model fold 9
# training model fold 10
# cv_scores key: utility, accuracy, logit_roc_auc, true_pos, true_neg, false_pos, false_neg
# cv_scores_ave:  [731.6309412526998, 0.5711503110095975, 0.5715441439650268, 7843.8, 8110.2, 5570.0, 6409.1]
# saved model metrics
#
# model_name:  Decision Tree model
# model_params:  max_depth=16, splitter=best, max_feature=sqrt
# training model fold 1
# training model fold 2
# training model fold 3
# training model fold 4
# training model fold 5
# training model fold 6
# training model fold 7
# training model fold 8
# training model fold 9
# training model fold 10
# cv_scores key: utility, accuracy, logit_roc_auc, true_pos, true_neg, false_pos, false_neg
# cv_scores_ave:  [784.1062943325791, 0.5752494287239722, 0.5747760268775909, 8497.9, 7570.6, 6109.6, 5755.0]
# saved model metrics
#
# model_name:  Decision Tree model
# model_params:  max_depth=16, splitter=best, max_feature=log2
# training model fold 1
# training model fold 2
# training model fold 3
# training model fold 4
# training model fold 5
# training model fold 6
# training model fold 7
# training model fold 8
# training model fold 9
# training model fold 10
# cv_scores key: utility, accuracy, logit_roc_auc, true_pos, true_neg, false_pos, false_neg
# cv_scores_ave:  [654.0406290642273, 0.5614235510063843, 0.5611818147783448, 8144.8, 7537.5, 6142.7, 6108.1]
# saved model metrics
#
# model_name:  Decision Tree model
# model_params:  max_depth=16, splitter=random, max_feature=None
# training model fold 1
# training model fold 2
# training model fold 3
# training model fold 4
# training model fold 5
# training model fold 6
# training model fold 7
# training model fold 8
# training model fold 9
# training model fold 10
# cv_scores key: utility, accuracy, logit_roc_auc, true_pos, true_neg, false_pos, false_neg
# cv_scores_ave:  [713.878480096062, 0.5696002507160175, 0.5691720141554343, 8407.3, 7503.4, 6176.8, 5845.6]
# saved model metrics
#
# model_name:  Decision Tree model
# model_params:  max_depth=16, splitter=random, max_feature=sqrt
# training model fold 1
# training model fold 2
# training model fold 3
# training model fold 4
# training model fold 5
# training model fold 6
# training model fold 7
# training model fold 8
# training model fold 9
# training model fold 10
# cv_scores key: utility, accuracy, logit_roc_auc, true_pos, true_neg, false_pos, false_neg
# cv_scores_ave:  [305.4457573923533, 0.5366464813082289, 0.5348562322869859, 8903.2, 6087.0, 7593.2, 5349.7]
# saved model metrics
#
# model_name:  Decision Tree model
# model_params:  max_depth=16, splitter=random, max_feature=log2
# training model fold 1
# training model fold 2
# training model fold 3
# training model fold 4
# training model fold 5
# training model fold 6
# training model fold 7
# training model fold 8
# training model fold 9
# training model fold 10
# cv_scores key: utility, accuracy, logit_roc_auc, true_pos, true_neg, false_pos, false_neg
# cv_scores_ave:  [229.7694826446963, 0.5310509574723125, 0.528955080362434, 9004.8, 5829.1, 7851.1, 5248.1]
# saved model metrics
#
# model_name:  Decision Tree model
# model_params:  max_depth=32, splitter=best, max_feature=None
# training model fold 1
# training model fold 2
# training model fold 3
# training model fold 4
# training model fold 5
# training model fold 6
# training model fold 7
# training model fold 8
# training model fold 9
# training model fold 10
# cv_scores key: utility, accuracy, logit_roc_auc, true_pos, true_neg, false_pos, false_neg
# cv_scores_ave:  [1440.9546654998003, 0.6385900155264949, 0.6387166338791902, 9017.6, 8820.2, 4860.0, 5235.3]
# saved model metrics
#
# model_name:  Decision Tree model
# model_params:  max_depth=32, splitter=best, max_feature=sqrt
# training model fold 1
# training model fold 2
# training model fold 3
# training model fold 4
# training model fold 5
# training model fold 6
# training model fold 7
# training model fold 8
# training model fold 9
# training model fold 10
# cv_scores key: utility, accuracy, logit_roc_auc, true_pos, true_neg, false_pos, false_neg
# cv_scores_ave:  [987.1557673100963, 0.5919500772761923, 0.5919018090330869, 8474.2, 8060.8, 5619.4, 5778.7]
# saved model metrics
#
# model_name:  Decision Tree model
# model_params:  max_depth=32, splitter=best, max_feature=log2
# training model fold 1
# training model fold 2
# training model fold 3
# training model fold 4
# training model fold 5
# training model fold 6
# training model fold 7
# training model fold 8
# training model fold 9
# training model fold 10
# cv_scores key: utility, accuracy, logit_roc_auc, true_pos, true_neg, false_pos, false_neg
# cv_scores_ave:  [890.2429185176388, 0.582810387494254, 0.5827487382826517, 8350.3, 7929.4, 5750.8, 5902.6]
# saved model metrics
#
# model_name:  Decision Tree model
# model_params:  max_depth=32, splitter=random, max_feature=None
# training model fold 1
# training model fold 2
# training model fold 3
# training model fold 4
# training model fold 5
# training model fold 6
# training model fold 7
# training model fold 8
# training model fold 9
# training model fold 10
# cv_scores key: utility, accuracy, logit_roc_auc, true_pos, true_neg, false_pos, false_neg
# cv_scores_ave:  [1200.1876536473787, 0.6133547828526703, 0.6131918760758854, 8833.8, 8299.1, 5381.1, 5419.1]
# saved model metrics
#
# model_name:  Decision Tree model
# model_params:  max_depth=32, splitter=random, max_feature=sqrt
# training model fold 1
# training model fold 2
# training model fold 3
# training model fold 4
# training model fold 5
# training model fold 6
# training model fold 7
# training model fold 8
# training model fold 9
# training model fold 10
# cv_scores key: utility, accuracy, logit_roc_auc, true_pos, true_neg, false_pos, false_neg
# cv_scores_ave:  [630.6381276838254, 0.5625046563067554, 0.5623235907399572, 8109.4, 7603.1, 6077.1, 6143.5]
# saved model metrics
#
# model_name:  Decision Tree model
# model_params:  max_depth=32, splitter=random, max_feature=log2
# training model fold 1
# training model fold 2
# training model fold 3
# training model fold 4
# training model fold 5
# training model fold 6
# training model fold 7
# training model fold 8
# training model fold 9
# training model fold 10
# cv_scores key: utility, accuracy, logit_roc_auc, true_pos, true_neg, false_pos, false_neg
# cv_scores_ave:  [517.8664075668552, 0.5491012518317422, 0.548677426081605, 8113.3, 7224.8, 6455.4, 6139.6]
# saved model metrics
#
# model_name:  Decision Tree model
# model_params:  max_depth=64, splitter=best, max_feature=None
# training model fold 1
# training model fold 2
# training model fold 3
# training model fold 4
# training model fold 5
# training model fold 6
# training model fold 7
# training model fold 8
# training model fold 9
# training model fold 10
# cv_scores key: utility, accuracy, logit_roc_auc, true_pos, true_neg, false_pos, false_neg
# cv_scores_ave:  [1532.5953685997022, 0.6487392722253897, 0.6485998388479993, 9338.5, 8782.8, 4897.4, 4914.4]
# saved model metrics
#
# model_name:  Decision Tree model
# model_params:  max_depth=64, splitter=best, max_feature=sqrt
# training model fold 1
# training model fold 2
# training model fold 3
# training model fold 4
# training model fold 5
# training model fold 6
# training model fold 7
# training model fold 8
# training model fold 9
# training model fold 10
# cv_scores key: utility, accuracy, logit_roc_auc, true_pos, true_neg, false_pos, false_neg
# cv_scores_ave:  [1083.4381719871942, 0.6000515563364988, 0.5998803440440902, 8669.9, 8091.4, 5588.8, 5583.0]
# saved model metrics
#
# model_name:  Decision Tree model
# model_params:  max_depth=64, splitter=best, max_feature=log2
# training model fold 1
# training model fold 2
# training model fold 3
# training model fold 4
# training model fold 5
# training model fold 6
# training model fold 7
# training model fold 8
# training model fold 9
# training model fold 10
# cv_scores key: utility, accuracy, logit_roc_auc, true_pos, true_neg, false_pos, false_neg
# cv_scores_ave:  [915.7611990024254, 0.5846218195898807, 0.5844886609037994, 8427.7, 7902.6, 5777.6, 5825.2]
# saved model metrics
#
# model_name:  Decision Tree model
# model_params:  max_depth=64, splitter=random, max_feature=None
# training model fold 1
# training model fold 2
# training model fold 3
# training model fold 4
# training model fold 5
# training model fold 6
# training model fold 7
# training model fold 8
# training model fold 9
# training model fold 10
# cv_scores key: utility, accuracy, logit_roc_auc, true_pos, true_neg, false_pos, false_neg
# cv_scores_ave:  [1211.9888830002778, 0.6192689253454061, 0.6191163963891337, 8930.4, 8367.7, 5312.5, 5322.5]
# saved model metrics
#
# model_name:  Decision Tree model
# model_params:  max_depth=64, splitter=random, max_feature=sqrt
# training model fold 1
# training model fold 2
# training model fold 3
# training model fold 4
# training model fold 5
# training model fold 6
# training model fold 7
# training model fold 8
# training model fold 9
# training model fold 10
# cv_scores key: utility, accuracy, logit_roc_auc, true_pos, true_neg, false_pos, false_neg
# cv_scores_ave:  [729.5498070803217, 0.5682291164803825, 0.5680691208009303, 8204.9, 7667.5, 6012.7, 6048.0]
# saved model metrics
#
# model_name:  Decision Tree model
# model_params:  max_depth=64, splitter=random, max_feature=log2
# training model fold 1
# training model fold 2
# training model fold 3
# training model fold 4
# training model fold 5
# training model fold 6
# training model fold 7
# training model fold 8
# training model fold 9
# training model fold 10
# cv_scores key: utility, accuracy, logit_roc_auc, true_pos, true_neg, false_pos, false_neg
# cv_scores_ave:  [556.4068537958011, 0.5561144452244118, 0.5559531037426643, 8032.4, 7501.6, 6178.6, 6220.5]
# saved model metrics

# %% [markdown]
# # Conclusion

# %% [markdown]
# * Utility score:
# * Accuracy:
