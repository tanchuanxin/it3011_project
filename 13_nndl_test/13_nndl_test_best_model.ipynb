# %% [markdown]
# # 13_nndl_test
#
# From the 11/12 series of notebooks, we have used 10-fold cross validation to try and determine the optimal model, and its set of hyperparameters for this problem.
#
# Now, we will evaluate the top model on the test set. The RNG model is taken from the TML version, since it is the same

# %%
''' data and math '''
import pandas as pd
import numpy as np

''' plotting images '''
from matplotlib import pyplot as plt
# %matplotlib inline

''' traversing directories '''
import os
from pathlib import Path

''' utilities '''
from tqdm import tqdm

''' metrics '''
from sklearn.metrics import accuracy_score
from sklearn.metrics import confusion_matrix
from sklearn.metrics import roc_auc_score
from sklearn.metrics import roc_curve

''' preprocessing '''
from sklearn.preprocessing import StandardScaler

# %%
''' used to reference the root directory, for directory traversal ''' 
from google.colab import drive
drive.mount('/content/gdrive', force_remount=True)
mount_dir = '/content/gdrive'
root_dir = Path('/content/gdrive/My Drive/it3011_project')
# Out:
# Mounted at /content/gdrive

# %% [markdown]
# # Loading data

# %%
# load data
train = pd.read_csv(root_dir/"data/train_no_na.csv")
test = pd.read_csv(root_dir/"data/test_no_na.csv")
print("data loaded")
# Out:
# data loaded

# %%
# check shape
print(train.shape)
print(test.shape)
# Out:
# (279331, 138)
# (120163, 138)

# %%
# create train/test sets
features = [feature for feature in test.keys() if "feature" in feature]
x_train = train.loc[:, features].values
y_train = train.loc[:,['action']].values.flatten()
x_test = test.loc[:, features].values
y_test = test.loc[:,['action']].values.flatten()
print("train/test set created")
# Out:
# train/test set created

# %% [markdown]
# # Helper functions

# %%
# constants
SEED = 42

# %%
# create the utility score, which takes in the prediction value and the ground truth action and generates a score
# link: https://www.kaggle.com/c/jane-street-market-prediction/overview/evaluation

# data: original train/test data    action: the y-value. can either be y_pred or original values too, if we want the max score attainable
def utility_score(data, action): 
  dates_set = set(data.date.values)
  dates = data.loc[:, ['date']].values.flatten()
  weights = data.loc[:, ['weight']].values.flatten()
  resps = data.loc[:, ['resp']].values.flatten()
  actions = action.flatten()

  i = len(dates_set)
  p_i = []

  for date in dates_set:
    indices = np.where(dates == date)[0]
    p_i_temp = 0
    for j in indices:
      p_i_temp = p_i_temp + weights[j] * resps[j] * actions[j]
    p_i.append(p_i_temp)
  
  p_i_squared = [p_i1*p_i2 for p_i1,p_i2 in zip(p_i,p_i)]
  t = ( sum(p_i) / np.sqrt(sum(p_i_squared)) ) * np.sqrt(250/i)
  u = min(max(t, 0), 6) * sum(p_i)

  return u

def max_train_utility_score(data=train, action=y_train):
  return utility_score(data, action)

def max_test_utility_score(data=test, action=y_test):
  return utility_score(data, action)

# %%
def model_scores(model, test, x_test, y_test):
  y_pred = model.predict(x_test) 
  y_pred = (y_pred > 0.5).astype(int)
  
  # # get some scores from helpers
  utility = utility_score(test, y_pred)
  accuracy =  accuracy_score(y_test, y_pred)

  # # confusion matrix
  # print("confusion matrix")
  cm = confusion_matrix(y_test, y_pred)
  true_pos = cm[1][1]
  true_neg = cm[0][0]
  false_pos = cm[0][1]
  false_neg = cm[1][0]

  # # plot confusion matrix
  # fig, ax = plt.subplots(figsize=(3, 3))
  # ax.imshow(cm)
  # ax.grid(False)
  # ax.xaxis.set(ticks=(0, 1), ticklabels=('Predicted 0s', 'Predicted 1s'))
  # ax.yaxis.set(ticks=(0, 1), ticklabels=('Actual 0s', 'Actual 1s'))
  # ax.set_ylim(1.5, -0.5)
  # for i in range(2):
  #     for j in range(2):
  #         ax.text(j, i, cm[i, j], ha='center', va='center', color='red')
  # plt.show()  

  # # AUC-ROC
  # print("AUC_ROC")
  logit_roc_auc = roc_auc_score(y_test, y_pred)

  # # plot auc-roc
  # fpr, tpr, thresholds = roc_curve(y_test, model.predict_proba(x_test)[:,1])
  # plt.figure()
  # plt.plot(fpr, tpr, label='Logistic Regression (area = %0.2f)' % logit_roc_auc)
  # plt.plot([0, 1], [0, 1],'r--')
  # plt.xlim([0.0, 1.0])
  # plt.ylim([0.0, 1.05])
  # plt.xlabel('False Positive Rate')
  # plt.ylabel('True Positive Rate')
  # plt.title('Receiver operating characteristic')
  # plt.legend(loc="lower right")
  # plt.show()

  return utility, accuracy, logit_roc_auc, true_pos, true_neg, false_pos, false_neg

# %%
import datetime
import csv

def save_scores(output_filename, workbook_name, model_name, model_params, utility, accuracy, logit_roc_auc, true_pos, true_neg, false_pos, false_neg):
  # create output file if not exists
  try:
    f = open(root_dir/output_filename)
  except IOError:
    with open (root_dir/output_filename, 'a') as csvfile:
      headers = ["workbook_name", "model_name", "model_params", "utility", "accuracy", "logit_roc_auc", "true_pos", "true_neg", "false_pos", "false_neg", "timestamp"]
      writer = csv.DictWriter(csvfile, delimiter=',', lineterminator='\n',fieldnames=headers)
      writer.writeheader() 
      print("created output file")  
    csvfile.close()

  # output file exists, append
  timestamp = datetime.datetime.now().strftime("%d/%m/%Y %H:%M:%S")
  
  ''' create another df that looks just like the excel file and concat with ''' 
  new_scores = pd.DataFrame(np.array([[workbook_name, model_name, model_params, utility, accuracy, logit_roc_auc, true_pos, true_neg, false_pos, false_neg, timestamp]]),
                   columns=["workbook_name", "model_name", "model_params", "utility", "accuracy", "logit_roc_auc", "true_pos", "true_neg", "false_pos", "false_neg", "timestamp"],
                  )

  new_scores.to_csv(root_dir/output_filename, mode='a', header=False, index=False)
  print("saved model metrics")

# %%
'''
used to generate the PosixPath variables for the results to save
'''
def results_paths(root_dir=root_dir):
    PATH_RESULTS = root_dir /'results_nndl'
    PATH_HISTORIES = PATH_RESULTS / 'histories'
    PATH_FIGURES = PATH_RESULTS / 'figures'
    PATH_CHECKPOINTS = PATH_RESULTS / 'checkpoints'
    PATH_PREDICTIONS = PATH_RESULTS / 'predictions'

    return PATH_RESULTS, PATH_HISTORIES, PATH_FIGURES, PATH_CHECKPOINTS, PATH_PREDICTIONS


''' 
used to save the history of a model as a npy file
'''
# filename like 'history/model_name.npy'
def history_saver(history, model_name, history_save_path, already_npy=False):
  history_json = {}

  if already_npy:
    history_npy = history
  else:
    history_npy = history.history

  np.save(history_save_path/model_name, history_npy)
  print("History saved")



''' 
used to load the history of a model from a npy file
'''
# filename like 'history/model_name.npy'
def history_loader(model_name, history_save_path):
  history_save_path = history_save_path/str(model_name+'.npy')
  history=np.load(history_save_path,allow_pickle='TRUE').item()
  print('History loaded')
  
  return history 

'''
used to plot the metrics for a given history
'''
def plot_metrics(history, model_name, figure_save_path):
    fig, (ax1, ax2, ax3) = plt.subplots(1, 3, figsize=(18, 6))

    # print(history.keys())

    # plot losses
    train_loss = history['loss']
    # val_loss = history['val_loss']
    loss_title = 'loss against epochs'

    ax1.plot(train_loss, label='train')
    # ax1.plot(val_loss, label='val')
    ax1.set_title(loss_title)
    ax1.set_ylabel('loss')
    ax1.set_xlabel('epochs')
    ax1.legend()

    # plot accuracy_score
    accuracy_score = history['accuracy']
    # val_accuracy_score = history['val_accuracy']
    accuracy_score_title = 'accuracy_score against epochs'

    ax2.plot(accuracy_score, label='train')
    # ax2.plot(val_accuracy_score, label='val')
    ax2.set_title(accuracy_score_title)
    ax2.set_ylabel('accuracy_score')
    ax2.set_xlabel('epochs')
    ax2.legend()


    # plot accuracy_score
    auc_score = history['auc']
    # val_auc_score = history['val_auc']
    auc_score_title = 'auc_score against epochs'

    ax3.plot(auc_score, label='train')
    # ax3.plot(val_auc_score, label='val')
    ax3.set_title(auc_score_title)
    ax3.set_ylabel('auc_score')
    ax3.set_xlabel('epochs')
    ax3.legend()


    # save figure
    fig.suptitle('Metrics for model: ' + model_name)
    plt.savefig(figure_save_path/f'{model_name}.png')

    plt.show()

# %% [markdown]
# # mlp2, epochs=2000, batch size=256, hidden units=[400,800,1600,800], dropout rates=[0.2,0.2,0.2,0.2], activation=tanh, learning rate=1e-4

# %%
# !pip install keras_tqdm
# Out:
# Collecting keras_tqdm
#   Downloading https://files.pythonhosted.org/packages/16/5c/ac63c65b79a895b8994474de2ad4d5b66ac0796b8903d60cfea3f8308d5c/keras_tqdm-2.0.1-py2.py3-none-any.whl
# Requirement already satisfied: Keras in /usr/local/lib/python3.7/dist-packages (from keras_tqdm) (2.4.3)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.7/dist-packages (from keras_tqdm) (4.41.1)
# Requirement already satisfied: h5py in /usr/local/lib/python3.7/dist-packages (from Keras->keras_tqdm) (2.10.0)
# Requirement already satisfied: pyyaml in /usr/local/lib/python3.7/dist-packages (from Keras->keras_tqdm) (3.13)
# Requirement already satisfied: numpy>=1.9.1 in /usr/local/lib/python3.7/dist-packages (from Keras->keras_tqdm) (1.19.5)
# Requirement already satisfied: scipy>=0.14 in /usr/local/lib/python3.7/dist-packages (from Keras->keras_tqdm) (1.4.1)
# Requirement already satisfied: six in /usr/local/lib/python3.7/dist-packages (from h5py->Keras->keras_tqdm) (1.15.0)
# Installing collected packages: keras-tqdm
# Successfully installed keras-tqdm-2.0.1

# %%
import tensorflow as tf
import tensorflow.keras as keras

from keras_tqdm import TQDMCallback
from keras.callbacks import ModelCheckpoint, EarlyStopping
from keras.layers import Input, Dense, BatchNormalization, Dropout, Activation
from keras.layers.experimental.preprocessing import Normalization
from keras.models import Model, Sequential
from keras.losses import BinaryCrossentropy
from keras.optimizers import Adam
from keras.metrics import BinaryAccuracy, AUC

tf.random.set_seed(SEED)
np.random.seed(SEED)

# %%
PATH_RESULTS, PATH_HISTORIES, PATH_FIGURES, PATH_CHECKPOINTS, PATH_PREDICTIONS = results_paths()

# %%
def create_mlp(num_columns, hidden_units, activation, dropout_rates, learning_rate): 
  inp = Input(shape=(num_columns,))
  x = BatchNormalization()(inp)

  for i in range(len(hidden_units)):   
    x = Dense(hidden_units[i])(x)
    x = Activation(activation)(x)
    x = BatchNormalization()(x)
    x = Dropout(dropout_rates[i])(x)

  x = Dense(1)(x)
  out = Activation("sigmoid")(x)

  model = Model(inputs=inp, outputs=out)

  model.compile(
    optimizer=Adam(learning_rate=learning_rate),
    loss=BinaryCrossentropy(label_smoothing=1e-4),
    metrics=[BinaryAccuracy(name="accuracy"), AUC(name="auc")]
  )

  return model

# %%
# settings to vary

# large number to achieve convergence. 50 was just to ensure we can run notebooks in reasonable amount of time
epochs = [2000] 
 
# smaller batch size for better results
batch_sizes = [256]

# larger hidden_units to learn more features
hidden_units = [
    [400, 800, 1600, 800]
]

# keep 0.2 for dropout_rates for regularizing effect
dropout_rates = [
    [0.2, 0.2, 0.2, 0.2]
] 

# tf.keras.activations.tanh] found to be the best
activations = [tf.keras.activations.tanh]

# learning_rates 1e-4 found to be the best
learning_rates = [1e-4]

# %%
for batch_size in batch_sizes:
  for hidden_unit in hidden_units:
    for activation in activations:
      for dropout_rate in dropout_rates:
        for learning_rate in learning_rates:
          for epoch in epochs:

            output_filename = "TEST_SCORES.csv"
            workbook_name = "13_nndl_test_best_model"
            model_name = f"Best Model - MLP2"
            model_params = f"batch_size={batch_size}, hidden_unit={hidden_unit}, activation={activation}, dropout_rate={dropout_rate}, learning_rate={learning_rate}, epoch={epoch}"
                    
            print("")
            print("model_name: ", model_name)
            print("model_params: ", model_params)

            # scaling data to make it easier for models to train
            scaler = StandardScaler().fit(x_train)
            x_train = scaler.transform(x_train)

            # test set scaled on the same scaler as train, because models are fitted on the train distributions and not test distributions
            x_test = scaler.transform(x_test)            

            print(f"training model")

            model = create_mlp(x_train.shape[1], hidden_unit, activation, dropout_rate, learning_rate)
            CheckpointCallback = ModelCheckpoint(str(PATH_CHECKPOINTS / (model_name + '.hdf5')), monitor='loss', verbose=1, save_weights_only=True, save_best_only=True, mode='auto', save_freq='epoch')

            history = model.fit(
                x_train, 
                y_train, 
                epochs=epoch, 
                batch_size=batch_size,
                callbacks = [CheckpointCallback]
            )

            model_score = model_scores(model, test=test, x_test=x_test, y_test=y_test)

            history_saver(history, model_name, PATH_HISTORIES, already_npy=False)
            history = history_loader(model_name, PATH_HISTORIES)
            plot_metrics(history, model_name, PATH_FIGURES)

            # save average scores
            save_scores(output_filename, workbook_name, model_name, model_params, *model_score)
# Out:
# Streaming output truncated to the last 5000 lines.
#
# Epoch 00217: loss improved from 0.38322 to 0.38258, saving model to /content/gdrive/My Drive/it3011_project/results_nndl/checkpoints/Best Model - MLP2.hdf5
# Epoch 218/2000
# 1092/1092 [==============================] - 8s 7ms/step - loss: 0.3826 - accuracy: 0.8241 - auc: 0.9080
#
# Epoch 00218: loss did not improve from 0.38258
# Epoch 219/2000
# 1092/1092 [==============================] - 8s 7ms/step - loss: 0.3802 - accuracy: 0.8256 - auc: 0.9093
#
# Epoch 00219: loss improved from 0.38258 to 0.38085, saving model to /content/gdrive/My Drive/it3011_project/results_nndl/checkpoints/Best Model - MLP2.hdf5
# Epoch 220/2000
# 1092/1092 [==============================] - 7s 7ms/step - loss: 0.3780 - accuracy: 0.8275 - auc: 0.9103
#
# Epoch 00220: loss did not improve from 0.38085
# Epoch 221/2000
# 1092/1092 [==============================] - 7s 7ms/step - loss: 0.3786 - accuracy: 0.8255 - auc: 0.9101
#
# Epoch 00221: loss did not improve from 0.38085
# Epoch 222/2000
# 1092/1092 [==============================] - 8s 7ms/step - loss: 0.3771 - accuracy: 0.8271 - auc: 0.9109
#
# Epoch 00222: loss improved from 0.38085 to 0.38032, saving model to /content/gdrive/My Drive/it3011_project/results_nndl/checkpoints/Best Model - MLP2.hdf5
# Epoch 223/2000
# 1092/1092 [==============================] - 8s 7ms/step - loss: 0.3795 - accuracy: 0.8259 - auc: 0.9096
#
# Epoch 00223: loss did not improve from 0.38032
# Epoch 224/2000
# 1092/1092 [==============================] - 7s 7ms/step - loss: 0.3778 - accuracy: 0.8262 - auc: 0.9105
#
# Epoch 00224: loss did not improve from 0.38032
# Epoch 225/2000
# 1092/1092 [==============================] - 7s 7ms/step - loss: 0.3796 - accuracy: 0.8251 - auc: 0.9096
#
# Epoch 00225: loss did not improve from 0.38032
# Epoch 226/2000
# 1092/1092 [==============================] - 8s 7ms/step - loss: 0.3788 - accuracy: 0.8263 - auc: 0.9100
#
# Epoch 00226: loss did not improve from 0.38032
# Epoch 227/2000
# 1092/1092 [==============================] - 8s 7ms/step - loss: 0.3777 - accuracy: 0.8264 - auc: 0.9106
#
# Epoch 00227: loss improved from 0.38032 to 0.37972, saving model to /content/gdrive/My Drive/it3011_project/results_nndl/checkpoints/Best Model - MLP2.hdf5
# Epoch 228/2000
# 1092/1092 [==============================] - 8s 7ms/step - loss: 0.3789 - accuracy: 0.8260 - auc: 0.9100
#
# Epoch 00228: loss improved from 0.37972 to 0.37953, saving model to /content/gdrive/My Drive/it3011_project/results_nndl/checkpoints/Best Model - MLP2.hdf5
# Epoch 229/2000
# 1092/1092 [==============================] - 8s 7ms/step - loss: 0.3765 - accuracy: 0.8274 - auc: 0.9111
#
# Epoch 00229: loss improved from 0.37953 to 0.37892, saving model to /content/gdrive/My Drive/it3011_project/results_nndl/checkpoints/Best Model - MLP2.hdf5
# Epoch 230/2000
# 1092/1092 [==============================] - 8s 7ms/step - loss: 0.3809 - accuracy: 0.8245 - auc: 0.9090
#
# Epoch 00230: loss did not improve from 0.37892
# Epoch 231/2000
# 1092/1092 [==============================] - 8s 7ms/step - loss: 0.3777 - accuracy: 0.8266 - auc: 0.9105
#
# Epoch 00231: loss did not improve from 0.37892
# Epoch 232/2000
# 1092/1092 [==============================] - 7s 7ms/step - loss: 0.3768 - accuracy: 0.8269 - auc: 0.9110
#
# Epoch 00232: loss improved from 0.37892 to 0.37758, saving model to /content/gdrive/My Drive/it3011_project/results_nndl/checkpoints/Best Model - MLP2.hdf5
# Epoch 233/2000
# 1092/1092 [==============================] - 8s 7ms/step - loss: 0.3757 - accuracy: 0.8288 - auc: 0.9116
#
# Epoch 00233: loss improved from 0.37758 to 0.37757, saving model to /content/gdrive/My Drive/it3011_project/results_nndl/checkpoints/Best Model - MLP2.hdf5
# Epoch 234/2000
# 1092/1092 [==============================] - 8s 7ms/step - loss: 0.3770 - accuracy: 0.8272 - auc: 0.9109
#
# Epoch 00234: loss did not improve from 0.37757
# Epoch 235/2000
# 1092/1092 [==============================] - 8s 7ms/step - loss: 0.3753 - accuracy: 0.8285 - auc: 0.9119
#
# Epoch 00235: loss improved from 0.37757 to 0.37750, saving model to /content/gdrive/My Drive/it3011_project/results_nndl/checkpoints/Best Model - MLP2.hdf5
# Epoch 236/2000
# 1092/1092 [==============================] - 8s 7ms/step - loss: 0.3741 - accuracy: 0.8291 - auc: 0.9124
#
# Epoch 00236: loss improved from 0.37750 to 0.37694, saving model to /content/gdrive/My Drive/it3011_project/results_nndl/checkpoints/Best Model - MLP2.hdf5
# Epoch 237/2000
# 1092/1092 [==============================] - 8s 7ms/step - loss: 0.3767 - accuracy: 0.8281 - auc: 0.9111
#
# Epoch 00237: loss did not improve from 0.37694
# Epoch 238/2000
# 1092/1092 [==============================] - 8s 7ms/step - loss: 0.3764 - accuracy: 0.8272 - auc: 0.9112
#
# Epoch 00238: loss did not improve from 0.37694
# Epoch 239/2000
# 1092/1092 [==============================] - 8s 7ms/step - loss: 0.3745 - accuracy: 0.8288 - auc: 0.9122
#
# Epoch 00239: loss improved from 0.37694 to 0.37587, saving model to /content/gdrive/My Drive/it3011_project/results_nndl/checkpoints/Best Model - MLP2.hdf5
# Epoch 240/2000
# 1092/1092 [==============================] - 8s 7ms/step - loss: 0.3713 - accuracy: 0.8308 - auc: 0.9137
#
# Epoch 00240: loss improved from 0.37587 to 0.37341, saving model to /content/gdrive/My Drive/it3011_project/results_nndl/checkpoints/Best Model - MLP2.hdf5
# Epoch 241/2000
# 1092/1092 [==============================] - 8s 7ms/step - loss: 0.3740 - accuracy: 0.8306 - auc: 0.9126
#
# Epoch 00241: loss did not improve from 0.37341
# Epoch 242/2000
# 1092/1092 [==============================] - 8s 7ms/step - loss: 0.3716 - accuracy: 0.8305 - auc: 0.9137
#
# Epoch 00242: loss did not improve from 0.37341
# Epoch 243/2000
# 1092/1092 [==============================] - 8s 7ms/step - loss: 0.3749 - accuracy: 0.8289 - auc: 0.9121
#
# Epoch 00243: loss did not improve from 0.37341
# Epoch 244/2000
# 1092/1092 [==============================] - 8s 7ms/step - loss: 0.3733 - accuracy: 0.8298 - auc: 0.9129
#
# Epoch 00244: loss did not improve from 0.37341
# Epoch 245/2000
# 1092/1092 [==============================] - 8s 7ms/step - loss: 0.3742 - accuracy: 0.8292 - auc: 0.9124
#
# Epoch 00245: loss did not improve from 0.37341
# Epoch 246/2000
# 1092/1092 [==============================] - 8s 7ms/step - loss: 0.3724 - accuracy: 0.8295 - auc: 0.9133
#
# Epoch 00246: loss did not improve from 0.37341
# Epoch 247/2000
# 1092/1092 [==============================] - 8s 7ms/step - loss: 0.3720 - accuracy: 0.8302 - auc: 0.9134
#
# Epoch 00247: loss did not improve from 0.37341
# Epoch 248/2000
# 1092/1092 [==============================] - 8s 8ms/step - loss: 0.3704 - accuracy: 0.8316 - auc: 0.9142
#
# Epoch 00248: loss improved from 0.37341 to 0.37236, saving model to /content/gdrive/My Drive/it3011_project/results_nndl/checkpoints/Best Model - MLP2.hdf5
# Epoch 249/2000
# 1092/1092 [==============================] - 8s 8ms/step - loss: 0.3738 - accuracy: 0.8296 - auc: 0.9124
#
# Epoch 00249: loss did not improve from 0.37236
# Epoch 250/2000
# 1092/1092 [==============================] - 8s 8ms/step - loss: 0.3721 - accuracy: 0.8309 - auc: 0.9136
#
# Epoch 00250: loss did not improve from 0.37236
# Epoch 251/2000
# 1092/1092 [==============================] - 8s 7ms/step - loss: 0.3720 - accuracy: 0.8298 - auc: 0.9133
#
# Epoch 00251: loss did not improve from 0.37236
# Epoch 252/2000
# 1092/1092 [==============================] - 8s 7ms/step - loss: 0.3701 - accuracy: 0.8317 - auc: 0.9144
#
# Epoch 00252: loss did not improve from 0.37236
# Epoch 253/2000
# 1092/1092 [==============================] - 8s 7ms/step - loss: 0.3701 - accuracy: 0.8310 - auc: 0.9143
#
# Epoch 00253: loss did not improve from 0.37236
# Epoch 254/2000
# 1092/1092 [==============================] - 8s 7ms/step - loss: 0.3711 - accuracy: 0.8303 - auc: 0.9138
#
# Epoch 00254: loss improved from 0.37236 to 0.37197, saving model to /content/gdrive/My Drive/it3011_project/results_nndl/checkpoints/Best Model - MLP2.hdf5
# Epoch 255/2000
# 1092/1092 [==============================] - 8s 8ms/step - loss: 0.3709 - accuracy: 0.8299 - auc: 0.9139
#
# Epoch 00255: loss did not improve from 0.37197
# Epoch 256/2000
# 1092/1092 [==============================] - 8s 7ms/step - loss: 0.3669 - accuracy: 0.8330 - auc: 0.9159
#
# Epoch 00256: loss improved from 0.37197 to 0.37073, saving model to /content/gdrive/My Drive/it3011_project/results_nndl/checkpoints/Best Model - MLP2.hdf5
# Epoch 257/2000
# 1092/1092 [==============================] - 8s 7ms/step - loss: 0.3683 - accuracy: 0.8322 - auc: 0.9153
#
# Epoch 00257: loss did not improve from 0.37073
# Epoch 258/2000
# 1092/1092 [==============================] - 8s 7ms/step - loss: 0.3692 - accuracy: 0.8314 - auc: 0.9148
#
# Epoch 00258: loss did not improve from 0.37073
# Epoch 259/2000
# 1092/1092 [==============================] - 8s 7ms/step - loss: 0.3711 - accuracy: 0.8312 - auc: 0.9139
#
# Epoch 00259: loss did not improve from 0.37073
# Epoch 260/2000
# 1092/1092 [==============================] - 8s 7ms/step - loss: 0.3692 - accuracy: 0.8331 - auc: 0.9149
#
# Epoch 00260: loss did not improve from 0.37073
# Epoch 261/2000
# 1092/1092 [==============================] - 8s 7ms/step - loss: 0.3687 - accuracy: 0.8315 - auc: 0.9151
#
# Epoch 00261: loss did not improve from 0.37073
# Epoch 262/2000
# 1092/1092 [==============================] - 8s 7ms/step - loss: 0.3701 - accuracy: 0.8308 - auc: 0.9143
#
# Epoch 00262: loss did not improve from 0.37073
# Epoch 263/2000
# 1092/1092 [==============================] - 8s 7ms/step - loss: 0.3689 - accuracy: 0.8331 - auc: 0.9151
#
# Epoch 00263: loss did not improve from 0.37073
# Epoch 264/2000
# 1092/1092 [==============================] - 8s 7ms/step - loss: 0.3673 - accuracy: 0.8338 - auc: 0.9158
#
# Epoch 00264: loss improved from 0.37073 to 0.37062, saving model to /content/gdrive/My Drive/it3011_project/results_nndl/checkpoints/Best Model - MLP2.hdf5
# Epoch 265/2000
# 1092/1092 [==============================] - 8s 8ms/step - loss: 0.3700 - accuracy: 0.8314 - auc: 0.9144
#
# Epoch 00265: loss did not improve from 0.37062
# Epoch 266/2000
# 1092/1092 [==============================] - 8s 8ms/step - loss: 0.3671 - accuracy: 0.8336 - auc: 0.9159
#
# Epoch 00266: loss improved from 0.37062 to 0.37011, saving model to /content/gdrive/My Drive/it3011_project/results_nndl/checkpoints/Best Model - MLP2.hdf5
# Epoch 267/2000
# 1092/1092 [==============================] - 9s 8ms/step - loss: 0.3675 - accuracy: 0.8327 - auc: 0.9156
#
# Epoch 00267: loss did not improve from 0.37011
# Epoch 268/2000
# 1092/1092 [==============================] - 8s 8ms/step - loss: 0.3704 - accuracy: 0.8308 - auc: 0.9142
#
# Epoch 00268: loss did not improve from 0.37011
# Epoch 269/2000
# 1092/1092 [==============================] - 8s 8ms/step - loss: 0.3664 - accuracy: 0.8332 - auc: 0.9161
#
# Epoch 00269: loss improved from 0.37011 to 0.36829, saving model to /content/gdrive/My Drive/it3011_project/results_nndl/checkpoints/Best Model - MLP2.hdf5
# Epoch 270/2000
# 1092/1092 [==============================] - 8s 8ms/step - loss: 0.3662 - accuracy: 0.8337 - auc: 0.9163
#
# Epoch 00270: loss did not improve from 0.36829
# Epoch 271/2000
# 1092/1092 [==============================] - 8s 8ms/step - loss: 0.3666 - accuracy: 0.8328 - auc: 0.9161
#
# Epoch 00271: loss did not improve from 0.36829
# Epoch 272/2000
# 1092/1092 [==============================] - 8s 8ms/step - loss: 0.3669 - accuracy: 0.8327 - auc: 0.9158
#
# Epoch 00272: loss did not improve from 0.36829
# Epoch 273/2000
# 1092/1092 [==============================] - 8s 8ms/step - loss: 0.3638 - accuracy: 0.8357 - auc: 0.9175
#
# Epoch 00273: loss improved from 0.36829 to 0.36803, saving model to /content/gdrive/My Drive/it3011_project/results_nndl/checkpoints/Best Model - MLP2.hdf5
# Epoch 274/2000
# 1092/1092 [==============================] - 8s 8ms/step - loss: 0.3673 - accuracy: 0.8330 - auc: 0.9157
#
# Epoch 00274: loss did not improve from 0.36803
# Epoch 275/2000
# 1092/1092 [==============================] - 8s 8ms/step - loss: 0.3653 - accuracy: 0.8338 - auc: 0.9167
#
# Epoch 00275: loss improved from 0.36803 to 0.36725, saving model to /content/gdrive/My Drive/it3011_project/results_nndl/checkpoints/Best Model - MLP2.hdf5
# Epoch 276/2000
# 1092/1092 [==============================] - 8s 8ms/step - loss: 0.3661 - accuracy: 0.8343 - auc: 0.9164
#
# Epoch 00276: loss did not improve from 0.36725
# Epoch 277/2000
# 1092/1092 [==============================] - 8s 8ms/step - loss: 0.3666 - accuracy: 0.8339 - auc: 0.9161
#
# Epoch 00277: loss improved from 0.36725 to 0.36715, saving model to /content/gdrive/My Drive/it3011_project/results_nndl/checkpoints/Best Model - MLP2.hdf5
# Epoch 278/2000
# 1092/1092 [==============================] - 8s 8ms/step - loss: 0.3658 - accuracy: 0.8343 - auc: 0.9164
#
# Epoch 00278: loss improved from 0.36715 to 0.36702, saving model to /content/gdrive/My Drive/it3011_project/results_nndl/checkpoints/Best Model - MLP2.hdf5
# Epoch 279/2000
# 1092/1092 [==============================] - 8s 7ms/step - loss: 0.3651 - accuracy: 0.8335 - auc: 0.9168
#
# Epoch 00279: loss improved from 0.36702 to 0.36618, saving model to /content/gdrive/My Drive/it3011_project/results_nndl/checkpoints/Best Model - MLP2.hdf5
# Epoch 280/2000
# 1092/1092 [==============================] - 8s 7ms/step - loss: 0.3648 - accuracy: 0.8346 - auc: 0.9171
#
# Epoch 00280: loss improved from 0.36618 to 0.36598, saving model to /content/gdrive/My Drive/it3011_project/results_nndl/checkpoints/Best Model - MLP2.hdf5
# Epoch 281/2000
# 1092/1092 [==============================] - 8s 7ms/step - loss: 0.3651 - accuracy: 0.8341 - auc: 0.9168
#
# Epoch 00281: loss improved from 0.36598 to 0.36591, saving model to /content/gdrive/My Drive/it3011_project/results_nndl/checkpoints/Best Model - MLP2.hdf5
# Epoch 282/2000
# 1092/1092 [==============================] - 8s 7ms/step - loss: 0.3655 - accuracy: 0.8333 - auc: 0.9166
#
# Epoch 00282: loss did not improve from 0.36591
# Epoch 283/2000
# 1092/1092 [==============================] - 8s 7ms/step - loss: 0.3644 - accuracy: 0.8342 - auc: 0.9171
#
# Epoch 00283: loss did not improve from 0.36591
# Epoch 284/2000
# 1092/1092 [==============================] - 8s 7ms/step - loss: 0.3632 - accuracy: 0.8353 - auc: 0.9178
#
# Epoch 00284: loss improved from 0.36591 to 0.36519, saving model to /content/gdrive/My Drive/it3011_project/results_nndl/checkpoints/Best Model - MLP2.hdf5
# Epoch 285/2000
# 1092/1092 [==============================] - 8s 7ms/step - loss: 0.3637 - accuracy: 0.8350 - auc: 0.9175
#
# Epoch 00285: loss did not improve from 0.36519
# Epoch 286/2000
# 1092/1092 [==============================] - 8s 7ms/step - loss: 0.3662 - accuracy: 0.8338 - auc: 0.9164
#
# Epoch 00286: loss did not improve from 0.36519
# Epoch 287/2000
# 1092/1092 [==============================] - 8s 7ms/step - loss: 0.3618 - accuracy: 0.8366 - auc: 0.9185
#
# Epoch 00287: loss improved from 0.36519 to 0.36506, saving model to /content/gdrive/My Drive/it3011_project/results_nndl/checkpoints/Best Model - MLP2.hdf5
# Epoch 288/2000
# 1092/1092 [==============================] - 8s 7ms/step - loss: 0.3623 - accuracy: 0.8366 - auc: 0.9182
#
# Epoch 00288: loss did not improve from 0.36506
# Epoch 289/2000
# 1092/1092 [==============================] - 8s 7ms/step - loss: 0.3638 - accuracy: 0.8345 - auc: 0.9174
#
# Epoch 00289: loss did not improve from 0.36506
# Epoch 290/2000
# 1092/1092 [==============================] - 8s 7ms/step - loss: 0.3649 - accuracy: 0.8348 - auc: 0.9170
#
# Epoch 00290: loss did not improve from 0.36506
# Epoch 291/2000
# 1092/1092 [==============================] - 8s 7ms/step - loss: 0.3646 - accuracy: 0.8343 - auc: 0.9172
#
# Epoch 00291: loss improved from 0.36506 to 0.36504, saving model to /content/gdrive/My Drive/it3011_project/results_nndl/checkpoints/Best Model - MLP2.hdf5
# Epoch 292/2000
# 1092/1092 [==============================] - 8s 7ms/step - loss: 0.3650 - accuracy: 0.8344 - auc: 0.9169
#
# Epoch 00292: loss did not improve from 0.36504
# Epoch 293/2000
# 1092/1092 [==============================] - 8s 7ms/step - loss: 0.3646 - accuracy: 0.8351 - auc: 0.9171
#
# Epoch 00293: loss improved from 0.36504 to 0.36450, saving model to /content/gdrive/My Drive/it3011_project/results_nndl/checkpoints/Best Model - MLP2.hdf5
# Epoch 294/2000
# 1092/1092 [==============================] - 8s 7ms/step - loss: 0.3599 - accuracy: 0.8372 - auc: 0.9194
#
# Epoch 00294: loss improved from 0.36450 to 0.36354, saving model to /content/gdrive/My Drive/it3011_project/results_nndl/checkpoints/Best Model - MLP2.hdf5
# Epoch 295/2000
# 1092/1092 [==============================] - 8s 7ms/step - loss: 0.3644 - accuracy: 0.8350 - auc: 0.9172
#
# Epoch 00295: loss did not improve from 0.36354
# Epoch 296/2000
# 1092/1092 [==============================] - 8s 7ms/step - loss: 0.3636 - accuracy: 0.8363 - auc: 0.9176
#
# Epoch 00296: loss did not improve from 0.36354
# Epoch 297/2000
# 1092/1092 [==============================] - 8s 8ms/step - loss: 0.3626 - accuracy: 0.8359 - auc: 0.9180
#
# Epoch 00297: loss improved from 0.36354 to 0.36263, saving model to /content/gdrive/My Drive/it3011_project/results_nndl/checkpoints/Best Model - MLP2.hdf5
# Epoch 298/2000
# 1092/1092 [==============================] - 8s 8ms/step - loss: 0.3629 - accuracy: 0.8360 - auc: 0.9180
#
# Epoch 00298: loss did not improve from 0.36263
# Epoch 299/2000
# 1092/1092 [==============================] - 8s 7ms/step - loss: 0.3628 - accuracy: 0.8346 - auc: 0.9179
#
# Epoch 00299: loss did not improve from 0.36263
# Epoch 300/2000
# 1092/1092 [==============================] - 8s 7ms/step - loss: 0.3618 - accuracy: 0.8370 - auc: 0.9185
#
# Epoch 00300: loss did not improve from 0.36263
# Epoch 301/2000
# 1092/1092 [==============================] - 8s 7ms/step - loss: 0.3609 - accuracy: 0.8374 - auc: 0.9189
#
# Epoch 00301: loss improved from 0.36263 to 0.36220, saving model to /content/gdrive/My Drive/it3011_project/results_nndl/checkpoints/Best Model - MLP2.hdf5
# Epoch 302/2000
# 1092/1092 [==============================] - 8s 7ms/step - loss: 0.3621 - accuracy: 0.8351 - auc: 0.9182
#
# Epoch 00302: loss did not improve from 0.36220
# Epoch 303/2000
# 1092/1092 [==============================] - 8s 7ms/step - loss: 0.3606 - accuracy: 0.8368 - auc: 0.9191
#
# Epoch 00303: loss did not improve from 0.36220
# Epoch 304/2000
# 1092/1092 [==============================] - 8s 7ms/step - loss: 0.3618 - accuracy: 0.8353 - auc: 0.9184
#
# Epoch 00304: loss did not improve from 0.36220
# Epoch 305/2000
# 1092/1092 [==============================] - 8s 7ms/step - loss: 0.3630 - accuracy: 0.8358 - auc: 0.9178
#
# Epoch 00305: loss did not improve from 0.36220
# Epoch 306/2000
# 1092/1092 [==============================] - 8s 7ms/step - loss: 0.3613 - accuracy: 0.8365 - auc: 0.9186
#
# Epoch 00306: loss did not improve from 0.36220
# Epoch 307/2000
# 1092/1092 [==============================] - 8s 7ms/step - loss: 0.3595 - accuracy: 0.8368 - auc: 0.9195
#
# Epoch 00307: loss improved from 0.36220 to 0.36145, saving model to /content/gdrive/My Drive/it3011_project/results_nndl/checkpoints/Best Model - MLP2.hdf5
# Epoch 308/2000
# 1092/1092 [==============================] - 8s 7ms/step - loss: 0.3595 - accuracy: 0.8383 - auc: 0.9195
#
# Epoch 00308: loss did not improve from 0.36145
# Epoch 309/2000
# 1092/1092 [==============================] - 8s 7ms/step - loss: 0.3581 - accuracy: 0.8377 - auc: 0.9201
#
# Epoch 00309: loss improved from 0.36145 to 0.36056, saving model to /content/gdrive/My Drive/it3011_project/results_nndl/checkpoints/Best Model - MLP2.hdf5
# Epoch 310/2000
# 1092/1092 [==============================] - 8s 7ms/step - loss: 0.3601 - accuracy: 0.8361 - auc: 0.9192
#
# Epoch 00310: loss did not improve from 0.36056
# Epoch 311/2000
# 1092/1092 [==============================] - 8s 7ms/step - loss: 0.3610 - accuracy: 0.8362 - auc: 0.9188
#
# Epoch 00311: loss did not improve from 0.36056
# Epoch 312/2000
# 1092/1092 [==============================] - 8s 7ms/step - loss: 0.3609 - accuracy: 0.8379 - auc: 0.9189
#
# Epoch 00312: loss did not improve from 0.36056
# Epoch 313/2000
# 1092/1092 [==============================] - 8s 7ms/step - loss: 0.3583 - accuracy: 0.8373 - auc: 0.9201
#
# Epoch 00313: loss improved from 0.36056 to 0.36023, saving model to /content/gdrive/My Drive/it3011_project/results_nndl/checkpoints/Best Model - MLP2.hdf5
# Epoch 314/2000
# 1092/1092 [==============================] - 8s 7ms/step - loss: 0.3609 - accuracy: 0.8369 - auc: 0.9189
#
# Epoch 00314: loss did not improve from 0.36023
# Epoch 315/2000
# 1092/1092 [==============================] - 8s 7ms/step - loss: 0.3591 - accuracy: 0.8383 - auc: 0.9198
#
# Epoch 00315: loss did not improve from 0.36023
# Epoch 316/2000
# 1092/1092 [==============================] - 8s 7ms/step - loss: 0.3597 - accuracy: 0.8371 - auc: 0.9194
#
# Epoch 00316: loss did not improve from 0.36023
# Epoch 317/2000
# 1092/1092 [==============================] - 8s 7ms/step - loss: 0.3590 - accuracy: 0.8371 - auc: 0.9197
#
# Epoch 00317: loss improved from 0.36023 to 0.35994, saving model to /content/gdrive/My Drive/it3011_project/results_nndl/checkpoints/Best Model - MLP2.hdf5
# Epoch 318/2000
# 1092/1092 [==============================] - 8s 7ms/step - loss: 0.3568 - accuracy: 0.8387 - auc: 0.9208
#
# Epoch 00318: loss improved from 0.35994 to 0.35978, saving model to /content/gdrive/My Drive/it3011_project/results_nndl/checkpoints/Best Model - MLP2.hdf5
# Epoch 319/2000
# 1092/1092 [==============================] - 8s 7ms/step - loss: 0.3583 - accuracy: 0.8384 - auc: 0.9201
#
# Epoch 00319: loss improved from 0.35978 to 0.35952, saving model to /content/gdrive/My Drive/it3011_project/results_nndl/checkpoints/Best Model - MLP2.hdf5
# Epoch 320/2000
# 1092/1092 [==============================] - 8s 7ms/step - loss: 0.3571 - accuracy: 0.8387 - auc: 0.9207
#
# Epoch 00320: loss improved from 0.35952 to 0.35870, saving model to /content/gdrive/My Drive/it3011_project/results_nndl/checkpoints/Best Model - MLP2.hdf5
# Epoch 321/2000
# 1092/1092 [==============================] - 8s 7ms/step - loss: 0.3570 - accuracy: 0.8386 - auc: 0.9207
#
# Epoch 00321: loss did not improve from 0.35870
# Epoch 322/2000
# 1092/1092 [==============================] - 8s 7ms/step - loss: 0.3573 - accuracy: 0.8387 - auc: 0.9206
#
# Epoch 00322: loss improved from 0.35870 to 0.35840, saving model to /content/gdrive/My Drive/it3011_project/results_nndl/checkpoints/Best Model - MLP2.hdf5
# Epoch 323/2000
# 1092/1092 [==============================] - 8s 7ms/step - loss: 0.3589 - accuracy: 0.8377 - auc: 0.9197
#
# Epoch 00323: loss did not improve from 0.35840
# Epoch 324/2000
# 1092/1092 [==============================] - 8s 7ms/step - loss: 0.3589 - accuracy: 0.8382 - auc: 0.9198
#
# Epoch 00324: loss did not improve from 0.35840
# Epoch 325/2000
# 1092/1092 [==============================] - 8s 7ms/step - loss: 0.3595 - accuracy: 0.8377 - auc: 0.9195
#
# Epoch 00325: loss did not improve from 0.35840
# Epoch 326/2000
# 1092/1092 [==============================] - 8s 7ms/step - loss: 0.3572 - accuracy: 0.8390 - auc: 0.9206
#
# Epoch 00326: loss improved from 0.35840 to 0.35834, saving model to /content/gdrive/My Drive/it3011_project/results_nndl/checkpoints/Best Model - MLP2.hdf5
# Epoch 327/2000
# 1092/1092 [==============================] - 8s 7ms/step - loss: 0.3569 - accuracy: 0.8390 - auc: 0.9207
#
# Epoch 00327: loss improved from 0.35834 to 0.35825, saving model to /content/gdrive/My Drive/it3011_project/results_nndl/checkpoints/Best Model - MLP2.hdf5
# Epoch 328/2000
# 1092/1092 [==============================] - 8s 7ms/step - loss: 0.3581 - accuracy: 0.8380 - auc: 0.9202
#
# Epoch 00328: loss did not improve from 0.35825
# Epoch 329/2000
# 1092/1092 [==============================] - 8s 7ms/step - loss: 0.3567 - accuracy: 0.8380 - auc: 0.9207
#
# Epoch 00329: loss did not improve from 0.35825
# Epoch 330/2000
# 1092/1092 [==============================] - 8s 7ms/step - loss: 0.3586 - accuracy: 0.8386 - auc: 0.9200
#
# Epoch 00330: loss did not improve from 0.35825
# Epoch 331/2000
# 1092/1092 [==============================] - 8s 7ms/step - loss: 0.3604 - accuracy: 0.8369 - auc: 0.9191
#
# Epoch 00331: loss did not improve from 0.35825
# Epoch 332/2000
# 1092/1092 [==============================] - 8s 7ms/step - loss: 0.3561 - accuracy: 0.8392 - auc: 0.9211
#
# Epoch 00332: loss improved from 0.35825 to 0.35783, saving model to /content/gdrive/My Drive/it3011_project/results_nndl/checkpoints/Best Model - MLP2.hdf5
# Epoch 333/2000
# 1092/1092 [==============================] - 8s 7ms/step - loss: 0.3570 - accuracy: 0.8385 - auc: 0.9207
#
# Epoch 00333: loss did not improve from 0.35783
# Epoch 334/2000
# 1092/1092 [==============================] - 8s 7ms/step - loss: 0.3563 - accuracy: 0.8390 - auc: 0.9210
#
# Epoch 00334: loss improved from 0.35783 to 0.35775, saving model to /content/gdrive/My Drive/it3011_project/results_nndl/checkpoints/Best Model - MLP2.hdf5
# Epoch 335/2000
# 1092/1092 [==============================] - 8s 8ms/step - loss: 0.3564 - accuracy: 0.8392 - auc: 0.9210
#
# Epoch 00335: loss did not improve from 0.35775
# Epoch 336/2000
# 1092/1092 [==============================] - 8s 8ms/step - loss: 0.3549 - accuracy: 0.8407 - auc: 0.9216
#
# Epoch 00336: loss did not improve from 0.35775
# Epoch 337/2000
# 1092/1092 [==============================] - 8s 8ms/step - loss: 0.3578 - accuracy: 0.8383 - auc: 0.9204
#
# Epoch 00337: loss did not improve from 0.35775
# Epoch 338/2000
# 1092/1092 [==============================] - 8s 7ms/step - loss: 0.3606 - accuracy: 0.8369 - auc: 0.9190
#
# Epoch 00338: loss did not improve from 0.35775
# Epoch 339/2000
# 1092/1092 [==============================] - 8s 8ms/step - loss: 0.3568 - accuracy: 0.8385 - auc: 0.9209
#
# Epoch 00339: loss improved from 0.35775 to 0.35734, saving model to /content/gdrive/My Drive/it3011_project/results_nndl/checkpoints/Best Model - MLP2.hdf5
# Epoch 340/2000
# 1092/1092 [==============================] - 8s 8ms/step - loss: 0.3541 - accuracy: 0.8409 - auc: 0.9221
#
# Epoch 00340: loss improved from 0.35734 to 0.35583, saving model to /content/gdrive/My Drive/it3011_project/results_nndl/checkpoints/Best Model - MLP2.hdf5
# Epoch 341/2000
# 1092/1092 [==============================] - 8s 8ms/step - loss: 0.3556 - accuracy: 0.8391 - auc: 0.9214
#
# Epoch 00341: loss did not improve from 0.35583
# Epoch 342/2000
# 1092/1092 [==============================] - 8s 8ms/step - loss: 0.3561 - accuracy: 0.8393 - auc: 0.9211
#
# Epoch 00342: loss did not improve from 0.35583
# Epoch 343/2000
# 1092/1092 [==============================] - 8s 7ms/step - loss: 0.3582 - accuracy: 0.8379 - auc: 0.9202
#
# Epoch 00343: loss did not improve from 0.35583
# Epoch 344/2000
# 1092/1092 [==============================] - 8s 7ms/step - loss: 0.3548 - accuracy: 0.8382 - auc: 0.9216
#
# Epoch 00344: loss did not improve from 0.35583
# Epoch 345/2000
# 1092/1092 [==============================] - 8s 7ms/step - loss: 0.3550 - accuracy: 0.8398 - auc: 0.9217
#
# Epoch 00345: loss did not improve from 0.35583
# Epoch 346/2000
# 1092/1092 [==============================] - 8s 7ms/step - loss: 0.3539 - accuracy: 0.8416 - auc: 0.9222
#
# Epoch 00346: loss did not improve from 0.35583
# Epoch 347/2000
# 1092/1092 [==============================] - 8s 7ms/step - loss: 0.3554 - accuracy: 0.8410 - auc: 0.9215
#
# Epoch 00347: loss did not improve from 0.35583
# Epoch 348/2000
# 1092/1092 [==============================] - 8s 7ms/step - loss: 0.3552 - accuracy: 0.8400 - auc: 0.9216
#
# Epoch 00348: loss did not improve from 0.35583
# Epoch 349/2000
# 1092/1092 [==============================] - 8s 7ms/step - loss: 0.3551 - accuracy: 0.8398 - auc: 0.9216
#
# Epoch 00349: loss did not improve from 0.35583
# Epoch 350/2000
# 1092/1092 [==============================] - 8s 7ms/step - loss: 0.3525 - accuracy: 0.8417 - auc: 0.9228
#
# Epoch 00350: loss improved from 0.35583 to 0.35518, saving model to /content/gdrive/My Drive/it3011_project/results_nndl/checkpoints/Best Model - MLP2.hdf5
# Epoch 351/2000
# 1092/1092 [==============================] - 8s 7ms/step - loss: 0.3552 - accuracy: 0.8395 - auc: 0.9214
#
# Epoch 00351: loss did not improve from 0.35518
# Epoch 352/2000
# 1092/1092 [==============================] - 8s 7ms/step - loss: 0.3537 - accuracy: 0.8404 - auc: 0.9223
#
# Epoch 00352: loss improved from 0.35518 to 0.35516, saving model to /content/gdrive/My Drive/it3011_project/results_nndl/checkpoints/Best Model - MLP2.hdf5
# Epoch 353/2000
# 1092/1092 [==============================] - 8s 7ms/step - loss: 0.3553 - accuracy: 0.8399 - auc: 0.9216
#
# Epoch 00353: loss did not improve from 0.35516
# Epoch 354/2000
# 1092/1092 [==============================] - 8s 7ms/step - loss: 0.3526 - accuracy: 0.8414 - auc: 0.9228
#
# Epoch 00354: loss improved from 0.35516 to 0.35402, saving model to /content/gdrive/My Drive/it3011_project/results_nndl/checkpoints/Best Model - MLP2.hdf5
# Epoch 355/2000
# 1092/1092 [==============================] - 8s 8ms/step - loss: 0.3538 - accuracy: 0.8400 - auc: 0.9221
#
# Epoch 00355: loss improved from 0.35402 to 0.35391, saving model to /content/gdrive/My Drive/it3011_project/results_nndl/checkpoints/Best Model - MLP2.hdf5
# Epoch 356/2000
# 1092/1092 [==============================] - 8s 8ms/step - loss: 0.3506 - accuracy: 0.8421 - auc: 0.9236
#
# Epoch 00356: loss improved from 0.35391 to 0.35375, saving model to /content/gdrive/My Drive/it3011_project/results_nndl/checkpoints/Best Model - MLP2.hdf5
# Epoch 357/2000
# 1092/1092 [==============================] - 8s 7ms/step - loss: 0.3517 - accuracy: 0.8411 - auc: 0.9232
#
# Epoch 00357: loss did not improve from 0.35375
# Epoch 358/2000
# 1092/1092 [==============================] - 8s 7ms/step - loss: 0.3538 - accuracy: 0.8395 - auc: 0.9221
#
# Epoch 00358: loss did not improve from 0.35375
# Epoch 359/2000
# 1092/1092 [==============================] - 8s 7ms/step - loss: 0.3535 - accuracy: 0.8408 - auc: 0.9223
#
# Epoch 00359: loss did not improve from 0.35375
# Epoch 360/2000
# 1092/1092 [==============================] - 8s 7ms/step - loss: 0.3535 - accuracy: 0.8396 - auc: 0.9223
#
# Epoch 00360: loss did not improve from 0.35375
# Epoch 361/2000
# 1092/1092 [==============================] - 8s 7ms/step - loss: 0.3535 - accuracy: 0.8409 - auc: 0.9224
#
# Epoch 00361: loss improved from 0.35375 to 0.35363, saving model to /content/gdrive/My Drive/it3011_project/results_nndl/checkpoints/Best Model - MLP2.hdf5
# Epoch 362/2000
# 1092/1092 [==============================] - 8s 7ms/step - loss: 0.3547 - accuracy: 0.8397 - auc: 0.9218
#
# Epoch 00362: loss did not improve from 0.35363
# Epoch 363/2000
# 1092/1092 [==============================] - 8s 7ms/step - loss: 0.3503 - accuracy: 0.8432 - auc: 0.9238
#
# Epoch 00363: loss improved from 0.35363 to 0.35308, saving model to /content/gdrive/My Drive/it3011_project/results_nndl/checkpoints/Best Model - MLP2.hdf5
# Epoch 364/2000
# 1092/1092 [==============================] - 8s 8ms/step - loss: 0.3542 - accuracy: 0.8408 - auc: 0.9220
#
# Epoch 00364: loss did not improve from 0.35308
# Epoch 365/2000
# 1092/1092 [==============================] - 8s 7ms/step - loss: 0.3514 - accuracy: 0.8417 - auc: 0.9234
#
# Epoch 00365: loss did not improve from 0.35308
# Epoch 366/2000
# 1092/1092 [==============================] - 8s 7ms/step - loss: 0.3514 - accuracy: 0.8415 - auc: 0.9233
#
# Epoch 00366: loss did not improve from 0.35308
# Epoch 367/2000
# 1092/1092 [==============================] - 8s 7ms/step - loss: 0.3527 - accuracy: 0.8409 - auc: 0.9227
#
# Epoch 00367: loss improved from 0.35308 to 0.35283, saving model to /content/gdrive/My Drive/it3011_project/results_nndl/checkpoints/Best Model - MLP2.hdf5
# Epoch 368/2000
# 1092/1092 [==============================] - 8s 7ms/step - loss: 0.3528 - accuracy: 0.8418 - auc: 0.9227
#
# Epoch 00368: loss did not improve from 0.35283
# Epoch 369/2000
# 1092/1092 [==============================] - 8s 7ms/step - loss: 0.3504 - accuracy: 0.8431 - auc: 0.9238
#
# Epoch 00369: loss did not improve from 0.35283
# Epoch 370/2000
# 1092/1092 [==============================] - 8s 7ms/step - loss: 0.3494 - accuracy: 0.8425 - auc: 0.9241
#
# Epoch 00370: loss improved from 0.35283 to 0.35182, saving model to /content/gdrive/My Drive/it3011_project/results_nndl/checkpoints/Best Model - MLP2.hdf5
# Epoch 371/2000
# 1092/1092 [==============================] - 8s 8ms/step - loss: 0.3494 - accuracy: 0.8432 - auc: 0.9242
#
# Epoch 00371: loss did not improve from 0.35182
# Epoch 372/2000
# 1092/1092 [==============================] - 8s 7ms/step - loss: 0.3513 - accuracy: 0.8422 - auc: 0.9234
#
# Epoch 00372: loss did not improve from 0.35182
# Epoch 373/2000
# 1092/1092 [==============================] - 8s 7ms/step - loss: 0.3512 - accuracy: 0.8414 - auc: 0.9233
#
# Epoch 00373: loss did not improve from 0.35182
# Epoch 374/2000
# 1092/1092 [==============================] - 8s 7ms/step - loss: 0.3491 - accuracy: 0.8442 - auc: 0.9244
#
# Epoch 00374: loss improved from 0.35182 to 0.35147, saving model to /content/gdrive/My Drive/it3011_project/results_nndl/checkpoints/Best Model - MLP2.hdf5
# Epoch 375/2000
# 1092/1092 [==============================] - 8s 8ms/step - loss: 0.3508 - accuracy: 0.8425 - auc: 0.9236
#
# Epoch 00375: loss did not improve from 0.35147
# Epoch 376/2000
# 1092/1092 [==============================] - 8s 7ms/step - loss: 0.3497 - accuracy: 0.8426 - auc: 0.9240
#
# Epoch 00376: loss did not improve from 0.35147
# Epoch 377/2000
# 1092/1092 [==============================] - 8s 7ms/step - loss: 0.3500 - accuracy: 0.8419 - auc: 0.9239
#
# Epoch 00377: loss did not improve from 0.35147
# Epoch 378/2000
# 1092/1092 [==============================] - 8s 7ms/step - loss: 0.3543 - accuracy: 0.8410 - auc: 0.9221
#
# Epoch 00378: loss did not improve from 0.35147
# Epoch 379/2000
# 1092/1092 [==============================] - 8s 8ms/step - loss: 0.3488 - accuracy: 0.8424 - auc: 0.9245
#
# Epoch 00379: loss did not improve from 0.35147
# Epoch 380/2000
# 1092/1092 [==============================] - 8s 8ms/step - loss: 0.3508 - accuracy: 0.8422 - auc: 0.9236
#
# Epoch 00380: loss did not improve from 0.35147
# Epoch 381/2000
# 1092/1092 [==============================] - 8s 7ms/step - loss: 0.3500 - accuracy: 0.8425 - auc: 0.9239
#
# Epoch 00381: loss did not improve from 0.35147
# Epoch 382/2000
# 1092/1092 [==============================] - 8s 7ms/step - loss: 0.3509 - accuracy: 0.8426 - auc: 0.9235
#
# Epoch 00382: loss improved from 0.35147 to 0.35142, saving model to /content/gdrive/My Drive/it3011_project/results_nndl/checkpoints/Best Model - MLP2.hdf5
# Epoch 383/2000
# 1092/1092 [==============================] - 8s 8ms/step - loss: 0.3506 - accuracy: 0.8417 - auc: 0.9238
#
# Epoch 00383: loss improved from 0.35142 to 0.35119, saving model to /content/gdrive/My Drive/it3011_project/results_nndl/checkpoints/Best Model - MLP2.hdf5
# Epoch 384/2000
# 1092/1092 [==============================] - 8s 8ms/step - loss: 0.3507 - accuracy: 0.8414 - auc: 0.9236
#
# Epoch 00384: loss did not improve from 0.35119
# Epoch 385/2000
# 1092/1092 [==============================] - 8s 7ms/step - loss: 0.3494 - accuracy: 0.8427 - auc: 0.9242
#
# Epoch 00385: loss improved from 0.35119 to 0.35095, saving model to /content/gdrive/My Drive/it3011_project/results_nndl/checkpoints/Best Model - MLP2.hdf5
# Epoch 386/2000
# 1092/1092 [==============================] - 8s 8ms/step - loss: 0.3487 - accuracy: 0.8434 - auc: 0.9246
#
# Epoch 00386: loss did not improve from 0.35095
# Epoch 387/2000
# 1092/1092 [==============================] - 8s 8ms/step - loss: 0.3516 - accuracy: 0.8411 - auc: 0.9233
#
# Epoch 00387: loss did not improve from 0.35095
# Epoch 388/2000
# 1092/1092 [==============================] - 8s 7ms/step - loss: 0.3482 - accuracy: 0.8438 - auc: 0.9248
#
# Epoch 00388: loss improved from 0.35095 to 0.35052, saving model to /content/gdrive/My Drive/it3011_project/results_nndl/checkpoints/Best Model - MLP2.hdf5
# Epoch 389/2000
# 1092/1092 [==============================] - 8s 7ms/step - loss: 0.3498 - accuracy: 0.8426 - auc: 0.9240
#
# Epoch 00389: loss improved from 0.35052 to 0.35031, saving model to /content/gdrive/My Drive/it3011_project/results_nndl/checkpoints/Best Model - MLP2.hdf5
# Epoch 390/2000
# 1092/1092 [==============================] - 8s 7ms/step - loss: 0.3499 - accuracy: 0.8436 - auc: 0.9241
#
# Epoch 00390: loss did not improve from 0.35031
# Epoch 391/2000
# 1092/1092 [==============================] - 8s 7ms/step - loss: 0.3465 - accuracy: 0.8457 - auc: 0.9256
#
# Epoch 00391: loss improved from 0.35031 to 0.34840, saving model to /content/gdrive/My Drive/it3011_project/results_nndl/checkpoints/Best Model - MLP2.hdf5
# Epoch 392/2000
# 1092/1092 [==============================] - 8s 8ms/step - loss: 0.3490 - accuracy: 0.8430 - auc: 0.9244
#
# Epoch 00392: loss did not improve from 0.34840
# Epoch 393/2000
# 1092/1092 [==============================] - 8s 8ms/step - loss: 0.3483 - accuracy: 0.8434 - auc: 0.9247
#
# Epoch 00393: loss did not improve from 0.34840
# Epoch 394/2000
# 1092/1092 [==============================] - 8s 8ms/step - loss: 0.3489 - accuracy: 0.8432 - auc: 0.9244
#
# Epoch 00394: loss did not improve from 0.34840
# Epoch 395/2000
# 1092/1092 [==============================] - 8s 8ms/step - loss: 0.3505 - accuracy: 0.8421 - auc: 0.9237
#
# Epoch 00395: loss did not improve from 0.34840
# Epoch 396/2000
# 1092/1092 [==============================] - 8s 8ms/step - loss: 0.3492 - accuracy: 0.8431 - auc: 0.9243
#
# Epoch 00396: loss did not improve from 0.34840
# Epoch 397/2000
# 1092/1092 [==============================] - 8s 8ms/step - loss: 0.3491 - accuracy: 0.8439 - auc: 0.9243
#
# Epoch 00397: loss did not improve from 0.34840
# Epoch 398/2000
# 1092/1092 [==============================] - 8s 8ms/step - loss: 0.3472 - accuracy: 0.8444 - auc: 0.9252
#
# Epoch 00398: loss did not improve from 0.34840
# Epoch 399/2000
# 1092/1092 [==============================] - 8s 8ms/step - loss: 0.3494 - accuracy: 0.8425 - auc: 0.9242
#
# Epoch 00399: loss did not improve from 0.34840
# Epoch 400/2000
# 1092/1092 [==============================] - 8s 7ms/step - loss: 0.3483 - accuracy: 0.8431 - auc: 0.9248
#
# Epoch 00400: loss did not improve from 0.34840
# Epoch 401/2000
# 1092/1092 [==============================] - 8s 7ms/step - loss: 0.3465 - accuracy: 0.8444 - auc: 0.9255
#
# Epoch 00401: loss did not improve from 0.34840
# Epoch 402/2000
# 1092/1092 [==============================] - 8s 7ms/step - loss: 0.3461 - accuracy: 0.8444 - auc: 0.9257
#
# Epoch 00402: loss did not improve from 0.34840
# Epoch 403/2000
# 1092/1092 [==============================] - 8s 7ms/step - loss: 0.3499 - accuracy: 0.8432 - auc: 0.9241
#
# Epoch 00403: loss did not improve from 0.34840
# Epoch 404/2000
# 1092/1092 [==============================] - 8s 8ms/step - loss: 0.3469 - accuracy: 0.8455 - auc: 0.9254
#
# Epoch 00404: loss did not improve from 0.34840
# Epoch 405/2000
# 1092/1092 [==============================] - 8s 8ms/step - loss: 0.3479 - accuracy: 0.8442 - auc: 0.9249
#
# Epoch 00405: loss did not improve from 0.34840
# Epoch 406/2000
# 1092/1092 [==============================] - 8s 7ms/step - loss: 0.3499 - accuracy: 0.8432 - auc: 0.9241
#
# Epoch 00406: loss did not improve from 0.34840
# Epoch 407/2000
# 1092/1092 [==============================] - 8s 7ms/step - loss: 0.3487 - accuracy: 0.8441 - auc: 0.9246
#
# Epoch 00407: loss did not improve from 0.34840
# Epoch 408/2000
# 1092/1092 [==============================] - 8s 7ms/step - loss: 0.3497 - accuracy: 0.8427 - auc: 0.9240
#
# Epoch 00408: loss did not improve from 0.34840
# Epoch 409/2000
# 1092/1092 [==============================] - 8s 7ms/step - loss: 0.3475 - accuracy: 0.8433 - auc: 0.9251
#
# Epoch 00409: loss did not improve from 0.34840
# Epoch 410/2000
# 1092/1092 [==============================] - 8s 7ms/step - loss: 0.3509 - accuracy: 0.8421 - auc: 0.9236
#
# Epoch 00410: loss did not improve from 0.34840
# Epoch 411/2000
# 1092/1092 [==============================] - 8s 7ms/step - loss: 0.3472 - accuracy: 0.8444 - auc: 0.9252
#
# Epoch 00411: loss did not improve from 0.34840
# Epoch 412/2000
# 1092/1092 [==============================] - 8s 7ms/step - loss: 0.3480 - accuracy: 0.8441 - auc: 0.9249
#
# Epoch 00412: loss did not improve from 0.34840
# Epoch 413/2000
# 1092/1092 [==============================] - 8s 7ms/step - loss: 0.3471 - accuracy: 0.8443 - auc: 0.9253
#
# Epoch 00413: loss did not improve from 0.34840
# Epoch 414/2000
# 1092/1092 [==============================] - 8s 7ms/step - loss: 0.3477 - accuracy: 0.8435 - auc: 0.9250
#
# Epoch 00414: loss did not improve from 0.34840
# Epoch 415/2000
# 1092/1092 [==============================] - 8s 7ms/step - loss: 0.3473 - accuracy: 0.8447 - auc: 0.9252
#
# Epoch 00415: loss did not improve from 0.34840
# Epoch 416/2000
# 1092/1092 [==============================] - 8s 7ms/step - loss: 0.3458 - accuracy: 0.8451 - auc: 0.9259
#
# Epoch 00416: loss did not improve from 0.34840
# Epoch 417/2000
# 1092/1092 [==============================] - 8s 8ms/step - loss: 0.3484 - accuracy: 0.8439 - auc: 0.9247
#
# Epoch 00417: loss did not improve from 0.34840
# Epoch 418/2000
# 1092/1092 [==============================] - 8s 8ms/step - loss: 0.3505 - accuracy: 0.8428 - auc: 0.9238
#
# Epoch 00418: loss did not improve from 0.34840
# Epoch 419/2000
# 1092/1092 [==============================] - 8s 8ms/step - loss: 0.3474 - accuracy: 0.8437 - auc: 0.9251
#
# Epoch 00419: loss did not improve from 0.34840
# Epoch 420/2000
# 1092/1092 [==============================] - 8s 7ms/step - loss: 0.3441 - accuracy: 0.8460 - auc: 0.9266
#
# Epoch 00420: loss improved from 0.34840 to 0.34583, saving model to /content/gdrive/My Drive/it3011_project/results_nndl/checkpoints/Best Model - MLP2.hdf5
# Epoch 421/2000
# 1092/1092 [==============================] - 8s 7ms/step - loss: 0.3449 - accuracy: 0.8463 - auc: 0.9263
#
# Epoch 00421: loss did not improve from 0.34583
# Epoch 422/2000
# 1092/1092 [==============================] - 8s 7ms/step - loss: 0.3439 - accuracy: 0.8462 - auc: 0.9267
#
# Epoch 00422: loss improved from 0.34583 to 0.34572, saving model to /content/gdrive/My Drive/it3011_project/results_nndl/checkpoints/Best Model - MLP2.hdf5
# Epoch 423/2000
# 1092/1092 [==============================] - 8s 8ms/step - loss: 0.3465 - accuracy: 0.8445 - auc: 0.9256
#
# Epoch 00423: loss did not improve from 0.34572
# Epoch 424/2000
# 1092/1092 [==============================] - 8s 8ms/step - loss: 0.3483 - accuracy: 0.8437 - auc: 0.9247
#
# Epoch 00424: loss did not improve from 0.34572
# Epoch 425/2000
# 1092/1092 [==============================] - 8s 7ms/step - loss: 0.3452 - accuracy: 0.8455 - auc: 0.9260
#
# Epoch 00425: loss did not improve from 0.34572
# Epoch 426/2000
# 1092/1092 [==============================] - 8s 8ms/step - loss: 0.3454 - accuracy: 0.8452 - auc: 0.9260
#
# Epoch 00426: loss did not improve from 0.34572
# Epoch 427/2000
# 1092/1092 [==============================] - 8s 8ms/step - loss: 0.3445 - accuracy: 0.8465 - auc: 0.9265
#
# Epoch 00427: loss did not improve from 0.34572
# Epoch 428/2000
# 1092/1092 [==============================] - 8s 8ms/step - loss: 0.3451 - accuracy: 0.8451 - auc: 0.9261
#
# Epoch 00428: loss did not improve from 0.34572
# Epoch 429/2000
# 1092/1092 [==============================] - 8s 8ms/step - loss: 0.3468 - accuracy: 0.8442 - auc: 0.9254
#
# Epoch 00429: loss did not improve from 0.34572
# Epoch 430/2000
# 1092/1092 [==============================] - 8s 8ms/step - loss: 0.3449 - accuracy: 0.8455 - auc: 0.9262
#
# Epoch 00430: loss did not improve from 0.34572
# Epoch 431/2000
# 1092/1092 [==============================] - 8s 8ms/step - loss: 0.3433 - accuracy: 0.8461 - auc: 0.9269
#
# Epoch 00431: loss improved from 0.34572 to 0.34555, saving model to /content/gdrive/My Drive/it3011_project/results_nndl/checkpoints/Best Model - MLP2.hdf5
# Epoch 432/2000
# 1092/1092 [==============================] - 8s 8ms/step - loss: 0.3439 - accuracy: 0.8462 - auc: 0.9267
#
# Epoch 00432: loss did not improve from 0.34555
# Epoch 433/2000
# 1092/1092 [==============================] - 9s 8ms/step - loss: 0.3453 - accuracy: 0.8459 - auc: 0.9261
#
# Epoch 00433: loss did not improve from 0.34555
# Epoch 434/2000
# 1092/1092 [==============================] - 8s 8ms/step - loss: 0.3434 - accuracy: 0.8467 - auc: 0.9270
#
# Epoch 00434: loss did not improve from 0.34555
# Epoch 435/2000
# 1092/1092 [==============================] - 8s 8ms/step - loss: 0.3441 - accuracy: 0.8466 - auc: 0.9267
#
# Epoch 00435: loss did not improve from 0.34555
# Epoch 436/2000
# 1092/1092 [==============================] - 8s 8ms/step - loss: 0.3424 - accuracy: 0.8465 - auc: 0.9273
#
# Epoch 00436: loss improved from 0.34555 to 0.34373, saving model to /content/gdrive/My Drive/it3011_project/results_nndl/checkpoints/Best Model - MLP2.hdf5
# Epoch 437/2000
# 1092/1092 [==============================] - 8s 8ms/step - loss: 0.3475 - accuracy: 0.8436 - auc: 0.9252
#
# Epoch 00437: loss did not improve from 0.34373
# Epoch 438/2000
# 1092/1092 [==============================] - 8s 8ms/step - loss: 0.3458 - accuracy: 0.8449 - auc: 0.9259
#
# Epoch 00438: loss did not improve from 0.34373
# Epoch 439/2000
# 1092/1092 [==============================] - 8s 7ms/step - loss: 0.3432 - accuracy: 0.8468 - auc: 0.9271
#
# Epoch 00439: loss did not improve from 0.34373
# Epoch 440/2000
# 1092/1092 [==============================] - 8s 8ms/step - loss: 0.3440 - accuracy: 0.8465 - auc: 0.9267
#
# Epoch 00440: loss did not improve from 0.34373
# Epoch 441/2000
# 1092/1092 [==============================] - 8s 8ms/step - loss: 0.3451 - accuracy: 0.8465 - auc: 0.9263
#
# Epoch 00441: loss did not improve from 0.34373
# Epoch 442/2000
# 1092/1092 [==============================] - 8s 7ms/step - loss: 0.3443 - accuracy: 0.8457 - auc: 0.9265
#
# Epoch 00442: loss did not improve from 0.34373
# Epoch 443/2000
# 1092/1092 [==============================] - 8s 8ms/step - loss: 0.3483 - accuracy: 0.8437 - auc: 0.9248
#
# Epoch 00443: loss did not improve from 0.34373
# Epoch 444/2000
# 1092/1092 [==============================] - 8s 8ms/step - loss: 0.3437 - accuracy: 0.8461 - auc: 0.9268
#
# Epoch 00444: loss did not improve from 0.34373
# Epoch 445/2000
# 1092/1092 [==============================] - 8s 7ms/step - loss: 0.3441 - accuracy: 0.8472 - auc: 0.9267
#
# Epoch 00445: loss did not improve from 0.34373
# Epoch 446/2000
# 1092/1092 [==============================] - 8s 7ms/step - loss: 0.3462 - accuracy: 0.8446 - auc: 0.9257
#
# Epoch 00446: loss did not improve from 0.34373
# Epoch 447/2000
# 1092/1092 [==============================] - 8s 7ms/step - loss: 0.3425 - accuracy: 0.8470 - auc: 0.9273
#
# Epoch 00447: loss did not improve from 0.34373
# Epoch 448/2000
# 1092/1092 [==============================] - 8s 7ms/step - loss: 0.3452 - accuracy: 0.8453 - auc: 0.9261
#
# Epoch 00448: loss did not improve from 0.34373
# Epoch 449/2000
# 1092/1092 [==============================] - 8s 7ms/step - loss: 0.3414 - accuracy: 0.8472 - auc: 0.9278
#
# Epoch 00449: loss did not improve from 0.34373
# Epoch 450/2000
# 1092/1092 [==============================] - 8s 7ms/step - loss: 0.3442 - accuracy: 0.8457 - auc: 0.9266
#
# Epoch 00450: loss did not improve from 0.34373
# Epoch 451/2000
# 1092/1092 [==============================] - 8s 8ms/step - loss: 0.3431 - accuracy: 0.8467 - auc: 0.9271
#
# Epoch 00451: loss did not improve from 0.34373
# Epoch 452/2000
# 1092/1092 [==============================] - 8s 8ms/step - loss: 0.3460 - accuracy: 0.8452 - auc: 0.9258
#
# Epoch 00452: loss did not improve from 0.34373
# Epoch 453/2000
# 1092/1092 [==============================] - 8s 8ms/step - loss: 0.3436 - accuracy: 0.8460 - auc: 0.9268
#
# Epoch 00453: loss did not improve from 0.34373
# Epoch 454/2000
# 1092/1092 [==============================] - 8s 8ms/step - loss: 0.3440 - accuracy: 0.8470 - auc: 0.9267
#
# Epoch 00454: loss improved from 0.34373 to 0.34354, saving model to /content/gdrive/My Drive/it3011_project/results_nndl/checkpoints/Best Model - MLP2.hdf5
# Epoch 455/2000
# 1092/1092 [==============================] - 9s 8ms/step - loss: 0.3415 - accuracy: 0.8467 - auc: 0.9277
#
# Epoch 00455: loss improved from 0.34354 to 0.34328, saving model to /content/gdrive/My Drive/it3011_project/results_nndl/checkpoints/Best Model - MLP2.hdf5
# Epoch 456/2000
# 1092/1092 [==============================] - 8s 8ms/step - loss: 0.3431 - accuracy: 0.8473 - auc: 0.9270
#
# Epoch 00456: loss did not improve from 0.34328
# Epoch 457/2000
# 1092/1092 [==============================] - 8s 8ms/step - loss: 0.3413 - accuracy: 0.8484 - auc: 0.9279
#
# Epoch 00457: loss improved from 0.34328 to 0.34323, saving model to /content/gdrive/My Drive/it3011_project/results_nndl/checkpoints/Best Model - MLP2.hdf5
# Epoch 458/2000
# ...
#
# Epoch 01376: loss did not improve from 0.30649
# Epoch 1377/2000
# 1092/1092 [==============================] - 10s 9ms/step - loss: 0.3042 - accuracy: 0.8674 - auc: 0.9432
#
# Epoch 01377: loss improved from 0.30649 to 0.30601, saving model to /content/gdrive/My Drive/it3011_project/results_nndl/checkpoints/Best Model - MLP2.hdf5
# Epoch 1378/2000
# 1092/1092 [==============================] - 10s 9ms/step - loss: 0.3049 - accuracy: 0.8683 - auc: 0.9429
#
# Epoch 01378: loss did not improve from 0.30601
# Epoch 1379/2000
# 1092/1092 [==============================] - 10s 9ms/step - loss: 0.3070 - accuracy: 0.8661 - auc: 0.9421
#
# Epoch 01379: loss did not improve from 0.30601
# Epoch 1380/2000
# 1092/1092 [==============================] - 10s 9ms/step - loss: 0.3060 - accuracy: 0.8666 - auc: 0.9425
#
# Epoch 01380: loss did not improve from 0.30601
# Epoch 1381/2000
# 1092/1092 [==============================] - 10s 9ms/step - loss: 0.3089 - accuracy: 0.8649 - auc: 0.9414
#
# Epoch 01381: loss did not improve from 0.30601
# Epoch 1382/2000
# 1092/1092 [==============================] - 10s 9ms/step - loss: 0.3071 - accuracy: 0.8649 - auc: 0.9421
#
# Epoch 01382: loss did not improve from 0.30601
# Epoch 1383/2000
# 1092/1092 [==============================] - 10s 9ms/step - loss: 0.3054 - accuracy: 0.8669 - auc: 0.9427
#
# Epoch 01383: loss did not improve from 0.30601
# Epoch 1384/2000
# 1092/1092 [==============================] - 10s 9ms/step - loss: 0.3088 - accuracy: 0.8656 - auc: 0.9415
#
# Epoch 01384: loss did not improve from 0.30601
# Epoch 1385/2000
# 1092/1092 [==============================] - 10s 9ms/step - loss: 0.3086 - accuracy: 0.8653 - auc: 0.9415
#
# Epoch 01385: loss did not improve from 0.30601
# Epoch 1386/2000
# 1092/1092 [==============================] - 10s 9ms/step - loss: 0.3075 - accuracy: 0.8654 - auc: 0.9419
#
# Epoch 01386: loss did not improve from 0.30601
# Epoch 1387/2000
# 1092/1092 [==============================] - 10s 9ms/step - loss: 0.3056 - accuracy: 0.8663 - auc: 0.9427
#
# Epoch 01387: loss did not improve from 0.30601
# Epoch 1388/2000
# 1092/1092 [==============================] - 10s 9ms/step - loss: 0.3091 - accuracy: 0.8647 - auc: 0.9413
#
# Epoch 01388: loss did not improve from 0.30601
# Epoch 1389/2000
# 1092/1092 [==============================] - 10s 9ms/step - loss: 0.3063 - accuracy: 0.8665 - auc: 0.9424
#
# Epoch 01389: loss did not improve from 0.30601
# Epoch 1390/2000
# 1092/1092 [==============================] - 10s 9ms/step - loss: 0.3055 - accuracy: 0.8663 - auc: 0.9427
#
# Epoch 01390: loss did not improve from 0.30601
# Epoch 1391/2000
# 1092/1092 [==============================] - 10s 9ms/step - loss: 0.3073 - accuracy: 0.8659 - auc: 0.9420
#
# Epoch 01391: loss did not improve from 0.30601
# Epoch 1392/2000
# 1092/1092 [==============================] - 10s 9ms/step - loss: 0.3079 - accuracy: 0.8661 - auc: 0.9418
#
# Epoch 01392: loss did not improve from 0.30601
# Epoch 1393/2000
# 1092/1092 [==============================] - 10s 9ms/step - loss: 0.3060 - accuracy: 0.8664 - auc: 0.9425
#
# Epoch 01393: loss did not improve from 0.30601
# Epoch 1394/2000
# 1092/1092 [==============================] - 10s 9ms/step - loss: 0.3073 - accuracy: 0.8658 - auc: 0.9420
#
# Epoch 01394: loss did not improve from 0.30601
# Epoch 1395/2000
# 1092/1092 [==============================] - 10s 9ms/step - loss: 0.3035 - accuracy: 0.8674 - auc: 0.9435
#
# Epoch 01395: loss improved from 0.30601 to 0.30465, saving model to /content/gdrive/My Drive/it3011_project/results_nndl/checkpoints/Best Model - MLP2.hdf5
# Epoch 1396/2000
# 1092/1092 [==============================] - 10s 9ms/step - loss: 0.3068 - accuracy: 0.8658 - auc: 0.9422
#
# Epoch 01396: loss did not improve from 0.30465
# Epoch 1397/2000
# 1092/1092 [==============================] - 10s 9ms/step - loss: 0.3093 - accuracy: 0.8648 - auc: 0.9413
#
# Epoch 01397: loss did not improve from 0.30465
# Epoch 1398/2000
# 1092/1092 [==============================] - 10s 9ms/step - loss: 0.3055 - accuracy: 0.8667 - auc: 0.9427
#
# Epoch 01398: loss did not improve from 0.30465
# Epoch 1399/2000
# 1092/1092 [==============================] - 10s 9ms/step - loss: 0.3047 - accuracy: 0.8687 - auc: 0.9430
#
# Epoch 01399: loss did not improve from 0.30465
# Epoch 1400/2000
# 1092/1092 [==============================] - 10s 9ms/step - loss: 0.3074 - accuracy: 0.8661 - auc: 0.9420
#
# Epoch 01400: loss did not improve from 0.30465
# Epoch 1401/2000
# 1092/1092 [==============================] - 10s 9ms/step - loss: 0.3049 - accuracy: 0.8667 - auc: 0.9429
#
# Epoch 01401: loss did not improve from 0.30465
# Epoch 1402/2000
# 1092/1092 [==============================] - 10s 9ms/step - loss: 0.3071 - accuracy: 0.8656 - auc: 0.9421
#
# Epoch 01402: loss did not improve from 0.30465
# Epoch 1403/2000
# 1092/1092 [==============================] - 10s 9ms/step - loss: 0.3063 - accuracy: 0.8657 - auc: 0.9424
#
# Epoch 01403: loss did not improve from 0.30465
# Epoch 1404/2000
# 1092/1092 [==============================] - 10s 9ms/step - loss: 0.3057 - accuracy: 0.8669 - auc: 0.9427
#
# Epoch 01404: loss did not improve from 0.30465
# Epoch 1405/2000
# 1092/1092 [==============================] - 10s 9ms/step - loss: 0.3055 - accuracy: 0.8679 - auc: 0.9427
#
# Epoch 01405: loss did not improve from 0.30465
# Epoch 1406/2000
# 1092/1092 [==============================] - 10s 9ms/step - loss: 0.3042 - accuracy: 0.8671 - auc: 0.9432
#
# Epoch 01406: loss did not improve from 0.30465
# Epoch 1407/2000
# 1092/1092 [==============================] - 10s 9ms/step - loss: 0.3037 - accuracy: 0.8682 - auc: 0.9435
#
# Epoch 01407: loss did not improve from 0.30465
# Epoch 1408/2000
# 1092/1092 [==============================] - 10s 9ms/step - loss: 0.3054 - accuracy: 0.8667 - auc: 0.9428
#
# Epoch 01408: loss did not improve from 0.30465
# Epoch 1409/2000
# 1092/1092 [==============================] - 10s 9ms/step - loss: 0.3057 - accuracy: 0.8665 - auc: 0.9426
#
# Epoch 01409: loss did not improve from 0.30465
# Epoch 1410/2000
# 1092/1092 [==============================] - 10s 9ms/step - loss: 0.3073 - accuracy: 0.8657 - auc: 0.9420
#
# Epoch 01410: loss did not improve from 0.30465
# Epoch 1411/2000
# 1092/1092 [==============================] - 10s 9ms/step - loss: 0.3069 - accuracy: 0.8668 - auc: 0.9422
#
# Epoch 01411: loss did not improve from 0.30465
# Epoch 1412/2000
# 1092/1092 [==============================] - 10s 9ms/step - loss: 0.3069 - accuracy: 0.8658 - auc: 0.9422
#
# Epoch 01412: loss did not improve from 0.30465
# Epoch 1413/2000
# 1092/1092 [==============================] - 10s 9ms/step - loss: 0.3082 - accuracy: 0.8651 - auc: 0.9416
#
# Epoch 01413: loss did not improve from 0.30465
# Epoch 1414/2000
# 1092/1092 [==============================] - 10s 9ms/step - loss: 0.3070 - accuracy: 0.8659 - auc: 0.9421
#
# Epoch 01414: loss did not improve from 0.30465
# Epoch 1415/2000
# 1092/1092 [==============================] - 10s 9ms/step - loss: 0.3066 - accuracy: 0.8658 - auc: 0.9422
#
# Epoch 01415: loss did not improve from 0.30465
# Epoch 1416/2000
# 1092/1092 [==============================] - 10s 9ms/step - loss: 0.3063 - accuracy: 0.8654 - auc: 0.9424
#
# Epoch 01416: loss did not improve from 0.30465
# Epoch 1417/2000
# 1092/1092 [==============================] - 10s 9ms/step - loss: 0.3040 - accuracy: 0.8674 - auc: 0.9433
#
# Epoch 01417: loss did not improve from 0.30465
# Epoch 1418/2000
# 1092/1092 [==============================] - 10s 9ms/step - loss: 0.3071 - accuracy: 0.8661 - auc: 0.9421
#
# Epoch 01418: loss did not improve from 0.30465
# Epoch 1419/2000
# 1092/1092 [==============================] - 10s 9ms/step - loss: 0.3053 - accuracy: 0.8670 - auc: 0.9428
#
# Epoch 01419: loss did not improve from 0.30465
# Epoch 1420/2000
# 1092/1092 [==============================] - 10s 9ms/step - loss: 0.3066 - accuracy: 0.8664 - auc: 0.9423
#
# Epoch 01420: loss did not improve from 0.30465
# Epoch 1421/2000
# 1092/1092 [==============================] - 10s 9ms/step - loss: 0.3063 - accuracy: 0.8661 - auc: 0.9424
#
# Epoch 01421: loss did not improve from 0.30465
# Epoch 1422/2000
# 1092/1092 [==============================] - 10s 9ms/step - loss: 0.3050 - accuracy: 0.8681 - auc: 0.9429
#
# Epoch 01422: loss did not improve from 0.30465
# Epoch 1423/2000
# 1092/1092 [==============================] - 10s 9ms/step - loss: 0.3042 - accuracy: 0.8663 - auc: 0.9432
#
# Epoch 01423: loss did not improve from 0.30465
# Epoch 1424/2000
# 1092/1092 [==============================] - 10s 9ms/step - loss: 0.3068 - accuracy: 0.8657 - auc: 0.9422
#
# Epoch 01424: loss did not improve from 0.30465
# Epoch 1425/2000
# 1092/1092 [==============================] - 10s 9ms/step - loss: 0.3049 - accuracy: 0.8670 - auc: 0.9430
#
# Epoch 01425: loss did not improve from 0.30465
# Epoch 1426/2000
# 1092/1092 [==============================] - 10s 9ms/step - loss: 0.3054 - accuracy: 0.8669 - auc: 0.9427
#
# Epoch 01426: loss did not improve from 0.30465
# Epoch 1427/2000
# 1092/1092 [==============================] - 10s 9ms/step - loss: 0.3062 - accuracy: 0.8663 - auc: 0.9425
#
# Epoch 01427: loss did not improve from 0.30465
# Epoch 1428/2000
# 1092/1092 [==============================] - 10s 9ms/step - loss: 0.3084 - accuracy: 0.8649 - auc: 0.9416
#
# Epoch 01428: loss did not improve from 0.30465
# Epoch 1429/2000
# 1092/1092 [==============================] - 10s 9ms/step - loss: 0.3064 - accuracy: 0.8671 - auc: 0.9424
#
# Epoch 01429: loss did not improve from 0.30465
# Epoch 1430/2000
# 1092/1092 [==============================] - 10s 9ms/step - loss: 0.3067 - accuracy: 0.8663 - auc: 0.9422
#
# Epoch 01430: loss did not improve from 0.30465
# Epoch 1431/2000
# 1092/1092 [==============================] - 10s 9ms/step - loss: 0.3039 - accuracy: 0.8678 - auc: 0.9433
#
# Epoch 01431: loss did not improve from 0.30465
# Epoch 1432/2000
# 1092/1092 [==============================] - 10s 9ms/step - loss: 0.3046 - accuracy: 0.8667 - auc: 0.9431
#
# Epoch 01432: loss did not improve from 0.30465
# Epoch 1433/2000
# 1092/1092 [==============================] - 10s 9ms/step - loss: 0.3046 - accuracy: 0.8667 - auc: 0.9430
#
# Epoch 01433: loss did not improve from 0.30465
# Epoch 1434/2000
# 1092/1092 [==============================] - 10s 9ms/step - loss: 0.3065 - accuracy: 0.8667 - auc: 0.9423
#
# Epoch 01434: loss did not improve from 0.30465
# Epoch 1435/2000
# 1092/1092 [==============================] - 10s 9ms/step - loss: 0.3053 - accuracy: 0.8674 - auc: 0.9428
#
# Epoch 01435: loss did not improve from 0.30465
# Epoch 1436/2000
# 1092/1092 [==============================] - 10s 9ms/step - loss: 0.3076 - accuracy: 0.8658 - auc: 0.9419
#
# Epoch 01436: loss did not improve from 0.30465
# Epoch 1437/2000
# 1092/1092 [==============================] - 10s 9ms/step - loss: 0.3058 - accuracy: 0.8663 - auc: 0.9426
#
# Epoch 01437: loss did not improve from 0.30465
# Epoch 1438/2000
# 1092/1092 [==============================] - 10s 9ms/step - loss: 0.3059 - accuracy: 0.8668 - auc: 0.9426
#
# Epoch 01438: loss did not improve from 0.30465
# Epoch 1439/2000
# 1092/1092 [==============================] - 10s 9ms/step - loss: 0.3082 - accuracy: 0.8653 - auc: 0.9416
#
# Epoch 01439: loss did not improve from 0.30465
# Epoch 1440/2000
# 1092/1092 [==============================] - 10s 9ms/step - loss: 0.3073 - accuracy: 0.8658 - auc: 0.9420
#
# Epoch 01440: loss did not improve from 0.30465
# Epoch 1441/2000
# 1092/1092 [==============================] - 10s 9ms/step - loss: 0.3051 - accuracy: 0.8672 - auc: 0.9429
#
# Epoch 01441: loss did not improve from 0.30465
# Epoch 1442/2000
# 1092/1092 [==============================] - 10s 9ms/step - loss: 0.3066 - accuracy: 0.8670 - auc: 0.9423
#
# Epoch 01442: loss did not improve from 0.30465
# Epoch 1443/2000
# 1092/1092 [==============================] - 10s 9ms/step - loss: 0.3041 - accuracy: 0.8678 - auc: 0.9433
#
# Epoch 01443: loss did not improve from 0.30465
# Epoch 1444/2000
# 1092/1092 [==============================] - 10s 9ms/step - loss: 0.3063 - accuracy: 0.8664 - auc: 0.9424
#
# Epoch 01444: loss did not improve from 0.30465
# Epoch 1445/2000
# 1092/1092 [==============================] - 10s 9ms/step - loss: 0.3053 - accuracy: 0.8665 - auc: 0.9428
#
# Epoch 01445: loss did not improve from 0.30465
# Epoch 1446/2000
# 1092/1092 [==============================] - 10s 9ms/step - loss: 0.3066 - accuracy: 0.8667 - auc: 0.9423
#
# Epoch 01446: loss did not improve from 0.30465
# Epoch 1447/2000
# 1092/1092 [==============================] - 10s 9ms/step - loss: 0.3059 - accuracy: 0.8671 - auc: 0.9425
#
# Epoch 01447: loss did not improve from 0.30465
# Epoch 1448/2000
# 1092/1092 [==============================] - 10s 9ms/step - loss: 0.3043 - accuracy: 0.8676 - auc: 0.9432
#
# Epoch 01448: loss did not improve from 0.30465
# Epoch 1449/2000
# 1092/1092 [==============================] - 10s 9ms/step - loss: 0.3047 - accuracy: 0.8666 - auc: 0.9430
#
# Epoch 01449: loss did not improve from 0.30465
# Epoch 1450/2000
# 1092/1092 [==============================] - 10s 9ms/step - loss: 0.3036 - accuracy: 0.8683 - auc: 0.9434
#
# Epoch 01450: loss did not improve from 0.30465
# Epoch 1451/2000
# 1092/1092 [==============================] - 10s 9ms/step - loss: 0.3062 - accuracy: 0.8668 - auc: 0.9424
#
# Epoch 01451: loss did not improve from 0.30465
# Epoch 1452/2000
# 1092/1092 [==============================] - 10s 9ms/step - loss: 0.3035 - accuracy: 0.8674 - auc: 0.9435
#
# Epoch 01452: loss did not improve from 0.30465
# Epoch 1453/2000
# 1092/1092 [==============================] - 10s 9ms/step - loss: 0.3057 - accuracy: 0.8666 - auc: 0.9426
#
# Epoch 01453: loss did not improve from 0.30465
# Epoch 1454/2000
# 1092/1092 [==============================] - 10s 9ms/step - loss: 0.3046 - accuracy: 0.8682 - auc: 0.9431
#
# Epoch 01454: loss did not improve from 0.30465
# Epoch 1455/2000
# 1092/1092 [==============================] - 10s 9ms/step - loss: 0.3045 - accuracy: 0.8662 - auc: 0.9431
#
# Epoch 01455: loss did not improve from 0.30465
# Epoch 1456/2000
# 1092/1092 [==============================] - 10s 9ms/step - loss: 0.3057 - accuracy: 0.8675 - auc: 0.9426
#
# Epoch 01456: loss did not improve from 0.30465
# Epoch 1457/2000
# 1092/1092 [==============================] - 10s 9ms/step - loss: 0.3050 - accuracy: 0.8677 - auc: 0.9429
#
# Epoch 01457: loss did not improve from 0.30465
# Epoch 1458/2000
# 1092/1092 [==============================] - 10s 9ms/step - loss: 0.3044 - accuracy: 0.8678 - auc: 0.9431
#
# Epoch 01458: loss improved from 0.30465 to 0.30454, saving model to /content/gdrive/My Drive/it3011_project/results_nndl/checkpoints/Best Model - MLP2.hdf5
# Epoch 1459/2000
# 1092/1092 [==============================] - 10s 9ms/step - loss: 0.3049 - accuracy: 0.8662 - auc: 0.9429
#
# Epoch 01459: loss did not improve from 0.30454
# Epoch 1460/2000
# 1092/1092 [==============================] - 10s 9ms/step - loss: 0.3023 - accuracy: 0.8696 - auc: 0.9440
#
# Epoch 01460: loss did not improve from 0.30454
# Epoch 1461/2000
# 1092/1092 [==============================] - 10s 9ms/step - loss: 0.3058 - accuracy: 0.8662 - auc: 0.9426
#
# Epoch 01461: loss did not improve from 0.30454
# Epoch 1462/2000
# 1092/1092 [==============================] - 10s 9ms/step - loss: 0.3054 - accuracy: 0.8673 - auc: 0.9427
#
# Epoch 01462: loss did not improve from 0.30454
# Epoch 1463/2000
# 1092/1092 [==============================] - 10s 9ms/step - loss: 0.3037 - accuracy: 0.8674 - auc: 0.9434
#
# Epoch 01463: loss did not improve from 0.30454
# Epoch 1464/2000
# 1092/1092 [==============================] - 10s 9ms/step - loss: 0.3048 - accuracy: 0.8674 - auc: 0.9430
#
# Epoch 01464: loss improved from 0.30454 to 0.30382, saving model to /content/gdrive/My Drive/it3011_project/results_nndl/checkpoints/Best Model - MLP2.hdf5
# Epoch 1465/2000
# 1092/1092 [==============================] - 10s 9ms/step - loss: 0.3045 - accuracy: 0.8667 - auc: 0.9431
#
# Epoch 01465: loss did not improve from 0.30382
# Epoch 1466/2000
# 1092/1092 [==============================] - 10s 9ms/step - loss: 0.3077 - accuracy: 0.8665 - auc: 0.9419
#
# Epoch 01466: loss did not improve from 0.30382
# Epoch 1467/2000
#  264/1092 [======>.......................] - ETA: 7s - loss: 0.3026 - accuracy: 0.8675 - auc: 0.9438

# %%
# '''
# predict on the test set. load best weights from checkpoints
# '''
# # model.load_weights(str(PATH_CHECKPOINTS / (model_name + '.hdf5')))

# test_metrics = model.evaluate(x_test, steps=3)

# test_metrics_dict = {
#     'test_loss': test_metrics[0]
# }

# np.save(PATH_PREDICTIONS/str(model_name + "_prediction_score"), test_metrics_dict)

# %%
# y_pred = (model.predict(x_test) > 0.5).astype(int)
# utility_score(test, y_pred)

# %% [markdown]
# # Conclusion
