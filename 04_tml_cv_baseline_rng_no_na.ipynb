# %% [markdown]
# # 04_tml_cv_baseline_rng_no_na
#
# We will use the train/test data generated from *04_create_dataset_no_na.ipynb* and use basic machine learning models to generate a baseline reference of model performance on our data. We will then decide on how to improve the various models after this

# %%
''' data and math '''
import pandas as pd
import numpy as np

''' plotting images '''
from matplotlib import pyplot as plt
# %matplotlib inline

''' traversing directories '''
import os
from pathlib import Path

''' utilities '''
from tqdm import tqdm

''' metrics '''
from sklearn.metrics import accuracy_score
from sklearn.metrics import confusion_matrix
from sklearn.metrics import roc_auc_score
from sklearn.metrics import roc_curve

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
''' used to reference the root directory, for directory traversal ''' 
from google.colab import drive
drive.mount('/content/gdrive', force_remount=True)
mount_dir = '/content/gdrive'
root_dir = Path('/content/gdrive/My Drive/it3011_project')
# Out:
# Mounted at /content/gdrive

# %% [markdown]
# # Loading data

# %%
# load data
train = pd.read_csv(root_dir/"data/train_no_na.csv")
test = pd.read_csv(root_dir/"data/test_no_na.csv")
print("data loaded")
# Out:
# data loaded

# %%
# check shape
print(train.shape)
print(test.shape)
# Out:
# (279331, 138)
# (120163, 138)

# %%
# create train/test sets
features = [feature for feature in test.keys() if "feature" in feature]
x_train = train.loc[:, features].values
y_train = train.loc[:,['action']].values.flatten()
x_test = test.loc[:, features].values
y_test = test.loc[:,['action']].values.flatten()
print("train/test set created")
# Out:
# train/test set created

# %%
# scaling data to make it easier for models to train
from sklearn.preprocessing import StandardScaler

scaler = StandardScaler().fit(x_train)
x_train = scaler.transform(x_train)

# test set scaled on the same scaler as train, because models are fitted on the train distributions and not test distributions
x_test = scaler.transform(x_test)

# %% [markdown]
# # Helper functions

# %%
# constants
SEED = 42

# cross validation
from sklearn.model_selection import KFold
kf = KFold(n_splits=10, random_state=SEED, shuffle=True)

# %%
# create the utility score, which takes in the prediction value and the ground truth action and generates a score
# link: https://www.kaggle.com/c/jane-street-market-prediction/overview/evaluation

# data: original train/test data    action: the y-value. can either be y_pred or original values too, if we want the max score attainable
def utility_score(data, action): 
  dates_set = set(data.date.values)
  dates = data.loc[:, ['date']].values.flatten()
  weights = data.loc[:, ['weight']].values.flatten()
  resps = data.loc[:, ['resp']].values.flatten()
  actions = action.flatten()

  i = len(dates_set)
  p_i = []

  for date in dates_set:
    indices = np.where(dates == date)[0]
    p_i_temp = 0
    for j in indices:
      p_i_temp = p_i_temp + weights[j] * resps[j] * actions[j]
    p_i.append(p_i_temp)
  
  p_i_squared = [p_i1*p_i2 for p_i1,p_i2 in zip(p_i,p_i)]
  t = ( sum(p_i) / np.sqrt(sum(p_i_squared)) ) * np.sqrt(250/i)
  u = min(max(t, 0), 6) * sum(p_i)

  return u

def max_train_utility_score(data=train, action=y_train):
  return utility_score(data, action)

def max_test_utility_score(data=test, action=y_test):
  return utility_score(data, action)

# %%
def model_scores(model, test, x_test, y_test):
  y_pred = model.predict(x_test) 
  
  # # get some scores from helpers
  utility = utility_score(test, y_pred)
  accuracy =  accuracy_score(y_test, y_pred)

  # # confusion matrix
  # print("confusion matrix")
  cm = confusion_matrix(y_test, y_pred)
  true_pos = cm[1][1]
  true_neg = cm[0][0]
  false_pos = cm[0][1]
  false_neg = cm[1][0]

  # # plot confusion matrix
  # fig, ax = plt.subplots(figsize=(3, 3))
  # ax.imshow(cm)
  # ax.grid(False)
  # ax.xaxis.set(ticks=(0, 1), ticklabels=('Predicted 0s', 'Predicted 1s'))
  # ax.yaxis.set(ticks=(0, 1), ticklabels=('Actual 0s', 'Actual 1s'))
  # ax.set_ylim(1.5, -0.5)
  # for i in range(2):
  #     for j in range(2):
  #         ax.text(j, i, cm[i, j], ha='center', va='center', color='red')
  # plt.show()  

  # # AUC-ROC
  # print("AUC_ROC")
  logit_roc_auc = roc_auc_score(y_test, model.predict(x_test))

  # # plot auc-roc
  # fpr, tpr, thresholds = roc_curve(y_test, model.predict_proba(x_test)[:,1])
  # plt.figure()
  # plt.plot(fpr, tpr, label='Logistic Regression (area = %0.2f)' % logit_roc_auc)
  # plt.plot([0, 1], [0, 1],'r--')
  # plt.xlim([0.0, 1.0])
  # plt.ylim([0.0, 1.05])
  # plt.xlabel('False Positive Rate')
  # plt.ylabel('True Positive Rate')
  # plt.title('Receiver operating characteristic')
  # plt.legend(loc="lower right")
  # plt.show()

  return utility, accuracy, logit_roc_auc, true_pos, true_neg, false_pos, false_neg

# %%
import datetime
import csv

def save_scores(output_filename, workbook_name, model_name, model_params, utility, accuracy, true_pos, true_neg, false_pos, false_neg, logit_roc_auc):
  # create output file if not exists
  try:
    f = open(root_dir/output_filename)
  except IOError:
    with open (root_dir/output_filename, 'a') as csvfile:
      headers = ["workbook_name", "model_name", "model_params", "utility", "accuracy", "logit_roc_auc", "true_pos", "true_neg", "false_pos", "false_neg", "timestamp"]
      writer = csv.DictWriter(csvfile, delimiter=',', lineterminator='\n',fieldnames=headers)
      writer.writeheader() 
      print("created output file")  
    csvfile.close()

  # output file exists, append
  timestamp = datetime.datetime.now().strftime("%d/%m/%Y %H:%M:%S")
  
  ''' create another df that looks just like the excel file and concat with ''' 
  new_scores = pd.DataFrame(np.array([[workbook_name, model_name, model_params, utility, accuracy, logit_roc_auc, true_pos, true_neg, false_pos, false_neg, timestamp]]),
                   columns=["workbook_name", "model_name", "model_params", "utility", "accuracy", "logit_roc_auc", "true_pos", "true_neg", "false_pos", "false_neg", "timestamp"],
                  )

  new_scores.to_csv(root_dir/output_filename, mode='a', header=False, index=False)
  print("saved model metrics")

# %% [markdown]
# # RNG model
# We just want to have a baseline to ensure our models are not worse than randomly generated predictions

# %%
# iterate over settings for the model
all_cv_scores = []

output_filename = "CV_SCORES_AVE.csv"
workbook_name = "04_tml_cv_baseline_rng_no_na"
model_name = "RNG model"
model_params = f"random"

print("")
print("model_name: ", model_name)
print("model_params: ", model_params)

for i in range(50):      
  print(f"random iteration = {i+1}")
  # cross validation
  cv_scores = []

  for i, (train_idx, val_idx) in enumerate(kf.split(x_train)):
    # train-val data (for utility score calculation) 
    train_cv, val_cv = train.iloc[train_idx], train.iloc[val_idx]
    # train-val features 
    x_train_cv, x_val_cv, y_train_cv, y_val_cv = x_train[train_idx], x_train[val_idx], y_train[train_idx], y_train[val_idx]

    print(f"training model fold {i+1}")
    y_pred = np.random.randint(2, size=y_val_cv.shape[0])
    
    utility = utility_score(val_cv, y_pred)
    accuracy = accuracy_score(y_val_cv, y_pred)
    cv_scores.append((utility, accuracy))
  
  # mean of cv scores
  cv_scores_ave = [sum(ele) / len(cv_scores) for ele in zip(*cv_scores)]
  print("cv_scores key: utility, accuracy")
  print("cv_scores_ave: ", cv_scores_ave)
  all_cv_scores.append(cv_scores_ave)

all_cv_scores_ave = [sum(ele) / len(all_cv_scores) for ele in zip(*all_cv_scores)]
filler_scores = [None]*5
all_cv_scores_ave += filler_scores
print("all_cv_scores key: utility, accuracy, logit_roc_auc, true_pos, true_neg, false_pos, false_neg")
print("all_cv_scores_ave: ", all_cv_scores_ave)

# save average scores
save_scores(output_filename, workbook_name, model_name, model_params, *all_cv_scores_ave)
# Out:
# model_name:  RNG model
# model_params:  random
# random iteration = 1
# training model fold 1
# training model fold 2
# training model fold 3
# training model fold 4
# training model fold 5
# training model fold 6
# training model fold 7
# training model fold 8
# training model fold 9
# training model fold 10
# cv_scores key: utility, accuracy
# cv_scores_ave:  [11.635987513245748, 0.5014373669624124]
# random iteration = 2
# training model fold 1
# training model fold 2
# training model fold 3
# training model fold 4
# training model fold 5
# training model fold 6
# training model fold 7
# training model fold 8
# training model fold 9
# training model fold 10
# cv_scores key: utility, accuracy
# cv_scores_ave:  [2.4228682647501616, 0.5003168389120495]
# random iteration = 3
# training model fold 1
# training model fold 2
# training model fold 3
# training model fold 4
# training model fold 5
# training model fold 6
# training model fold 7
# training model fold 8
# training model fold 9
# training model fold 10
# cv_scores key: utility, accuracy
# cv_scores_ave:  [14.311780957158788, 0.5001592997805602]
# random iteration = 4
# training model fold 1
# training model fold 2
# training model fold 3
# training model fold 4
# training model fold 5
# training model fold 6
# training model fold 7
# training model fold 8
# training model fold 9
# training model fold 10
# cv_scores key: utility, accuracy
# cv_scores_ave:  [13.928588010579205, 0.49933949733266536]
# random iteration = 5
# training model fold 1
# training model fold 2
# training model fold 3
# training model fold 4
# training model fold 5
# training model fold 6
# training model fold 7
# training model fold 8
# training model fold 9
# training model fold 10
# cv_scores key: utility, accuracy
# cv_scores_ave:  [14.694007170101543, 0.5010793770755406]
# random iteration = 6
# training model fold 1
# training model fold 2
# training model fold 3
# training model fold 4
# training model fold 5
# training model fold 6
# training model fold 7
# training model fold 8
# training model fold 9
# training model fold 10
# cv_scores key: utility, accuracy
# cv_scores_ave:  [6.802145787154797, 0.5000984585769859]
# random iteration = 7
# training model fold 1
# training model fold 2
# training model fold 3
# training model fold 4
# training model fold 5
# training model fold 6
# training model fold 7
# training model fold 8
# training model fold 9
# training model fold 10
# cv_scores key: utility, accuracy
# cv_scores_ave:  [6.813861908282919, 0.4995471379390832]
# random iteration = 8
# training model fold 1
# training model fold 2
# training model fold 3
# training model fold 4
# training model fold 5
# training model fold 6
# training model fold 7
# training model fold 8
# training model fold 9
# training model fold 10
# cv_scores key: utility, accuracy
# cv_scores_ave:  [14.92553393568269, 0.49922133532654495]
# random iteration = 9
# training model fold 1
# training model fold 2
# training model fold 3
# training model fold 4
# training model fold 5
# training model fold 6
# training model fold 7
# training model fold 8
# training model fold 9
# training model fold 10
# cv_scores key: utility, accuracy
# cv_scores_ave:  [6.784468219199508, 0.49998747373415453]
# random iteration = 10
# training model fold 1
# training model fold 2
# training model fold 3
# training model fold 4
# training model fold 5
# training model fold 6
# training model fold 7
# training model fold 8
# training model fold 9
# training model fold 10
# cv_scores key: utility, accuracy
# cv_scores_ave:  [3.7292022018179423, 0.5002058403561995]
# random iteration = 11
# training model fold 1
# training model fold 2
# training model fold 3
# training model fold 4
# training model fold 5
# training model fold 6
# training model fold 7
# training model fold 8
# training model fold 9
# training model fold 10
# cv_scores key: utility, accuracy
# cv_scores_ave:  [3.8978800935416977, 0.4994254234921712]
# random iteration = 12
# training model fold 1
# training model fold 2
# training model fold 3
# training model fold 4
# training model fold 5
# training model fold 6
# training model fold 7
# training model fold 8
# training model fold 9
# training model fold 10
# cv_scores key: utility, accuracy
# cv_scores_ave:  [9.709233172679113, 0.5004994140427119]
# random iteration = 13
# training model fold 1
# training model fold 2
# training model fold 3
# training model fold 4
# training model fold 5
# training model fold 6
# training model fold 7
# training model fold 8
# training model fold 9
# training model fold 10
# cv_scores key: utility, accuracy
# cv_scores_ave:  [4.708378449740396, 0.4994934241730852]
# random iteration = 14
# training model fold 1
# training model fold 2
# training model fold 3
# training model fold 4
# training model fold 5
# training model fold 6
# training model fold 7
# training model fold 8
# training model fold 9
# training model fold 10
# cv_scores key: utility, accuracy
# cv_scores_ave:  [5.823806270075779, 0.4994039503146729]
# random iteration = 15
# training model fold 1
# training model fold 2
# training model fold 3
# training model fold 4
# training model fold 5
# training model fold 6
# training model fold 7
# training model fold 8
# training model fold 9
# training model fold 10
# cv_scores key: utility, accuracy
# cv_scores_ave:  [19.68198492943168, 0.5008251789764885]
# random iteration = 16
# training model fold 1
# training model fold 2
# training model fold 3
# training model fold 4
# training model fold 5
# training model fold 6
# training model fold 7
# training model fold 8
# training model fold 9
# training model fold 10
# cv_scores key: utility, accuracy
# cv_scores_ave:  [7.0374387770258355, 0.4994039460854241]
# random iteration = 17
# training model fold 1
# training model fold 2
# training model fold 3
# training model fold 4
# training model fold 5
# training model fold 6
# training model fold 7
# training model fold 8
# training model fold 9
# training model fold 10
# cv_scores key: utility, accuracy
# cv_scores_ave:  [31.655777990934695, 0.5010507340398195]
# random iteration = 18
# training model fold 1
# training model fold 2
# training model fold 3
# training model fold 4
# training model fold 5
# training model fold 6
# training model fold 7
# training model fold 8
# training model fold 9
# training model fold 10
# cv_scores key: utility, accuracy
# cv_scores_ave:  [5.8527014129925155, 0.49865572841452116]
# random iteration = 19
# training model fold 1
# training model fold 2
# training model fold 3
# training model fold 4
# training model fold 5
# training model fold 6
# training model fold 7
# training model fold 8
# training model fold 9
# training model fold 10
# cv_scores key: utility, accuracy
# cv_scores_ave:  [17.298757565977343, 0.5008466689428228]
# random iteration = 20
# training model fold 1
# training model fold 2
# training model fold 3
# training model fold 4
# training model fold 5
# training model fold 6
# training model fold 7
# training model fold 8
# training model fold 9
# training model fold 10
# cv_scores key: utility, accuracy
# cv_scores_ave:  [6.4400777292664655, 0.49998746860779236]
# random iteration = 21
# training model fold 1
# training model fold 2
# training model fold 3
# training model fold 4
# training model fold 5
# training model fold 6
# training model fold 7
# training model fold 8
# training model fold 9
# training model fold 10
# cv_scores key: utility, accuracy
# cv_scores_ave:  [19.067972799414374, 0.4991926929316188]
# random iteration = 22
# training model fold 1
# training model fold 2
# training model fold 3
# training model fold 4
# training model fold 5
# training model fold 6
# training model fold 7
# training model fold 8
# training model fold 9
# training model fold 10
# cv_scores key: utility, accuracy
# cv_scores_ave:  [3.6262053774964484, 0.5006354400110784]
# random iteration = 23
# training model fold 1
# training model fold 2
# training model fold 3
# training model fold 4
# training model fold 5
# training model fold 6
# training model fold 7
# training model fold 8
# training model fold 9
# training model fold 10
# cv_scores key: utility, accuracy
# cv_scores_ave:  [8.026090684119495, 0.49911753149177435]
# random iteration = 24
# training model fold 1
# training model fold 2
# training model fold 3
# training model fold 4
# training model fold 5
# training model fold 6
# training model fold 7
# training model fold 8
# training model fold 9
# training model fold 10
# cv_scores key: utility, accuracy
# cv_scores_ave:  [25.44308429117482, 0.49824043912766536]
# random iteration = 25
# training model fold 1
# training model fold 2
# training model fold 3
# training model fold 4
# training model fold 5
# training model fold 6
# training model fold 7
# training model fold 8
# training model fold 9
# training model fold 10
# cv_scores key: utility, accuracy
# cv_scores_ave:  [5.224118373130112, 0.4999552598027379]
# random iteration = 26
# training model fold 1
# training model fold 2
# training model fold 3
# training model fold 4
# training model fold 5
# training model fold 6
# training model fold 7
# training model fold 8
# training model fold 9
# training model fold 10
# cv_scores key: utility, accuracy
# cv_scores_ave:  [4.651489875197276, 0.5006426016671222]
# random iteration = 27
# training model fold 1
# training model fold 2
# training model fold 3
# training model fold 4
# training model fold 5
# training model fold 6
# training model fold 7
# training model fold 8
# training model fold 9
# training model fold 10
# cv_scores key: utility, accuracy
# cv_scores_ave:  [12.551716411612121, 0.5004743484387976]
# random iteration = 28
# training model fold 1
# training model fold 2
# training model fold 3
# training model fold 4
# training model fold 5
# training model fold 6
# training model fold 7
# training model fold 8
# training model fold 9
# training model fold 10
# cv_scores key: utility, accuracy
# cv_scores_ave:  [4.314685094167805, 0.5002559695134835]
# random iteration = 29
# training model fold 1
# training model fold 2
# training model fold 3
# training model fold 4
# training model fold 5
# training model fold 6
# training model fold 7
# training model fold 8
# training model fold 9
# training model fold 10
# cv_scores key: utility, accuracy
# cv_scores_ave:  [9.447176515095723, 0.5020173328147404]
# random iteration = 30
# training model fold 1
# training model fold 2
# training model fold 3
# training model fold 4
# training model fold 5
# training model fold 6
# training model fold 7
# training model fold 8
# training model fold 9
# training model fold 10
# cv_scores key: utility, accuracy
# cv_scores_ave:  [8.622758256152716, 0.5000375790538546]
# random iteration = 31
# training model fold 1
# training model fold 2
# training model fold 3
# training model fold 4
# training model fold 5
# training model fold 6
# training model fold 7
# training model fold 8
# training model fold 9
# training model fold 10
# cv_scores key: utility, accuracy
# cv_scores_ave:  [7.2889355970390195, 0.49827980702558233]
# random iteration = 32
# training model fold 1
# training model fold 2
# training model fold 3
# training model fold 4
# training model fold 5
# training model fold 6
# training model fold 7
# training model fold 8
# training model fold 9
# training model fold 10
# cv_scores key: utility, accuracy
# cv_scores_ave:  [10.010637552596773, 0.5006103877357055]
# random iteration = 33
# training model fold 1
# training model fold 2
# training model fold 3
# training model fold 4
# training model fold 5
# training model fold 6
# training model fold 7
# training model fold 8
# training model fold 9
# training model fold 10
# cv_scores key: utility, accuracy
# cv_scores_ave:  [8.687656162434584, 0.49741705360896526]
# random iteration = 34
# training model fold 1
# training model fold 2
# training model fold 3
# training model fold 4
# training model fold 5
# training model fold 6
# training model fold 7
# training model fold 8
# training model fold 9
# training model fold 10
# cv_scores key: utility, accuracy
# cv_scores_ave:  [11.62730475621065, 0.4996688598192202]
# random iteration = 35
# training model fold 1
# training model fold 2
# training model fold 3
# training model fold 4
# training model fold 5
# training model fold 6
# training model fold 7
# training model fold 8
# training model fold 9
# training model fold 10
# cv_scores key: utility, accuracy
# cv_scores_ave:  [2.513562045232962, 0.4999015370656064]
# random iteration = 36
# training model fold 1
# training model fold 2
# training model fold 3
# training model fold 4
# training model fold 5
# training model fold 6
# training model fold 7
# training model fold 8
# training model fold 9
# training model fold 10
# cv_scores key: utility, accuracy
# cv_scores_ave:  [7.734321431529311, 0.5002452317072233]
# random iteration = 37
# training model fold 1
# training model fold 2
# training model fold 3
# training model fold 4
# training model fold 5
# training model fold 6
# training model fold 7
# training model fold 8
# training model fold 9
# training model fold 10
# cv_scores key: utility, accuracy
# cv_scores_ave:  [10.969191676013391, 0.4991783893560256]
# random iteration = 38
# training model fold 1
# training model fold 2
# training model fold 3
# training model fold 4
# training model fold 5
# training model fold 6
# training model fold 7
# training model fold 8
# training model fold 9
# training model fold 10
# cv_scores key: utility, accuracy
# cv_scores_ave:  [6.380677276467589, 0.49957578225639504]
# random iteration = 39
# training model fold 1
# training model fold 2
# training model fold 3
# training model fold 4
# training model fold 5
# training model fold 6
# training model fold 7
# training model fold 8
# training model fold 9
# training model fold 10
# cv_scores key: utility, accuracy
# cv_scores_ave:  [11.087460580912595, 0.4984910404428934]
# random iteration = 40
# training model fold 1
# training model fold 2
# training model fold 3
# training model fold 4
# training model fold 5
# training model fold 6
# training model fold 7
# training model fold 8
# training model fold 9
# training model fold 10
# cv_scores key: utility, accuracy
# cv_scores_ave:  [6.078289247077801, 0.5005173095320851]
# random iteration = 41
# training model fold 1
# training model fold 2
# training model fold 3
# training model fold 4
# training model fold 5
# training model fold 6
# training model fold 7
# training model fold 8
# training model fold 9
# training model fold 10
# cv_scores key: utility, accuracy
# cv_scores_ave:  [9.15176718395195, 0.49822611581557785]
# random iteration = 42
# training model fold 1
# training model fold 2
# training model fold 3
# training model fold 4
# training model fold 5
# training model fold 6
# training model fold 7
# training model fold 8
# training model fold 9
# training model fold 10
# cv_scores key: utility, accuracy
# cv_scores_ave:  [17.48265798642687, 0.5007177875853458]
# random iteration = 43
# training model fold 1
# training model fold 2
# training model fold 3
# training model fold 4
# training model fold 5
# training model fold 6
# training model fold 7
# training model fold 8
# training model fold 9
# training model fold 10
# cv_scores key: utility, accuracy
# cv_scores_ave:  [0.10913593326408802, 0.49783231431635233]
# random iteration = 44
# training model fold 1
# training model fold 2
# training model fold 3
# training model fold 4
# training model fold 5
# training model fold 6
# training model fold 7
# training model fold 8
# training model fold 9
# training model fold 10
# cv_scores key: utility, accuracy
# cv_scores_ave:  [11.04686159066435, 0.501426640690467]
# random iteration = 45
# training model fold 1
# training model fold 2
# training model fold 3
# training model fold 4
# training model fold 5
# training model fold 6
# training model fold 7
# training model fold 8
# training model fold 9
# training model fold 10
# cv_scores key: utility, accuracy
# cv_scores_ave:  [8.556644741892793, 0.49961156041923604]
# random iteration = 46
# training model fold 1
# training model fold 2
# training model fold 3
# training model fold 4
# training model fold 5
# training model fold 6
# training model fold 7
# training model fold 8
# training model fold 9
# training model fold 10
# cv_scores key: utility, accuracy
# cv_scores_ave:  [16.62259275219793, 0.49990511988009345]
# random iteration = 47
# training model fold 1
# training model fold 2
# training model fold 3
# training model fold 4
# training model fold 5
# training model fold 6
# training model fold 7
# training model fold 8
# training model fold 9
# training model fold 10
# cv_scores key: utility, accuracy
# cv_scores_ave:  [16.883191752995163, 0.5005602638329429]
# random iteration = 48
# training model fold 1
# training model fold 2
# training model fold 3
# training model fold 4
# training model fold 5
# training model fold 6
# training model fold 7
# training model fold 8
# training model fold 9
# training model fold 10
# cv_scores key: utility, accuracy
# cv_scores_ave:  [10.193180925727214, 0.4997332797361921]
# random iteration = 49
# training model fold 1
# training model fold 2
# training model fold 3
# training model fold 4
# training model fold 5
# training model fold 6
# training model fold 7
# training model fold 8
# training model fold 9
# training model fold 10
# cv_scores key: utility, accuracy
# cv_scores_ave:  [10.590119537912646, 0.500091272570722]
# random iteration = 50
# training model fold 1
# training model fold 2
# training model fold 3
# training model fold 4
# training model fold 5
# training model fold 6
# training model fold 7
# training model fold 8
# training model fold 9
# training model fold 10
# cv_scores key: utility, accuracy
# cv_scores_ave:  [8.383522138255811, 0.5002738838422375]
# all_cv_scores key: utility, accuracy, logit_roc_auc, true_pos, true_neg, false_pos, false_neg
# all_cv_scores_ave:  [10.010549778120069, 0.4998763479035489, None, None, None, None, None]
# saved model metrics

# %% [markdown]
# # Conclusion

# %% [markdown]
# Our models should at least do better than our randomly generated samples
# * Average utility score:  10.845353180393888
# * Average accuracy:  0.4998556066466747
