# %% [markdown]
# # 12_nndl_cv_mlp2
#
# We will experiment with Neural Networks and Deep Learning on the no_na dataset. This is mlp2, our second version of multi-layer perceptron
#
# # Difference from mlp1 - no dropout on the input layer

# %%
''' data and math '''
import pandas as pd
import numpy as np

''' plotting images '''
from matplotlib import pyplot as plt
# %matplotlib inline

''' traversing directories '''
import os
from pathlib import Path

''' utilities '''
from tqdm import tqdm

''' metrics '''
from sklearn.metrics import accuracy_score
from sklearn.metrics import confusion_matrix
from sklearn.metrics import roc_auc_score
from sklearn.metrics import roc_curve

''' preprocessing '''
from sklearn.preprocessing import StandardScaler

# %%
''' used to reference the root directory, for directory traversal ''' 
from google.colab import drive
drive.mount('/content/gdrive', force_remount=True)
mount_dir = '/content/gdrive'
root_dir = Path('/content/gdrive/My Drive/it3011_project')
# Out:
# Mounted at /content/gdrive

# %% [markdown]
# # Loading data

# %%
# load data
train = pd.read_csv(root_dir/"data/train_no_na.csv")
test = pd.read_csv(root_dir/"data/test_no_na.csv")
print("data loaded")
# Out:
# data loaded

# %%
# check shape
print(train.shape)
print(test.shape)
# Out:
# (279331, 138)
# (120163, 138)

# %%
# create train/test sets
features = [feature for feature in test.keys() if "feature" in feature]
x_train = train.loc[:, features].values
y_train = train.loc[:,['action']].values.flatten()
x_test = test.loc[:, features].values
y_test = test.loc[:,['action']].values.flatten()
print("train/test set created")
# Out:
# train/test set created

# %% [markdown]
# # Helper functions

# %%
# constants
SEED = 42

# cross validation
from sklearn.model_selection import KFold
kf = KFold(n_splits=10, random_state=SEED, shuffle=True)

# %%
# create the utility score, which takes in the prediction value and the ground truth action and generates a score
# link: https://www.kaggle.com/c/jane-street-market-prediction/overview/evaluation

# data: original train/test data    action: the y-value. can either be y_pred or original values too, if we want the max score attainable
def utility_score(data, action): 
  dates_set = set(data.date.values)
  dates = data.loc[:, ['date']].values.flatten()
  weights = data.loc[:, ['weight']].values.flatten()
  resps = data.loc[:, ['resp']].values.flatten()
  actions = action.flatten()

  i = len(dates_set)
  p_i = []

  for date in dates_set:
    indices = np.where(dates == date)[0]
    p_i_temp = 0
    for j in indices:
      p_i_temp = p_i_temp + weights[j] * resps[j] * actions[j]
    p_i.append(p_i_temp)
  
  p_i_squared = [p_i1*p_i2 for p_i1,p_i2 in zip(p_i,p_i)]
  t = ( sum(p_i) / np.sqrt(sum(p_i_squared)) ) * np.sqrt(250/i)
  u = min(max(t, 0), 6) * sum(p_i)

  return u

def max_train_utility_score(data=train, action=y_train):
  return utility_score(data, action)

def max_test_utility_score(data=test, action=y_test):
  return utility_score(data, action)

# %%
def model_scores(model, test, x_test, y_test):
  y_pred = model.predict(x_test) 
  y_pred = (y_pred > 0.5).astype(int)
  
  # # get some scores from helpers
  utility = utility_score(test, y_pred)
  accuracy =  accuracy_score(y_test, y_pred)

  # # confusion matrix
  # print("confusion matrix")
  cm = confusion_matrix(y_test, y_pred)
  true_pos = cm[1][1]
  true_neg = cm[0][0]
  false_pos = cm[0][1]
  false_neg = cm[1][0]

  # # plot confusion matrix
  # fig, ax = plt.subplots(figsize=(3, 3))
  # ax.imshow(cm)
  # ax.grid(False)
  # ax.xaxis.set(ticks=(0, 1), ticklabels=('Predicted 0s', 'Predicted 1s'))
  # ax.yaxis.set(ticks=(0, 1), ticklabels=('Actual 0s', 'Actual 1s'))
  # ax.set_ylim(1.5, -0.5)
  # for i in range(2):
  #     for j in range(2):
  #         ax.text(j, i, cm[i, j], ha='center', va='center', color='red')
  # plt.show()  

  # # AUC-ROC
  # print("AUC_ROC")
  logit_roc_auc = roc_auc_score(y_test, y_pred)

  # # plot auc-roc
  # fpr, tpr, thresholds = roc_curve(y_test, model.predict_proba(x_test)[:,1])
  # plt.figure()
  # plt.plot(fpr, tpr, label='Logistic Regression (area = %0.2f)' % logit_roc_auc)
  # plt.plot([0, 1], [0, 1],'r--')
  # plt.xlim([0.0, 1.0])
  # plt.ylim([0.0, 1.05])
  # plt.xlabel('False Positive Rate')
  # plt.ylabel('True Positive Rate')
  # plt.title('Receiver operating characteristic')
  # plt.legend(loc="lower right")
  # plt.show()

  return utility, accuracy, logit_roc_auc, true_pos, true_neg, false_pos, false_neg

# %%
import datetime
import csv

def save_scores(output_filename, workbook_name, model_name, model_params, utility, accuracy, logit_roc_auc, true_pos, true_neg, false_pos, false_neg):
  # create output file if not exists
  try:
    f = open(root_dir/output_filename)
  except IOError:
    with open (root_dir/output_filename, 'a') as csvfile:
      headers = ["workbook_name", "model_name", "model_params", "utility", "accuracy", "logit_roc_auc", "true_pos", "true_neg", "false_pos", "false_neg", "timestamp"]
      writer = csv.DictWriter(csvfile, delimiter=',', lineterminator='\n',fieldnames=headers)
      writer.writeheader() 
      print("created output file")  
    csvfile.close()

  # output file exists, append
  timestamp = datetime.datetime.now().strftime("%d/%m/%Y %H:%M:%S")
  
  ''' create another df that looks just like the excel file and concat with ''' 
  new_scores = pd.DataFrame(np.array([[workbook_name, model_name, model_params, utility, accuracy, logit_roc_auc, true_pos, true_neg, false_pos, false_neg, timestamp]]),
                   columns=["workbook_name", "model_name", "model_params", "utility", "accuracy", "logit_roc_auc", "true_pos", "true_neg", "false_pos", "false_neg", "timestamp"],
                  )

  new_scores.to_csv(root_dir/output_filename, mode='a', header=False, index=False)
  print("saved model metrics")

# %%
'''
used to generate the PosixPath variables for the results to save
'''
def results_paths(root_dir=root_dir):
    PATH_RESULTS = root_dir /'results_nndl'
    PATH_HISTORIES = PATH_RESULTS / 'histories'
    PATH_FIGURES = PATH_RESULTS / 'figures'
    PATH_CHECKPOINTS = PATH_RESULTS / 'checkpoints'
    PATH_PREDICTIONS = PATH_RESULTS / 'predictions'

    return PATH_RESULTS, PATH_HISTORIES, PATH_FIGURES, PATH_CHECKPOINTS, PATH_PREDICTIONS


''' 
used to save the history of a model as a npy file
'''
# filename like 'history/model_name.npy'
def history_saver(history, model_name, history_save_path, already_npy=False):
  history_json = {}

  if already_npy:
    history_npy = history
  else:
    history_npy = history.history

  np.save(history_save_path/model_name, history_npy)
  print("History saved")



''' 
used to load the history of a model from a npy file
'''
# filename like 'history/model_name.npy'
def history_loader(model_name, history_save_path):
  history_save_path = history_save_path/str(model_name+'.npy')
  history=np.load(history_save_path,allow_pickle='TRUE').item()
  print('History loaded')
  
  return history 

'''
used to plot the metrics for a given history
'''
def plot_metrics(history, model_name, figure_save_path):
    fig, (ax1, ax2, ax3) = plt.subplots(1, 3, figsize=(18, 6))

    # print(history.keys())

    # plot losses
    train_loss = history['loss']
    val_loss = history['val_loss']
    loss_title = 'loss against epochs'

    ax1.plot(train_loss, label='train')
    ax1.plot(val_loss, label='val')
    ax1.set_title(loss_title)
    ax1.set_ylabel('loss')
    ax1.set_xlabel('epochs')
    ax1.legend()

    # plot accuracy_score
    accuracy_score = history['accuracy']
    val_accuracy_score = history['val_accuracy']
    accuracy_score_title = 'accuracy_score against epochs'

    ax2.plot(accuracy_score, label='train')
    ax2.plot(val_accuracy_score, label='val')
    ax2.set_title(accuracy_score_title)
    ax2.set_ylabel('accuracy_score')
    ax2.set_xlabel('epochs')
    ax2.legend()


    # plot accuracy_score
    auc_score = history['auc']
    val_auc_score = history['val_auc']
    auc_score_title = 'auc_score against epochs'

    ax3.plot(auc_score, label='train')
    ax3.plot(val_auc_score, label='val')
    ax3.set_title(auc_score_title)
    ax3.set_ylabel('auc_score')
    ax3.set_xlabel('epochs')
    ax3.legend()


    # save figure
    fig.suptitle('Metrics for model: ' + model_name)
    plt.savefig(figure_save_path/f'{model_name}.png')

    plt.show()

# %% [markdown]
# # Neural Network - Model 2 (Activations)

# %%
# !pip install keras_tqdm
# Out:
# Collecting keras_tqdm
#   Downloading https://files.pythonhosted.org/packages/16/5c/ac63c65b79a895b8994474de2ad4d5b66ac0796b8903d60cfea3f8308d5c/keras_tqdm-2.0.1-py2.py3-none-any.whl
# Requirement already satisfied: Keras in /usr/local/lib/python3.7/dist-packages (from keras_tqdm) (2.4.3)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.7/dist-packages (from keras_tqdm) (4.41.1)
# Requirement already satisfied: h5py in /usr/local/lib/python3.7/dist-packages (from Keras->keras_tqdm) (2.10.0)
# Requirement already satisfied: scipy>=0.14 in /usr/local/lib/python3.7/dist-packages (from Keras->keras_tqdm) (1.4.1)
# Requirement already satisfied: numpy>=1.9.1 in /usr/local/lib/python3.7/dist-packages (from Keras->keras_tqdm) (1.19.5)
# Requirement already satisfied: pyyaml in /usr/local/lib/python3.7/dist-packages (from Keras->keras_tqdm) (3.13)
# Requirement already satisfied: six in /usr/local/lib/python3.7/dist-packages (from h5py->Keras->keras_tqdm) (1.15.0)
# Installing collected packages: keras-tqdm
# Successfully installed keras-tqdm-2.0.1

# %%
import tensorflow as tf
import tensorflow.keras as keras

from keras_tqdm import TQDMCallback
from keras.callbacks import ModelCheckpoint, EarlyStopping
from keras.layers import Input, Dense, BatchNormalization, Dropout, Activation
from keras.layers.experimental.preprocessing import Normalization
from keras.models import Model, Sequential
from keras.losses import BinaryCrossentropy
from keras.optimizers import Adam
from keras.metrics import BinaryAccuracy, AUC

tf.random.set_seed(SEED)
np.random.seed(SEED)

# %%
PATH_RESULTS, PATH_HISTORIES, PATH_FIGURES, PATH_CHECKPOINTS, PATH_PREDICTIONS = results_paths()

# %%
def create_mlp(num_columns, hidden_units, activation, dropout_rates, learning_rate): 
  inp = Input(shape=(num_columns,))
  x = BatchNormalization()(inp)

  for i in range(len(hidden_units)):   
    x = Dense(hidden_units[i])(x)
    x = Activation(activation)(x)
    x = BatchNormalization()(x)
    x = Dropout(dropout_rates[i])(x)

  x = Dense(1)(x)
  out = Activation("sigmoid")(x)

  model = Model(inputs=inp, outputs=out)

  model.compile(
    optimizer=Adam(learning_rate=learning_rate),
    loss=BinaryCrossentropy(label_smoothing=1e-4),
    metrics=[BinaryAccuracy(name="accuracy"), AUC(name="auc")]
  )

  return model

# %%
# settings to vary

# epochs default = [50] going forward for training due to time constraints, final evaluation put about 1000 to try and achieve convergence
epochs = [50] 

# batch_sizes default = [512] going forward for training due to time constraints, final evaluation can be batch size of 128/256 to achieve better utility scores
batch_sizes = [512]

# hidden_units default = [200, 400, 800, 400] going forward for training due to time constraints, final evaluation can be greater number of hidden units to achieve better utility scores
hidden_units = [
    [200, 400, 800, 400]
]

# dropout_rates should have same number of values as hidden_units
# dropout_rates default = [0.2, 0.2, 0.2, 0.2] going forward for training due to very poor performance of 0.4, and 0 provides no regularizing effect (model has not converged yet)
dropout_rates = [
    [0.2, 0.2, 0.2, 0.2]
] 

# activations default = [tf.keras.activations.tanh] going forward for training due to it performing well
activations = [tf.keras.activations.tanh]

# learning_rates default = [1e-4]
learning_rates = [1e-2, 1e-4, 1e-6]

# %%
for batch_size in batch_sizes:
  for hidden_unit in hidden_units:
    for activation in activations:
      for dropout_rate in dropout_rates:
        for learning_rate in learning_rates:
          for epoch in epochs:

            output_filename = "CV_SCORES_AVE_NNDL.csv"
            workbook_name = "12F_nndl_cv_mlp2_learning_rates"
            model_name = f"mlp2_learning_rates_{learning_rate}"
            model_params = f"batch_size={batch_size}, hidden_unit={hidden_unit}, activation={activation}, dropout_rate={dropout_rate}, learning_rate={learning_rate}, epoch={epoch}"
                    
            print("")
            print("model_name: ", model_name)
            print("model_params: ", model_params)

            # cross validation
            cv_scores = []

            for i, (train_idx, val_idx) in enumerate(kf.split(x_train)):
              # train-val data (for utility score calculation) 
              train_cv, val_cv = train.iloc[train_idx], train.iloc[val_idx]
              # train-val features 
              x_train_cv, x_val_cv, y_train_cv, y_val_cv = x_train[train_idx], x_train[val_idx], y_train[train_idx], y_train[val_idx]

              # scaling data to make it easier for models to train
              scaler = StandardScaler().fit(x_train_cv)
              x_train_cv = scaler.transform(x_train_cv)

              # test set scaled on the same scaler as train, because models are fitted on the train distributions and not test distributions
              x_val_cv = scaler.transform(x_val_cv)

              print(f"training model fold {i+1}")

              model = create_mlp(x_train_cv.shape[1], hidden_unit, activation, dropout_rate, learning_rate)
              model_name_fold = model_name + f"_fold_{i+1}"
              # CheckpointCallback = ModelCheckpoint(str(PATH_CHECKPOINTS / (model_name + '.hdf5')), monitor='val_loss', verbose=1, save_weights_only=True, save_best_only=True, mode='auto', save_freq='epoch')

              history = model.fit(
                  x_train_cv, 
                  y_train_cv, 
                  epochs=epoch, 
                  batch_size=batch_size,
                  validation_data=(x_val_cv, y_val_cv),
                  # callbacks = [CheckpointCallback]
              )

              model_score = model_scores(model, test=val_cv, x_test=x_val_cv, y_test=y_val_cv)
              cv_scores.append(model_score)

              history_saver(history, model_name_fold, PATH_HISTORIES, already_npy=False)
              history = history_loader(model_name_fold, PATH_HISTORIES)
              plot_metrics(history, model_name_fold, PATH_FIGURES)

            # mean of cv scores
            cv_scores_ave = [sum(ele) / len(cv_scores) for ele in zip(*cv_scores)]
            print("cv_scores key: utility, accuracy, logit_roc_auc, true_pos, true_neg, false_pos, false_neg")
            print("cv_scores_ave: ", cv_scores_ave)

            # save average scores
            save_scores(output_filename, workbook_name, model_name, model_params, *cv_scores_ave)
# Out:
# model_name:  mlp2_learning_rates_0.01
# model_params:  batch_size=512, hidden_unit=[200, 400, 800, 400], activation=<function tanh at 0x7fc3beb8e680>, dropout_rate=[0.2, 0.2, 0.2, 0.2], learning_rate=0.01, epoch=50
# training model fold 1
# Epoch 1/50
# 492/492 [==============================] - 11s 15ms/step - loss: 0.8190 - accuracy: 0.5023 - auc: 0.5022 - val_loss: 0.8937 - val_accuracy: 0.4812 - val_auc: 0.4829
# Epoch 2/50
# 492/492 [==============================] - 6s 13ms/step - loss: 0.7109 - accuracy: 0.5028 - auc: 0.5032 - val_loss: 0.6946 - val_accuracy: 0.4828 - val_auc: 0.4879
# Epoch 3/50
# 492/492 [==============================] - 6s 12ms/step - loss: 0.6963 - accuracy: 0.5071 - auc: 0.5085 - val_loss: 0.7195 - val_accuracy: 0.5107 - val_auc: 0.5080
# Epoch 4/50
# 492/492 [==============================] - 6s 13ms/step - loss: 0.6972 - accuracy: 0.5059 - auc: 0.5069 - val_loss: 0.6918 - val_accuracy: 0.5243 - val_auc: 0.5183
# Epoch 5/50
# 492/492 [==============================] - 6s 12ms/step - loss: 0.6929 - accuracy: 0.5148 - auc: 0.5195 - val_loss: 0.6919 - val_accuracy: 0.5195 - val_auc: 0.5290
# Epoch 6/50
# 492/492 [==============================] - 6s 12ms/step - loss: 0.6920 - accuracy: 0.5202 - auc: 0.5281 - val_loss: 0.6905 - val_accuracy: 0.5267 - val_auc: 0.5417
# Epoch 7/50
# 492/492 [==============================] - 6s 13ms/step - loss: 0.6912 - accuracy: 0.5246 - auc: 0.5346 - val_loss: 0.6945 - val_accuracy: 0.5199 - val_auc: 0.5413
# Epoch 8/50
# 492/492 [==============================] - 6s 13ms/step - loss: 0.6925 - accuracy: 0.5217 - auc: 0.5275 - val_loss: 0.6916 - val_accuracy: 0.5195 - val_auc: 0.5281
# Epoch 9/50
# 492/492 [==============================] - 6s 13ms/step - loss: 0.6929 - accuracy: 0.5128 - auc: 0.5185 - val_loss: 0.6918 - val_accuracy: 0.5220 - val_auc: 0.5307
# Epoch 10/50
# 492/492 [==============================] - 6s 12ms/step - loss: 0.6927 - accuracy: 0.5135 - auc: 0.5179 - val_loss: 0.6918 - val_accuracy: 0.5208 - val_auc: 0.5265
# Epoch 11/50
# 492/492 [==============================] - 6s 12ms/step - loss: 0.6922 - accuracy: 0.5204 - auc: 0.5248 - val_loss: 0.6923 - val_accuracy: 0.5217 - val_auc: 0.5358
# Epoch 12/50
# 492/492 [==============================] - 6s 12ms/step - loss: 0.6920 - accuracy: 0.5207 - auc: 0.5270 - val_loss: 0.6938 - val_accuracy: 0.4858 - val_auc: 0.5253
# Epoch 13/50
# 492/492 [==============================] - 6s 12ms/step - loss: 0.6932 - accuracy: 0.5102 - auc: 0.5113 - val_loss: 0.6931 - val_accuracy: 0.4929 - val_auc: 0.5174
# Epoch 14/50
# 492/492 [==============================] - 6s 13ms/step - loss: 0.6930 - accuracy: 0.5125 - auc: 0.5118 - val_loss: 0.6949 - val_accuracy: 0.5143 - val_auc: 0.4995
# Epoch 15/50
# 492/492 [==============================] - 6s 13ms/step - loss: 0.6932 - accuracy: 0.5126 - auc: 0.5129 - val_loss: 0.6927 - val_accuracy: 0.5207 - val_auc: 0.5084
# Epoch 16/50
# 492/492 [==============================] - 6s 13ms/step - loss: 0.6931 - accuracy: 0.5094 - auc: 0.5066 - val_loss: 0.6941 - val_accuracy: 0.4863 - val_auc: 0.5007
# Epoch 17/50
# 492/492 [==============================] - 6s 13ms/step - loss: 0.6935 - accuracy: 0.5029 - auc: 0.5010 - val_loss: 0.6928 - val_accuracy: 0.5127 - val_auc: 0.5193
# Epoch 18/50
# 492/492 [==============================] - 6s 13ms/step - loss: 0.6933 - accuracy: 0.5056 - auc: 0.5048 - val_loss: 0.6934 - val_accuracy: 0.4907 - val_auc: 0.5123
# Epoch 19/50
# 492/492 [==============================] - 6s 13ms/step - loss: 0.6933 - accuracy: 0.5055 - auc: 0.5000 - val_loss: 0.7013 - val_accuracy: 0.5143 - val_auc: 0.5000
# Epoch 20/50
# 492/492 [==============================] - 6s 12ms/step - loss: 0.6933 - accuracy: 0.5071 - auc: 0.5002 - val_loss: 0.6929 - val_accuracy: 0.5143 - val_auc: 0.5001
# Epoch 21/50
# 492/492 [==============================] - 6s 13ms/step - loss: 0.6934 - accuracy: 0.5057 - auc: 0.5012 - val_loss: 0.6928 - val_accuracy: 0.5143 - val_auc: 0.5000
# Epoch 22/50
# 492/492 [==============================] - 6s 13ms/step - loss: 0.6933 - accuracy: 0.5052 - auc: 0.5022 - val_loss: 0.6923 - val_accuracy: 0.5143 - val_auc: 0.5148
# Epoch 23/50
# 492/492 [==============================] - 6s 13ms/step - loss: 0.6934 - accuracy: 0.5083 - auc: 0.5064 - val_loss: 0.6969 - val_accuracy: 0.5144 - val_auc: 0.5146
# Epoch 24/50
# 492/492 [==============================] - 6s 13ms/step - loss: 0.6947 - accuracy: 0.5054 - auc: 0.5016 - val_loss: 0.6928 - val_accuracy: 0.5144 - val_auc: 0.5103
# Epoch 25/50
# 492/492 [==============================] - 6s 13ms/step - loss: 0.6933 - accuracy: 0.5058 - auc: 0.4998 - val_loss: 0.6960 - val_accuracy: 0.4859 - val_auc: 0.5004
# Epoch 26/50
# 492/492 [==============================] - 6s 13ms/step - loss: 0.6934 - accuracy: 0.5036 - auc: 0.5001 - val_loss: 0.6938 - val_accuracy: 0.4858 - val_auc: 0.5011
# Epoch 27/50
# 492/492 [==============================] - 6s 13ms/step - loss: 0.6941 - accuracy: 0.5018 - auc: 0.4987 - val_loss: 0.6931 - val_accuracy: 0.5142 - val_auc: 0.4973
# Epoch 28/50
# 492/492 [==============================] - 6s 13ms/step - loss: 0.6932 - accuracy: 0.5089 - auc: 0.5005 - val_loss: 0.6935 - val_accuracy: 0.5143 - val_auc: 0.5000
# Epoch 29/50
# 492/492 [==============================] - 6s 13ms/step - loss: 0.6939 - accuracy: 0.5053 - auc: 0.4984 - val_loss: 0.6991 - val_accuracy: 0.5143 - val_auc: 0.5000
# Epoch 30/50
# 492/492 [==============================] - 6s 13ms/step - loss: 0.6944 - accuracy: 0.5060 - auc: 0.5005 - val_loss: 0.6939 - val_accuracy: 0.5143 - val_auc: 0.5000
# Epoch 31/50
# 492/492 [==============================] - 6s 13ms/step - loss: 0.6934 - accuracy: 0.5059 - auc: 0.4997 - val_loss: 0.6928 - val_accuracy: 0.5143 - val_auc: 0.5000
# Epoch 32/50
# 492/492 [==============================] - 6s 13ms/step - loss: 0.6931 - accuracy: 0.5091 - auc: 0.5009 - val_loss: 0.6929 - val_accuracy: 0.5143 - val_auc: 0.5000
# Epoch 33/50
# 492/492 [==============================] - 6s 13ms/step - loss: 0.6933 - accuracy: 0.5046 - auc: 0.4980 - val_loss: 0.6930 - val_accuracy: 0.5143 - val_auc: 0.4999
# Epoch 34/50
# 492/492 [==============================] - 6s 13ms/step - loss: 0.6932 - accuracy: 0.5054 - auc: 0.4991 - val_loss: 0.6928 - val_accuracy: 0.5143 - val_auc: 0.5001
# Epoch 35/50
# 492/492 [==============================] - 6s 13ms/step - loss: 0.6932 - accuracy: 0.5083 - auc: 0.5011 - val_loss: 0.6929 - val_accuracy: 0.5143 - val_auc: 0.5000
# Epoch 36/50
# 492/492 [==============================] - 6s 13ms/step - loss: 0.6937 - accuracy: 0.5020 - auc: 0.4971 - val_loss: 0.6931 - val_accuracy: 0.5143 - val_auc: 0.5000
# Epoch 37/50
# 492/492 [==============================] - 6s 13ms/step - loss: 0.6934 - accuracy: 0.5045 - auc: 0.4964 - val_loss: 0.6929 - val_accuracy: 0.5143 - val_auc: 0.5000
# Epoch 38/50
# 492/492 [==============================] - 6s 13ms/step - loss: 0.6934 - accuracy: 0.5067 - auc: 0.4992 - val_loss: 0.6929 - val_accuracy: 0.5143 - val_auc: 0.5000
# Epoch 39/50
# 492/492 [==============================] - 6s 13ms/step - loss: 0.6934 - accuracy: 0.5046 - auc: 0.5005 - val_loss: 0.6941 - val_accuracy: 0.5143 - val_auc: 0.5000
# Epoch 40/50
# 492/492 [==============================] - 6s 13ms/step - loss: 0.6937 - accuracy: 0.5049 - auc: 0.4988 - val_loss: 0.6929 - val_accuracy: 0.5143 - val_auc: 0.5000
# Epoch 41/50
# 492/492 [==============================] - 6s 13ms/step - loss: 0.6932 - accuracy: 0.5052 - auc: 0.4994 - val_loss: 0.6947 - val_accuracy: 0.5143 - val_auc: 0.5000
# Epoch 42/50
# 492/492 [==============================] - 6s 13ms/step - loss: 0.6944 - accuracy: 0.5048 - auc: 0.5002 - val_loss: 0.6941 - val_accuracy: 0.5143 - val_auc: 0.5000
# Epoch 43/50
# 492/492 [==============================] - 6s 13ms/step - loss: 0.6941 - accuracy: 0.5015 - auc: 0.4958 - val_loss: 0.6933 - val_accuracy: 0.4857 - val_auc: 0.5000
# Epoch 44/50
# 492/492 [==============================] - 6s 13ms/step - loss: 0.6931 - accuracy: 0.5057 - auc: 0.5009 - val_loss: 0.6932 - val_accuracy: 0.5143 - val_auc: 0.5000
# Epoch 45/50
# 492/492 [==============================] - 6s 13ms/step - loss: 0.6932 - accuracy: 0.5073 - auc: 0.5022 - val_loss: 0.6938 - val_accuracy: 0.5143 - val_auc: 0.5000
# Epoch 46/50
# 492/492 [==============================] - 6s 13ms/step - loss: 0.6940 - accuracy: 0.5022 - auc: 0.4962 - val_loss: 0.6928 - val_accuracy: 0.5143 - val_auc: 0.5000
# Epoch 47/50
# 492/492 [==============================] - 6s 13ms/step - loss: 0.6934 - accuracy: 0.5058 - auc: 0.5001 - val_loss: 0.6930 - val_accuracy: 0.5143 - val_auc: 0.5000
# Epoch 48/50
# 492/492 [==============================] - 6s 13ms/step - loss: 0.6936 - accuracy: 0.5052 - auc: 0.5009 - val_loss: 0.6928 - val_accuracy: 0.5143 - val_auc: 0.5000
# Epoch 49/50
# 492/492 [==============================] - 6s 13ms/step - loss: 0.6929 - accuracy: 0.5093 - auc: 0.5035 - val_loss: 0.6933 - val_accuracy: 0.4857 - val_auc: 0.5000
# Epoch 50/50
# 492/492 [==============================] - 6s 13ms/step - loss: 0.6934 - accuracy: 0.5050 - auc: 0.5017 - val_loss: 0.6929 - val_accuracy: 0.5143 - val_auc: 0.5000
# History saved
# History loaded
# training model fold 2
# Epoch 1/50
# 492/492 [==============================] - 9s 14ms/step - loss: 0.9335 - accuracy: 0.5063 - auc: 0.5056 - val_loss: 0.7165 - val_accuracy: 0.4919 - val_auc: 0.5009
# Epoch 2/50
# 492/492 [==============================] - 7s 14ms/step - loss: 0.7032 - accuracy: 0.5043 - auc: 0.5059 - val_loss: 0.7280 - val_accuracy: 0.5077 - val_auc: 0.5175
# Epoch 3/50
# 492/492 [==============================] - 7s 14ms/step - loss: 0.6988 - accuracy: 0.5104 - auc: 0.5132 - val_loss: 0.7019 - val_accuracy: 0.5140 - val_auc: 0.5149
# Epoch 4/50
# 492/492 [==============================] - 7s 14ms/step - loss: 0.6948 - accuracy: 0.5140 - auc: 0.5189 - val_loss: 0.6913 - val_accuracy: 0.5239 - val_auc: 0.5332
# Epoch 5/50
# 492/492 [==============================] - 7s 13ms/step - loss: 0.6918 - accuracy: 0.5222 - auc: 0.5299 - val_loss: 0.6908 - val_accuracy: 0.5295 - val_auc: 0.5409
# Epoch 6/50
# 492/492 [==============================] - 7s 13ms/step - loss: 0.6914 - accuracy: 0.5224 - auc: 0.5328 - val_loss: 0.6912 - val_accuracy: 0.5310 - val_auc: 0.5402
# Epoch 7/50
# 492/492 [==============================] - 7s 13ms/step - loss: 0.6915 - accuracy: 0.5241 - auc: 0.5351 - val_loss: 0.6941 - val_accuracy: 0.5081 - val_auc: 0.5248
# Epoch 8/50
# 492/492 [==============================] - 7s 13ms/step - loss: 0.6912 - accuracy: 0.5283 - auc: 0.5369 - val_loss: 0.6900 - val_accuracy: 0.5337 - val_auc: 0.5492
# Epoch 9/50
# 492/492 [==============================] - 7s 13ms/step - loss: 0.6911 - accuracy: 0.5248 - auc: 0.5355 - val_loss: 0.6917 - val_accuracy: 0.5209 - val_auc: 0.5327
# Epoch 10/50
# 492/492 [==============================] - 7s 13ms/step - loss: 0.6914 - accuracy: 0.5245 - auc: 0.5338 - val_loss: 0.6907 - val_accuracy: 0.5342 - val_auc: 0.5407
# Epoch 11/50
# 492/492 [==============================] - 7s 13ms/step - loss: 0.6919 - accuracy: 0.5215 - auc: 0.5281 - val_loss: 0.6927 - val_accuracy: 0.5148 - val_auc: 0.5223
# Epoch 12/50
# 492/492 [==============================] - 7s 13ms/step - loss: 0.6924 - accuracy: 0.5164 - auc: 0.5219 - val_loss: 0.6923 - val_accuracy: 0.5234 - val_auc: 0.5297
# Epoch 13/50
# 492/492 [==============================] - 7s 13ms/step - loss: 0.6923 - accuracy: 0.5174 - auc: 0.5244 - val_loss: 0.6909 - val_accuracy: 0.5241 - val_auc: 0.5408
# Epoch 14/50
# 492/492 [==============================] - 7s 13ms/step - loss: 0.6927 - accuracy: 0.5152 - auc: 0.5178 - val_loss: 0.6922 - val_accuracy: 0.5197 - val_auc: 0.5238
# Epoch 15/50
# 492/492 [==============================] - 7s 13ms/step - loss: 0.6922 - accuracy: 0.5177 - auc: 0.5216 - val_loss: 0.6955 - val_accuracy: 0.5077 - val_auc: 0.5273
# Epoch 16/50
# 492/492 [==============================] - 7s 13ms/step - loss: 0.6930 - accuracy: 0.5154 - auc: 0.5196 - val_loss: 0.6944 - val_accuracy: 0.5199 - val_auc: 0.5355
# Epoch 17/50
# 492/492 [==============================] - 7s 13ms/step - loss: 0.6926 - accuracy: 0.5179 - auc: 0.5215 - val_loss: 0.6933 - val_accuracy: 0.5087 - val_auc: 0.5289
# Epoch 18/50
# 492/492 [==============================] - 7s 13ms/step - loss: 0.6931 - accuracy: 0.5124 - auc: 0.5143 - val_loss: 0.6926 - val_accuracy: 0.5123 - val_auc: 0.5253
# Epoch 19/50
# 492/492 [==============================] - 7s 14ms/step - loss: 0.6926 - accuracy: 0.5155 - auc: 0.5147 - val_loss: 0.6954 - val_accuracy: 0.4923 - val_auc: 0.5176
# Epoch 20/50
# 492/492 [==============================] - 7s 13ms/step - loss: 0.6936 - accuracy: 0.5074 - auc: 0.5062 - val_loss: 0.6927 - val_accuracy: 0.5097 - val_auc: 0.5157
# Epoch 21/50
# 492/492 [==============================] - 7s 13ms/step - loss: 0.6932 - accuracy: 0.5080 - auc: 0.5051 - val_loss: 0.6939 - val_accuracy: 0.5074 - val_auc: 0.5112
# Epoch 22/50
# 492/492 [==============================] - 7s 13ms/step - loss: 0.6932 - accuracy: 0.5076 - auc: 0.5030 - val_loss: 0.7142 - val_accuracy: 0.5078 - val_auc: 0.4970
# Epoch 23/50
# 492/492 [==============================] - 7s 13ms/step - loss: 0.6936 - accuracy: 0.5084 - auc: 0.5055 - val_loss: 0.6953 - val_accuracy: 0.5077 - val_auc: 0.4994
# Epoch 24/50
# 492/492 [==============================] - 7s 13ms/step - loss: 0.6935 - accuracy: 0.5060 - auc: 0.5019 - val_loss: 0.6934 - val_accuracy: 0.5066 - val_auc: 0.5025
# Epoch 25/50
# 492/492 [==============================] - 7s 13ms/step - loss: 0.6934 - accuracy: 0.5079 - auc: 0.5002 - val_loss: 0.6938 - val_accuracy: 0.5081 - val_auc: 0.4962
# Epoch 26/50
# 492/492 [==============================] - 6s 13ms/step - loss: 0.6937 - accuracy: 0.5054 - auc: 0.4994 - val_loss: 0.6931 - val_accuracy: 0.5074 - val_auc: 0.4997
# Epoch 27/50
# 492/492 [==============================] - 6s 13ms/step - loss: 0.6934 - accuracy: 0.5057 - auc: 0.4969 - val_loss: 0.6964 - val_accuracy: 0.5087 - val_auc: 0.5030
# Epoch 28/50
# 492/492 [==============================] - 6s 13ms/step - loss: 0.6937 - accuracy: 0.5035 - auc: 0.5003 - val_loss: 0.6970 - val_accuracy: 0.5079 - val_auc: 0.5003
# Epoch 29/50
# 492/492 [==============================] - 6s 13ms/step - loss: 0.6946 - accuracy: 0.5036 - auc: 0.4992 - val_loss: 0.9684 - val_accuracy: 0.4923 - val_auc: 0.5000
# Epoch 30/50
# 492/492 [==============================] - 6s 13ms/step - loss: 0.6939 - accuracy: 0.5066 - auc: 0.5005 - val_loss: 0.6932 - val_accuracy: 0.5077 - val_auc: 0.4992
# Epoch 31/50
# 492/492 [==============================] - 6s 13ms/step - loss: 0.6935 - accuracy: 0.5056 - auc: 0.4999 - val_loss: 0.6984 - val_accuracy: 0.5077 - val_auc: 0.5015
# Epoch 32/50
# 492/492 [==============================] - 6s 13ms/step - loss: 0.6938 - accuracy: 0.5049 - auc: 0.5001 - val_loss: 0.6934 - val_accuracy: 0.5078 - val_auc: 0.4998
# Epoch 33/50
# 492/492 [==============================] - 6s 13ms/step - loss: 0.6932 - accuracy: 0.5063 - auc: 0.4981 - val_loss: 0.6940 - val_accuracy: 0.4918 - val_auc: 0.4994
# Epoch 34/50
# 492/492 [==============================] - 6s 13ms/step - loss: 0.6934 - accuracy: 0.5066 - auc: 0.5021 - val_loss: 0.6967 - val_accuracy: 0.4921 - val_auc: 0.4997
# Epoch 35/50
# 492/492 [==============================] - 6s 13ms/step - loss: 0.6941 - accuracy: 0.5055 - auc: 0.5012 - val_loss: 0.6939 - val_accuracy: 0.5078 - val_auc: 0.5024
# Epoch 36/50
# 492/492 [==============================] - 6s 13ms/step - loss: 0.6935 - accuracy: 0.5064 - auc: 0.5007 - val_loss: 0.6937 - val_accuracy: 0.4938 - val_auc: 0.5031
# Epoch 37/50
# 492/492 [==============================] - 6s 13ms/step - loss: 0.6935 - accuracy: 0.5061 - auc: 0.4994 - val_loss: 0.6931 - val_accuracy: 0.5077 - val_auc: 0.5003
# Epoch 38/50
# 492/492 [==============================] - 6s 13ms/step - loss: 0.6934 - accuracy: 0.5060 - auc: 0.4969 - val_loss: 0.6959 - val_accuracy: 0.5079 - val_auc: 0.5001
# Epoch 39/50
# 492/492 [==============================] - 7s 13ms/step - loss: 0.6939 - accuracy: 0.5067 - auc: 0.5024 - val_loss: 0.6932 - val_accuracy: 0.5077 - val_auc: 0.4999
# Epoch 40/50
# 492/492 [==============================] - 6s 13ms/step - loss: 0.6933 - accuracy: 0.5052 - auc: 0.4987 - val_loss: 0.6934 - val_accuracy: 0.4929 - val_auc: 0.5003
# Epoch 41/50
# 492/492 [==============================] - 6s 13ms/step - loss: 0.6932 - accuracy: 0.5057 - auc: 0.4976 - val_loss: 0.6933 - val_accuracy: 0.5078 - val_auc: 0.5002
# Epoch 42/50
# 492/492 [==============================] - 6s 13ms/step - loss: 0.6932 - accuracy: 0.5071 - auc: 0.4988 - val_loss: 0.6937 - val_accuracy: 0.5077 - val_auc: 0.5002
# Epoch 43/50
# 492/492 [==============================] - 6s 13ms/step - loss: 0.6933 - accuracy: 0.5066 - auc: 0.4979 - val_loss: 0.6934 - val_accuracy: 0.5077 - val_auc: 0.5001
# Epoch 44/50
# 492/492 [==============================] - 6s 13ms/step - loss: 0.6937 - accuracy: 0.5065 - auc: 0.5029 - val_loss: 0.6933 - val_accuracy: 0.5072 - val_auc: 0.4996
# Epoch 45/50
# 492/492 [==============================] - 6s 13ms/step - loss: 0.6935 - accuracy: 0.5055 - auc: 0.5007 - val_loss: 0.6931 - val_accuracy: 0.5077 - val_auc: 0.5004
# Epoch 46/50
# 492/492 [==============================] - 6s 13ms/step - loss: 0.6932 - accuracy: 0.5073 - auc: 0.4984 - val_loss: 0.6974 - val_accuracy: 0.5077 - val_auc: 0.5001
# Epoch 47/50
# 492/492 [==============================] - 6s 13ms/step - loss: 0.6936 - accuracy: 0.5074 - auc: 0.5012 - val_loss: 0.6932 - val_accuracy: 0.5078 - val_auc: 0.5002
# Epoch 48/50
# 492/492 [==============================] - 6s 13ms/step - loss: 0.6933 - accuracy: 0.5058 - auc: 0.4999 - val_loss: 0.6932 - val_accuracy: 0.5075 - val_auc: 0.4999
# Epoch 49/50
# 492/492 [==============================] - 6s 13ms/step - loss: 0.6932 - accuracy: 0.5082 - auc: 0.5006 - val_loss: 0.6935 - val_accuracy: 0.5077 - val_auc: 0.5000
# Epoch 50/50
# 492/492 [==============================] - 6s 13ms/step - loss: 0.6933 - accuracy: 0.5058 - auc: 0.5015 - val_loss: 0.6942 - val_accuracy: 0.4922 - val_auc: 0.4998
# History saved
# History loaded
# training model fold 3
# Epoch 1/50
# 492/492 [==============================] - 9s 15ms/step - loss: 0.9396 - accuracy: 0.5011 - auc: 0.5001 - val_loss: 0.8908 - val_accuracy: 0.5088 - val_auc: 0.5082
# Epoch 2/50
# 492/492 [==============================] - 7s 14ms/step - loss: 0.7171 - accuracy: 0.5038 - auc: 0.5028 - val_loss: 0.7187 - val_accuracy: 0.4943 - val_auc: 0.4935
# Epoch 3/50
# 492/492 [==============================] - 7s 14ms/step - loss: 0.6986 - accuracy: 0.5022 - auc: 0.5015 - val_loss: 0.6982 - val_accuracy: 0.5101 - val_auc: 0.5104
# Epoch 4/50
# 492/492 [==============================] - 7s 14ms/step - loss: 0.6970 - accuracy: 0.5039 - auc: 0.5037 - val_loss: 0.7002 - val_accuracy: 0.5050 - val_auc: 0.5051
# Epoch 5/50
# 492/492 [==============================] - 7s 14ms/step - loss: 0.6946 - accuracy: 0.5173 - auc: 0.5211 - val_loss: 0.6935 - val_accuracy: 0.5252 - val_auc: 0.5288
# Epoch 6/50
# 492/492 [==============================] - 7s 14ms/step - loss: 0.6915 - accuracy: 0.5274 - auc: 0.5355 - val_loss: 0.6912 - val_accuracy: 0.5271 - val_auc: 0.5400
# Epoch 7/50
# 492/492 [==============================] - 7s 14ms/step - loss: 0.6914 - accuracy: 0.5240 - auc: 0.5332 - val_loss: 0.6911 - val_accuracy: 0.5271 - val_auc: 0.5363
# Epoch 8/50
# 492/492 [==============================] - 7s 14ms/step - loss: 0.6920 - accuracy: 0.5243 - auc: 0.5319 - val_loss: 0.6921 - val_accuracy: 0.5129 - val_auc: 0.5261
# Epoch 9/50
# 492/492 [==============================] - 7s 14ms/step - loss: 0.6919 - accuracy: 0.5245 - auc: 0.5318 - val_loss: 0.6928 - val_accuracy: 0.5219 - val_auc: 0.5274
# Epoch 10/50
# 492/492 [==============================] - 7s 14ms/step - loss: 0.6930 - accuracy: 0.5172 - auc: 0.5192 - val_loss: 0.6924 - val_accuracy: 0.5180 - val_auc: 0.5271
# Epoch 11/50
# 492/492 [==============================] - 7s 14ms/step - loss: 0.6923 - accuracy: 0.5201 - auc: 0.5241 - val_loss: 0.6927 - val_accuracy: 0.5120 - val_auc: 0.5264
# Epoch 12/50
# 492/492 [==============================] - 7s 14ms/step - loss: 0.6926 - accuracy: 0.5139 - auc: 0.5179 - val_loss: 0.6934 - val_accuracy: 0.4989 - val_auc: 0.4985
# Epoch 13/50
# 492/492 [==============================] - 7s 14ms/step - loss: 0.6927 - accuracy: 0.5131 - auc: 0.5155 - val_loss: 0.6944 - val_accuracy: 0.5059 - val_auc: 0.5143
# Epoch 14/50
# 492/492 [==============================] - 7s 14ms/step - loss: 0.6927 - accuracy: 0.5139 - auc: 0.5140 - val_loss: 0.6929 - val_accuracy: 0.5141 - val_auc: 0.5101
# Epoch 15/50
# 492/492 [==============================] - 7s 14ms/step - loss: 0.6932 - accuracy: 0.5118 - auc: 0.5115 - val_loss: 0.6930 - val_accuracy: 0.5106 - val_auc: 0.5109
# Epoch 16/50
# 492/492 [==============================] - 7s 14ms/step - loss: 0.6928 - accuracy: 0.5135 - auc: 0.5132 - val_loss: 0.6933 - val_accuracy: 0.5059 - val_auc: 0.5124
# Epoch 17/50
# 492/492 [==============================] - 7s 14ms/step - loss: 0.6929 - accuracy: 0.5133 - auc: 0.5134 - val_loss: 0.6949 - val_accuracy: 0.5059 - val_auc: 0.5121
# Epoch 18/50
# 492/492 [==============================] - 7s 14ms/step - loss: 0.6931 - accuracy: 0.5154 - auc: 0.5127 - val_loss: 0.6952 - val_accuracy: 0.5171 - val_auc: 0.5143
# Epoch 19/50
# 492/492 [==============================] - 7s 14ms/step - loss: 0.6930 - accuracy: 0.5142 - auc: 0.5139 - val_loss: 0.6934 - val_accuracy: 0.5059 - val_auc: 0.5108
# Epoch 20/50
# 492/492 [==============================] - 7s 14ms/step - loss: 0.6932 - accuracy: 0.5096 - auc: 0.5106 - val_loss: 0.6933 - val_accuracy: 0.5152 - val_auc: 0.5205
# Epoch 21/50
# 492/492 [==============================] - 7s 14ms/step - loss: 0.6931 - accuracy: 0.5147 - auc: 0.5146 - val_loss: 0.6928 - val_accuracy: 0.5123 - val_auc: 0.5203
# Epoch 22/50
# 492/492 [==============================] - 7s 14ms/step - loss: 0.6936 - accuracy: 0.5113 - auc: 0.5105 - val_loss: 0.6928 - val_accuracy: 0.5160 - val_auc: 0.5134
# Epoch 23/50
# 492/492 [==============================] - 7s 14ms/step - loss: 0.6926 - accuracy: 0.5167 - auc: 0.5168 - val_loss: 0.6933 - val_accuracy: 0.5141 - val_auc: 0.5140
# Epoch 24/50
# 492/492 [==============================] - 7s 14ms/step - loss: 0.6928 - accuracy: 0.5144 - auc: 0.5110 - val_loss: 0.6931 - val_accuracy: 0.5059 - val_auc: 0.5102
# Epoch 25/50
# 492/492 [==============================] - 7s 14ms/step - loss: 0.6929 - accuracy: 0.5131 - auc: 0.5118 - val_loss: 0.6936 - val_accuracy: 0.5059 - val_auc: 0.5171
# Epoch 26/50
# 492/492 [==============================] - 7s 14ms/step - loss: 0.6930 - accuracy: 0.5132 - auc: 0.5116 - val_loss: 0.6928 - val_accuracy: 0.5154 - val_auc: 0.5176
# Epoch 27/50
# 492/492 [==============================] - 7s 14ms/step - loss: 0.6931 - accuracy: 0.5108 - auc: 0.5100 - val_loss: 0.6939 - val_accuracy: 0.5063 - val_auc: 0.5025
# Epoch 28/50
# 492/492 [==============================] - 7s 14ms/step - loss: 0.6930 - accuracy: 0.5122 - auc: 0.5095 - val_loss: 0.6932 - val_accuracy: 0.5059 - val_auc: 0.5000
# Epoch 29/50
# 492/492 [==============================] - 7s 14ms/step - loss: 0.6933 - accuracy: 0.5086 - auc: 0.5044 - val_loss: 0.6937 - val_accuracy: 0.5059 - val_auc: 0.5089
# Epoch 30/50
# 492/492 [==============================] - 7s 14ms/step - loss: 0.6934 - accuracy: 0.5109 - auc: 0.5071 - val_loss: 0.6940 - val_accuracy: 0.5084 - val_auc: 0.5074
# Epoch 31/50
# 492/492 [==============================] - 7s 14ms/step - loss: 0.6937 - accuracy: 0.5083 - auc: 0.5052 - val_loss: 0.7029 - val_accuracy: 0.5060 - val_auc: 0.5002
# Epoch 32/50
# 492/492 [==============================] - 7s 14ms/step - loss: 0.6940 - accuracy: 0.5100 - auc: 0.5078 - val_loss: 0.6935 - val_accuracy: 0.5098 - val_auc: 0.5061
# Epoch 33/50
# 492/492 [==============================] - 7s 14ms/step - loss: 0.6934 - accuracy: 0.5076 - auc: 0.5034 - val_loss: 0.6940 - val_accuracy: 0.5061 - val_auc: 0.5099
# Epoch 34/50
# 492/492 [==============================] - 7s 14ms/step - loss: 0.6933 - accuracy: 0.5097 - auc: 0.5057 - val_loss: 0.6936 - val_accuracy: 0.5058 - val_auc: 0.5069
# Epoch 35/50
# 492/492 [==============================] - 7s 14ms/step - loss: 0.6935 - accuracy: 0.5096 - auc: 0.5033 - val_loss: 0.6934 - val_accuracy: 0.4943 - val_auc: 0.4997
# Epoch 36/50
# 492/492 [==============================] - 7s 14ms/step - loss: 0.6932 - accuracy: 0.5079 - auc: 0.5024 - val_loss: 0.6934 - val_accuracy: 0.5060 - val_auc: 0.5040
# Epoch 37/50
# 492/492 [==============================] - 7s 14ms/step - loss: 0.6932 - accuracy: 0.5107 - auc: 0.5040 - val_loss: 0.6976 - val_accuracy: 0.5060 - val_auc: 0.4991
# Epoch 38/50
# 492/492 [==============================] - 7s 14ms/step - loss: 0.6935 - accuracy: 0.5057 - auc: 0.4992 - val_loss: 0.6933 - val_accuracy: 0.5059 - val_auc: 0.5003
# Epoch 39/50
# 492/492 [==============================] - 7s 14ms/step - loss: 0.6933 - accuracy: 0.5061 - auc: 0.4992 - val_loss: 0.6938 - val_accuracy: 0.5058 - val_auc: 0.4996
# Epoch 40/50
# 492/492 [==============================] - 7s 14ms/step - loss: 0.6932 - accuracy: 0.5078 - auc: 0.5014 - val_loss: 0.6969 - val_accuracy: 0.5061 - val_auc: 0.5004
# Epoch 41/50
# 492/492 [==============================] - 7s 14ms/step - loss: 0.6933 - accuracy: 0.5060 - auc: 0.4993 - val_loss: 0.6933 - val_accuracy: 0.5059 - val_auc: 0.5000
# Epoch 42/50
# 492/492 [==============================] - 7s 14ms/step - loss: 0.6934 - accuracy: 0.5074 - auc: 0.4978 - val_loss: 0.6940 - val_accuracy: 0.4939 - val_auc: 0.4996
# Epoch 43/50
# 492/492 [==============================] - 7s 14ms/step - loss: 0.6940 - accuracy: 0.5036 - auc: 0.4990 - val_loss: 0.6933 - val_accuracy: 0.5057 - val_auc: 0.5002
# Epoch 44/50
# 492/492 [==============================] - 7s 14ms/step - loss: 0.6935 - accuracy: 0.5019 - auc: 0.4993 - val_loss: 0.6937 - val_accuracy: 0.4940 - val_auc: 0.4999
# Epoch 45/50
# 492/492 [==============================] - 7s 14ms/step - loss: 0.6933 - accuracy: 0.5044 - auc: 0.5022 - val_loss: 0.6933 - val_accuracy: 0.5057 - val_auc: 0.4997
# Epoch 46/50
# 492/492 [==============================] - 7s 14ms/step - loss: 0.6933 - accuracy: 0.5045 - auc: 0.4999 - val_loss: 0.6936 - val_accuracy: 0.5060 - val_auc: 0.5004
# Epoch 47/50
# 492/492 [==============================] - 7s 14ms/step - loss: 0.6935 - accuracy: 0.5077 - auc: 0.5020 - val_loss: 0.6939 - val_accuracy: 0.5059 - val_auc: 0.4999
# Epoch 48/50
# 492/492 [==============================] - 7s 14ms/step - loss: 0.6935 - accuracy: 0.5047 - auc: 0.4991 - val_loss: 0.6950 - val_accuracy: 0.5059 - val_auc: 0.4999
# Epoch 49/50
# 492/492 [==============================] - 7s 14ms/step - loss: 0.6936 - accuracy: 0.5058 - auc: 0.4988 - val_loss: 0.6937 - val_accuracy: 0.5059 - val_auc: 0.5001
# Epoch 50/50
# 492/492 [==============================] - 7s 14ms/step - loss: 0.6937 - accuracy: 0.5036 - auc: 0.4997 - val_loss: 0.6950 - val_accuracy: 0.5058 - val_auc: 0.4999
# History saved
# History loaded
# training model fold 4
# Epoch 1/50
# 492/492 [==============================] - 9s 15ms/step - loss: 1.1079 - accuracy: 0.5038 - auc: 0.5031 - val_loss: 0.6965 - val_accuracy: 0.4927 - val_auc: 0.5030
# Epoch 2/50
# 492/492 [==============================] - 7s 14ms/step - loss: 0.6996 - accuracy: 0.5035 - auc: 0.5012 - val_loss: 0.6943 - val_accuracy: 0.4911 - val_auc: 0.4920
# Epoch 3/50
# 492/492 [==============================] - 7s 14ms/step - loss: 0.7007 - accuracy: 0.5043 - auc: 0.5051 - val_loss: 0.7215 - val_accuracy: 0.4980 - val_auc: 0.5092
# Epoch 4/50
# 492/492 [==============================] - 7s 14ms/step - loss: 0.6991 - accuracy: 0.5077 - auc: 0.5080 - val_loss: 0.6998 - val_accuracy: 0.5014 - val_auc: 0.5046
# Epoch 5/50
# 492/492 [==============================] - 7s 14ms/step - loss: 0.6950 - accuracy: 0.5099 - auc: 0.5099 - val_loss: 0.6954 - val_accuracy: 0.5137 - val_auc: 0.5228
# Epoch 6/50
# 492/492 [==============================] - 7s 14ms/step - loss: 0.6937 - accuracy: 0.5161 - auc: 0.5194 - val_loss: 0.6927 - val_accuracy: 0.5142 - val_auc: 0.5270
# Epoch 7/50
# 492/492 [==============================] - 7s 14ms/step - loss: 0.6915 - accuracy: 0.5300 - auc: 0.5348 - val_loss: 0.6916 - val_accuracy: 0.5269 - val_auc: 0.5378
# Epoch 8/50
# 492/492 [==============================] - 7s 14ms/step - loss: 0.6910 - accuracy: 0.5297 - auc: 0.5385 - val_loss: 0.6892 - val_accuracy: 0.5386 - val_auc: 0.5494
# Epoch 9/50
# 492/492 [==============================] - 7s 14ms/step - loss: 0.6909 - accuracy: 0.5299 - auc: 0.5391 - val_loss: 0.6895 - val_accuracy: 0.5370 - val_auc: 0.5498
# Epoch 10/50
# 492/492 [==============================] - 7s 14ms/step - loss: 0.6908 - accuracy: 0.5307 - auc: 0.5392 - val_loss: 0.6914 - val_accuracy: 0.5204 - val_auc: 0.5310
# Epoch 11/50
# 492/492 [==============================] - 7s 14ms/step - loss: 0.6917 - accuracy: 0.5236 - auc: 0.5300 - val_loss: 0.6919 - val_accuracy: 0.5118 - val_auc: 0.5349
# Epoch 12/50
# 492/492 [==============================] - 7s 14ms/step - loss: 0.6921 - accuracy: 0.5200 - auc: 0.5277 - val_loss: 0.6950 - val_accuracy: 0.5108 - val_auc: 0.5349
# Epoch 13/50
# 492/492 [==============================] - 7s 14ms/step - loss: 0.6923 - accuracy: 0.5192 - auc: 0.5257 - val_loss: 0.6921 - val_accuracy: 0.5170 - val_auc: 0.5304
# Epoch 14/50
# 492/492 [==============================] - 7s 14ms/step - loss: 0.6926 - accuracy: 0.5167 - auc: 0.5229 - val_loss: 0.6973 - val_accuracy: 0.4985 - val_auc: 0.5325
# Epoch 15/50
# 492/492 [==============================] - 7s 14ms/step - loss: 0.6934 - accuracy: 0.5112 - auc: 0.5143 - val_loss: 0.6922 - val_accuracy: 0.5175 - val_auc: 0.5210
# Epoch 16/50
# 492/492 [==============================] - 7s 14ms/step - loss: 0.6933 - accuracy: 0.5124 - auc: 0.5129 - val_loss: 0.6932 - val_accuracy: 0.4997 - val_auc: 0.5191
# Epoch 17/50
# 492/492 [==============================] - 7s 14ms/step - loss: 0.6933 - accuracy: 0.5097 - auc: 0.5118 - val_loss: 0.6929 - val_accuracy: 0.4955 - val_auc: 0.5182
# Epoch 18/50
# 492/492 [==============================] - 7s 14ms/step - loss: 0.6934 - accuracy: 0.5071 - auc: 0.5077 - val_loss: 0.6950 - val_accuracy: 0.4854 - val_auc: 0.4876
# Epoch 19/50
# 492/492 [==============================] - 7s 14ms/step - loss: 0.6934 - accuracy: 0.5110 - auc: 0.5122 - val_loss: 0.6928 - val_accuracy: 0.5153 - val_auc: 0.5173
# Epoch 20/50
# 492/492 [==============================] - 7s 15ms/step - loss: 0.6939 - accuracy: 0.5080 - auc: 0.5081 - val_loss: 0.6925 - val_accuracy: 0.5178 - val_auc: 0.5215
# Epoch 21/50
# 492/492 [==============================] - 7s 14ms/step - loss: 0.6931 - accuracy: 0.5108 - auc: 0.5113 - val_loss: 0.7116 - val_accuracy: 0.5095 - val_auc: 0.5193
# Epoch 22/50
# 492/492 [==============================] - 7s 14ms/step - loss: 0.6930 - accuracy: 0.5115 - auc: 0.5122 - val_loss: 0.6932 - val_accuracy: 0.5095 - val_auc: 0.5120
# Epoch 23/50
# 492/492 [==============================] - 7s 14ms/step - loss: 0.6935 - accuracy: 0.5074 - auc: 0.5064 - val_loss: 0.6942 - val_accuracy: 0.5095 - val_auc: 0.5189
# Epoch 24/50
# 492/492 [==============================] - 7s 14ms/step - loss: 0.6934 - accuracy: 0.5097 - auc: 0.5071 - val_loss: 0.6941 - val_accuracy: 0.5095 - val_auc: 0.5040
# Epoch 25/50
# 492/492 [==============================] - 7s 14ms/step - loss: 0.6934 - accuracy: 0.5077 - auc: 0.5061 - val_loss: 0.6929 - val_accuracy: 0.5095 - val_auc: 0.5052
# Epoch 26/50
# 492/492 [==============================] - 7s 14ms/step - loss: 0.6932 - accuracy: 0.5057 - auc: 0.5000 - val_loss: 0.6933 - val_accuracy: 0.4905 - val_auc: 0.4996
# Epoch 27/50
# 492/492 [==============================] - 7s 14ms/step - loss: 0.6934 - accuracy: 0.5055 - auc: 0.5003 - val_loss: 0.6933 - val_accuracy: 0.4905 - val_auc: 0.5000
# Epoch 28/50
# 492/492 [==============================] - 7s 14ms/step - loss: 0.6933 - accuracy: 0.5064 - auc: 0.4984 - val_loss: 0.6932 - val_accuracy: 0.5095 - val_auc: 0.5050
# Epoch 29/50
# 492/492 [==============================] - 7s 14ms/step - loss: 0.6947 - accuracy: 0.5021 - auc: 0.5003 - val_loss: 0.6950 - val_accuracy: 0.4941 - val_auc: 0.5168
# Epoch 30/50
# 492/492 [==============================] - 7s 14ms/step - loss: 0.6940 - accuracy: 0.5057 - auc: 0.5047 - val_loss: 0.7108 - val_accuracy: 0.4905 - val_auc: 0.5146
# Epoch 31/50
# 492/492 [==============================] - 7s 14ms/step - loss: 0.6940 - accuracy: 0.5078 - auc: 0.5063 - val_loss: 0.6951 - val_accuracy: 0.4945 - val_auc: 0.5141
# Epoch 32/50
# 492/492 [==============================] - 7s 14ms/step - loss: 0.6930 - accuracy: 0.5095 - auc: 0.5086 - val_loss: 0.6934 - val_accuracy: 0.5095 - val_auc: 0.5177
# Epoch 33/50
# 492/492 [==============================] - 7s 14ms/step - loss: 0.6929 - accuracy: 0.5119 - auc: 0.5107 - val_loss: 0.6930 - val_accuracy: 0.5092 - val_auc: 0.5164
# Epoch 34/50
# 492/492 [==============================] - 7s 14ms/step - loss: 0.6932 - accuracy: 0.5071 - auc: 0.5040 - val_loss: 0.6951 - val_accuracy: 0.4961 - val_auc: 0.5150
# Epoch 35/50
# 492/492 [==============================] - 7s 14ms/step - loss: 0.6945 - accuracy: 0.5063 - auc: 0.5058 - val_loss: 0.7020 - val_accuracy: 0.4963 - val_auc: 0.5067
# Epoch 36/50
# 492/492 [==============================] - 7s 14ms/step - loss: 0.6939 - accuracy: 0.5050 - auc: 0.5029 - val_loss: 0.6934 - val_accuracy: 0.4987 - val_auc: 0.5065
# Epoch 37/50
# 492/492 [==============================] - 7s 14ms/step - loss: 0.6937 - accuracy: 0.5032 - auc: 0.5016 - val_loss: 0.6964 - val_accuracy: 0.4915 - val_auc: 0.5074
# Epoch 38/50
# 492/492 [==============================] - 7s 14ms/step - loss: 0.6939 - accuracy: 0.5039 - auc: 0.5025 - val_loss: 0.6928 - val_accuracy: 0.5094 - val_auc: 0.5138
# Epoch 39/50
# 492/492 [==============================] - 7s 14ms/step - loss: 0.6931 - accuracy: 0.5080 - auc: 0.5028 - val_loss: 0.6926 - val_accuracy: 0.5130 - val_auc: 0.5136
# Epoch 40/50
# 492/492 [==============================] - 7s 14ms/step - loss: 0.6933 - accuracy: 0.5080 - auc: 0.5057 - val_loss: 0.6944 - val_accuracy: 0.4914 - val_auc: 0.5038
# Epoch 41/50
# 492/492 [==============================] - 7s 14ms/step - loss: 0.6939 - accuracy: 0.5043 - auc: 0.5016 - val_loss: 0.6928 - val_accuracy: 0.5095 - val_auc: 0.5048
# Epoch 42/50
# 492/492 [==============================] - 7s 14ms/step - loss: 0.6931 - accuracy: 0.5069 - auc: 0.4998 - val_loss: 0.6955 - val_accuracy: 0.5095 - val_auc: 0.5062
# Epoch 43/50
# 492/492 [==============================] - 7s 14ms/step - loss: 0.6935 - accuracy: 0.5051 - auc: 0.5028 - val_loss: 0.8135 - val_accuracy: 0.5095 - val_auc: 0.5132
# Epoch 44/50
# 492/492 [==============================] - 7s 14ms/step - loss: 0.6941 - accuracy: 0.5054 - auc: 0.5011 - val_loss: 0.6929 - val_accuracy: 0.5096 - val_auc: 0.5028
# Epoch 45/50
# 492/492 [==============================] - 7s 14ms/step - loss: 0.6933 - accuracy: 0.5042 - auc: 0.4983 - val_loss: 0.6934 - val_accuracy: 0.4954 - val_auc: 0.5038
# Epoch 46/50
# 492/492 [==============================] - 7s 14ms/step - loss: 0.6934 - accuracy: 0.5042 - auc: 0.5002 - val_loss: 0.6930 - val_accuracy: 0.5095 - val_auc: 0.4999
# Epoch 47/50
# 492/492 [==============================] - 7s 14ms/step - loss: 0.6938 - accuracy: 0.5052 - auc: 0.4973 - val_loss: 0.6942 - val_accuracy: 0.5081 - val_auc: 0.4995
# Epoch 48/50
# 492/492 [==============================] - 7s 14ms/step - loss: 0.6939 - accuracy: 0.5020 - auc: 0.4991 - val_loss: 0.6946 - val_accuracy: 0.5095 - val_auc: 0.4999
# Epoch 49/50
# 492/492 [==============================] - 7s 14ms/step - loss: 0.6934 - accuracy: 0.5051 - auc: 0.5024 - val_loss: 0.6994 - val_accuracy: 0.5096 - val_auc: 0.5014
# Epoch 50/50
# 492/492 [==============================] - 7s 14ms/step - loss: 0.6943 - accuracy: 0.5046 - auc: 0.5002 - val_loss: 0.7009 - val_accuracy: 0.4915 - val_auc: 0.5013
# History saved
# History loaded
# training model fold 5
# Epoch 1/50
# 492/492 [==============================] - 10s 15ms/step - loss: 1.0462 - accuracy: 0.5019 - auc: 0.5007 - val_loss: 0.8688 - val_accuracy: 0.5155 - val_auc: 0.5159
# Epoch 2/50
# 492/492 [==============================] - 7s 14ms/step - loss: 0.7089 - accuracy: 0.5065 - auc: 0.5076 - val_loss: 0.8065 - val_accuracy: 0.5140 - val_auc: 0.5256
# Epoch 3/50
# 492/492 [==============================] - 7s 14ms/step - loss: 0.7053 - accuracy: 0.5108 - auc: 0.5123 - val_loss: 0.7160 - val_accuracy: 0.5165 - val_auc: 0.5317
# Epoch 4/50
# 492/492 [==============================] - 7s 14ms/step - loss: 0.6974 - accuracy: 0.5132 - auc: 0.5166 - val_loss: 0.7057 - val_accuracy: 0.4925 - val_auc: 0.5052
# Epoch 5/50
# 492/492 [==============================] - 7s 14ms/step - loss: 0.6953 - accuracy: 0.5120 - auc: 0.5161 - val_loss: 0.6958 - val_accuracy: 0.5104 - val_auc: 0.5209
# Epoch 6/50
# 492/492 [==============================] - 7s 14ms/step - loss: 0.6931 - accuracy: 0.5173 - auc: 0.5239 - val_loss: 0.6911 - val_accuracy: 0.5192 - val_auc: 0.5310
# Epoch 7/50
# 492/492 [==============================] - 7s 14ms/step - loss: 0.6910 - accuracy: 0.5237 - auc: 0.5337 - val_loss: 0.6922 - val_accuracy: 0.5182 - val_auc: 0.5339
# Epoch 8/50
# 492/492 [==============================] - 7s 14ms/step - loss: 0.6921 - accuracy: 0.5225 - auc: 0.5288 - val_loss: 0.6905 - val_accuracy: 0.5321 - val_auc: 0.5385
# Epoch 9/50
# 492/492 [==============================] - 7s 14ms/step - loss: 0.6915 - accuracy: 0.5215 - auc: 0.5290 - val_loss: 0.6909 - val_accuracy: 0.5254 - val_auc: 0.5352
# Epoch 10/50
# 492/492 [==============================] - 7s 14ms/step - loss: 0.6918 - accuracy: 0.5203 - auc: 0.5252 - val_loss: 0.6917 - val_accuracy: 0.5176 - val_auc: 0.5273
# Epoch 11/50
# 492/492 [==============================] - 7s 15ms/step - loss: 0.6927 - accuracy: 0.5130 - auc: 0.5168 - val_loss: 0.6921 - val_accuracy: 0.5166 - val_auc: 0.5228
# Epoch 12/50
# 492/492 [==============================] - 7s 15ms/step - loss: 0.6928 - accuracy: 0.5118 - auc: 0.5122 - val_loss: 0.6926 - val_accuracy: 0.5163 - val_auc: 0.5153
# Epoch 13/50
# 492/492 [==============================] - 7s 15ms/step - loss: 0.6927 - accuracy: 0.5121 - auc: 0.5146 - val_loss: 0.6940 - val_accuracy: 0.5168 - val_auc: 0.5204
# Epoch 14/50
# 492/492 [==============================] - 7s 15ms/step - loss: 0.6929 - accuracy: 0.5121 - auc: 0.5135 - val_loss: 0.6964 - val_accuracy: 0.5109 - val_auc: 0.5154
# Epoch 15/50
# 492/492 [==============================] - 7s 15ms/step - loss: 0.6931 - accuracy: 0.5095 - auc: 0.5114 - val_loss: 0.6927 - val_accuracy: 0.5158 - val_auc: 0.5158
# Epoch 16/50
# 492/492 [==============================] - 7s 15ms/step - loss: 0.6929 - accuracy: 0.5120 - auc: 0.5140 - val_loss: 0.6969 - val_accuracy: 0.5109 - val_auc: 0.5159
# Epoch 17/50
# 492/492 [==============================] - 7s 15ms/step - loss: 0.6936 - accuracy: 0.5109 - auc: 0.5101 - val_loss: 0.6926 - val_accuracy: 0.5109 - val_auc: 0.5167
# Epoch 18/50
# 492/492 [==============================] - 7s 15ms/step - loss: 0.6932 - accuracy: 0.5107 - auc: 0.5125 - val_loss: 0.6931 - val_accuracy: 0.5160 - val_auc: 0.5160
# Epoch 19/50
# 492/492 [==============================] - 7s 15ms/step - loss: 0.6930 - accuracy: 0.5084 - auc: 0.5058 - val_loss: 0.6931 - val_accuracy: 0.5109 - val_auc: 0.5000
# Epoch 20/50
# 492/492 [==============================] - 7s 15ms/step - loss: 0.6932 - accuracy: 0.5072 - auc: 0.4984 - val_loss: 0.6930 - val_accuracy: 0.5109 - val_auc: 0.5000
# Epoch 21/50
# 492/492 [==============================] - 7s 15ms/step - loss: 0.6932 - accuracy: 0.5062 - auc: 0.5011 - val_loss: 0.6930 - val_accuracy: 0.5109 - val_auc: 0.5000
# Epoch 22/50
# 492/492 [==============================] - 7s 15ms/step - loss: 0.6933 - accuracy: 0.5082 - auc: 0.4987 - val_loss: 0.6978 - val_accuracy: 0.5109 - val_auc: 0.5000
# Epoch 23/50
# 492/492 [==============================] - 7s 15ms/step - loss: 0.6937 - accuracy: 0.5042 - auc: 0.4979 - val_loss: 0.6930 - val_accuracy: 0.5109 - val_auc: 0.5000
# Epoch 24/50
# 492/492 [==============================] - 7s 15ms/step - loss: 0.6931 - accuracy: 0.5079 - auc: 0.5006 - val_loss: 0.6930 - val_accuracy: 0.5109 - val_auc: 0.5000
# Epoch 25/50
# 492/492 [==============================] - 7s 15ms/step - loss: 0.6932 - accuracy: 0.5059 - auc: 0.4988 - val_loss: 0.6936 - val_accuracy: 0.5109 - val_auc: 0.5000
# Epoch 26/50
# 492/492 [==============================] - 7s 15ms/step - loss: 0.6934 - accuracy: 0.5050 - auc: 0.4981 - val_loss: 0.6935 - val_accuracy: 0.5109 - val_auc: 0.5000
# Epoch 27/50
# 492/492 [==============================] - 7s 15ms/step - loss: 0.6932 - accuracy: 0.5077 - auc: 0.5003 - val_loss: 0.6933 - val_accuracy: 0.5109 - val_auc: 0.5000
# Epoch 28/50
# 492/492 [==============================] - 7s 15ms/step - loss: 0.6934 - accuracy: 0.5071 - auc: 0.5002 - val_loss: 0.6957 - val_accuracy: 0.5109 - val_auc: 0.5000
# Epoch 29/50
# 492/492 [==============================] - 7s 15ms/step - loss: 0.6934 - accuracy: 0.5075 - auc: 0.5023 - val_loss: 0.6929 - val_accuracy: 0.5109 - val_auc: 0.5000
# Epoch 30/50
# 492/492 [==============================] - 7s 15ms/step - loss: 0.6931 - accuracy: 0.5076 - auc: 0.5004 - val_loss: 0.6930 - val_accuracy: 0.5109 - val_auc: 0.5000
# Epoch 31/50
# 492/492 [==============================] - 7s 15ms/step - loss: 0.6935 - accuracy: 0.5037 - auc: 0.5002 - val_loss: 0.6941 - val_accuracy: 0.4891 - val_auc: 0.5000
# Epoch 32/50
# 492/492 [==============================] - 7s 15ms/step - loss: 0.6941 - accuracy: 0.4999 - auc: 0.4967 - val_loss: 0.6932 - val_accuracy: 0.5109 - val_auc: 0.5000
# Epoch 33/50
# 492/492 [==============================] - 7s 15ms/step - loss: 0.6934 - accuracy: 0.5052 - auc: 0.4990 - val_loss: 0.6938 - val_accuracy: 0.5109 - val_auc: 0.5000
# Epoch 34/50
# 492/492 [==============================] - 7s 15ms/step - loss: 0.6933 - accuracy: 0.5059 - auc: 0.4985 - val_loss: 0.6930 - val_accuracy: 0.5109 - val_auc: 0.5000
# Epoch 35/50
# 492/492 [==============================] - 7s 15ms/step - loss: 0.6933 - accuracy: 0.5042 - auc: 0.4974 - val_loss: 0.6931 - val_accuracy: 0.5109 - val_auc: 0.5000
# Epoch 36/50
# 492/492 [==============================] - 7s 15ms/step - loss: 0.6932 - accuracy: 0.5068 - auc: 0.5006 - val_loss: 0.6929 - val_accuracy: 0.5109 - val_auc: 0.5000
# Epoch 37/50
# 492/492 [==============================] - 7s 15ms/step - loss: 0.6933 - accuracy: 0.5038 - auc: 0.4987 - val_loss: 0.6929 - val_accuracy: 0.5109 - val_auc: 0.5000
# Epoch 38/50
# 492/492 [==============================] - 7s 15ms/step - loss: 0.6934 - accuracy: 0.5043 - auc: 0.5007 - val_loss: 0.6934 - val_accuracy: 0.5109 - val_auc: 0.5000
# Epoch 39/50
# 492/492 [==============================] - 7s 15ms/step - loss: 0.6938 - accuracy: 0.5036 - auc: 0.4950 - val_loss: 0.6958 - val_accuracy: 0.5109 - val_auc: 0.5000
# Epoch 40/50
# 492/492 [==============================] - 7s 15ms/step - loss: 0.6936 - accuracy: 0.5045 - auc: 0.5005 - val_loss: 0.6944 - val_accuracy: 0.4891 - val_auc: 0.5000
# Epoch 41/50
# 492/492 [==============================] - 7s 15ms/step - loss: 0.6938 - accuracy: 0.5025 - auc: 0.4993 - val_loss: 0.6929 - val_accuracy: 0.5109 - val_auc: 0.5000
# Epoch 42/50
# 492/492 [==============================] - 7s 15ms/step - loss: 0.6936 - accuracy: 0.5042 - auc: 0.5002 - val_loss: 0.6929 - val_accuracy: 0.5109 - val_auc: 0.5000
# Epoch 43/50
# 492/492 [==============================] - 7s 15ms/step - loss: 0.6931 - accuracy: 0.5085 - auc: 0.4999 - val_loss: 0.6933 - val_accuracy: 0.5109 - val_auc: 0.5000
# Epoch 44/50
# 492/492 [==============================] - 7s 15ms/step - loss: 0.6932 - accuracy: 0.5073 - auc: 0.5023 - val_loss: 0.6931 - val_accuracy: 0.5109 - val_auc: 0.5000
# Epoch 45/50
# 492/492 [==============================] - 7s 15ms/step - loss: 0.6939 - accuracy: 0.5028 - auc: 0.5000 - val_loss: 0.6930 - val_accuracy: 0.5109 - val_auc: 0.5000
# Epoch 46/50
# 492/492 [==============================] - 7s 15ms/step - loss: 0.6934 - accuracy: 0.5051 - auc: 0.4994 - val_loss: 0.6936 - val_accuracy: 0.5109 - val_auc: 0.5000
# Epoch 47/50
# 492/492 [==============================] - 7s 15ms/step - loss: 0.6936 - accuracy: 0.5045 - auc: 0.4990 - val_loss: 0.7041 - val_accuracy: 0.5109 - val_auc: 0.4999
# Epoch 48/50
# 492/492 [==============================] - 7s 15ms/step - loss: 0.6936 - accuracy: 0.5056 - auc: 0.5013 - val_loss: 0.6979 - val_accuracy: 0.5108 - val_auc: 0.5001
# Epoch 49/50
# 492/492 [==============================] - 7s 15ms/step - loss: 0.6933 - accuracy: 0.5046 - auc: 0.5009 - val_loss: 0.6934 - val_accuracy: 0.5110 - val_auc: 0.5004
# Epoch 50/50
# 492/492 [==============================] - 7s 15ms/step - loss: 0.6935 - accuracy: 0.5037 - auc: 0.4995 - val_loss: 0.7387 - val_accuracy: 0.5108 - val_auc: 0.5002
# History saved
# History loaded
# training model fold 6
# Epoch 1/50
# 492/492 [==============================] - 10s 16ms/step - loss: 1.0668 - accuracy: 0.5028 - auc: 0.5026 - val_loss: 0.6959 - val_accuracy: 0.4955 - val_auc: 0.4949
# Epoch 2/50
# 492/492 [==============================] - 7s 15ms/step - loss: 0.6997 - accuracy: 0.5052 - auc: 0.5054 - val_loss: 0.6926 - val_accuracy: 0.5122 - val_auc: 0.5147
# Epoch 3/50
# 492/492 [==============================] - 7s 15ms/step - loss: 0.6996 - accuracy: 0.5051 - auc: 0.5060 - val_loss: 0.7288 - val_accuracy: 0.4987 - val_auc: 0.5107
# Epoch 4/50
# 492/492 [==============================] - 7s 15ms/step - loss: 0.6985 - accuracy: 0.5070 - auc: 0.5083 - val_loss: 0.7256 - val_accuracy: 0.5067 - val_auc: 0.4998
# Epoch 5/50
# 492/492 [==============================] - 7s 15ms/step - loss: 0.6987 - accuracy: 0.5077 - auc: 0.5105 - val_loss: 0.6971 - val_accuracy: 0.5056 - val_auc: 0.5035
# Epoch 6/50
# 492/492 [==============================] - 7s 15ms/step - loss: 0.6940 - accuracy: 0.5141 - auc: 0.5171 - val_loss: 0.6923 - val_accuracy: 0.5119 - val_auc: 0.5224
# Epoch 7/50
# 492/492 [==============================] - 7s 15ms/step - loss: 0.6921 - accuracy: 0.5188 - auc: 0.5259 - val_loss: 0.6919 - val_accuracy: 0.5200 - val_auc: 0.5323
# Epoch 8/50
# 492/492 [==============================] - 7s 15ms/step - loss: 0.6917 - accuracy: 0.5223 - auc: 0.5292 - val_loss: 0.6919 - val_accuracy: 0.5254 - val_auc: 0.5255
# Epoch 9/50
# 492/492 [==============================] - 7s 15ms/step - loss: 0.6917 - accuracy: 0.5234 - auc: 0.5309 - val_loss: 0.6919 - val_accuracy: 0.5181 - val_auc: 0.5229
# Epoch 10/50
# 492/492 [==============================] - 7s 15ms/step - loss: 0.6918 - accuracy: 0.5210 - auc: 0.5284 - val_loss: 0.6925 - val_accuracy: 0.5195 - val_auc: 0.5232
# Epoch 11/50
# 492/492 [==============================] - 7s 15ms/step - loss: 0.6925 - accuracy: 0.5126 - auc: 0.5192 - val_loss: 0.6923 - val_accuracy: 0.5180 - val_auc: 0.5216
# Epoch 12/50
# 492/492 [==============================] - 7s 15ms/step - loss: 0.6924 - accuracy: 0.5142 - auc: 0.5198 - val_loss: 0.6934 - val_accuracy: 0.5063 - val_auc: 0.5130
# Epoch 13/50
# 492/492 [==============================] - 7s 15ms/step - loss: 0.6926 - accuracy: 0.5150 - auc: 0.5200 - val_loss: 0.6926 - val_accuracy: 0.5183 - val_auc: 0.5203
# Epoch 14/50
# 492/492 [==============================] - 7s 15ms/step - loss: 0.6928 - accuracy: 0.5112 - auc: 0.5159 - val_loss: 0.6923 - val_accuracy: 0.5151 - val_auc: 0.5232
# Epoch 15/50
# 492/492 [==============================] - 7s 15ms/step - loss: 0.6930 - accuracy: 0.5127 - auc: 0.5164 - val_loss: 0.6923 - val_accuracy: 0.5133 - val_auc: 0.5181
# Epoch 16/50
# 492/492 [==============================] - 7s 15ms/step - loss: 0.6934 - accuracy: 0.5088 - auc: 0.5105 - val_loss: 0.6924 - val_accuracy: 0.5161 - val_auc: 0.5157
# Epoch 17/50
# 492/492 [==============================] - 7s 15ms/step - loss: 0.6928 - accuracy: 0.5119 - auc: 0.5150 - val_loss: 0.6923 - val_accuracy: 0.5118 - val_auc: 0.5146
# Epoch 18/50
# 492/492 [==============================] - 7s 15ms/step - loss: 0.6933 - accuracy: 0.5093 - auc: 0.5126 - val_loss: 0.6931 - val_accuracy: 0.5134 - val_auc: 0.5133
# Epoch 19/50
# 492/492 [==============================] - 7s 15ms/step - loss: 0.6933 - accuracy: 0.5085 - auc: 0.5107 - val_loss: 0.6931 - val_accuracy: 0.5134 - val_auc: 0.5160
# Epoch 20/50
# 492/492 [==============================] - 7s 15ms/step - loss: 0.6928 - accuracy: 0.5079 - auc: 0.5131 - val_loss: 0.6964 - val_accuracy: 0.5133 - val_auc: 0.5140
# Epoch 21/50
# ...
# Epoch 33/50
# 492/492 [==============================] - 8s 16ms/step - loss: 0.6936 - accuracy: 0.5059 - auc: 0.4990 - val_loss: 0.6934 - val_accuracy: 0.4946 - val_auc: 0.5001
# Epoch 34/50
# 492/492 [==============================] - 8s 16ms/step - loss: 0.6939 - accuracy: 0.5041 - auc: 0.4973 - val_loss: 0.6932 - val_accuracy: 0.5057 - val_auc: 0.5005
# Epoch 35/50
# 492/492 [==============================] - 8s 16ms/step - loss: 0.6931 - accuracy: 0.5083 - auc: 0.5000 - val_loss: 0.6941 - val_accuracy: 0.5058 - val_auc: 0.5010
# Epoch 36/50
# 492/492 [==============================] - 8s 16ms/step - loss: 0.6934 - accuracy: 0.5055 - auc: 0.5016 - val_loss: 0.6936 - val_accuracy: 0.4943 - val_auc: 0.5001
# Epoch 37/50
# 492/492 [==============================] - 8s 16ms/step - loss: 0.6939 - accuracy: 0.5045 - auc: 0.4995 - val_loss: 0.6933 - val_accuracy: 0.4944 - val_auc: 0.4994
# Epoch 38/50
# 492/492 [==============================] - 8s 15ms/step - loss: 0.6933 - accuracy: 0.5075 - auc: 0.4997 - val_loss: 0.6933 - val_accuracy: 0.5055 - val_auc: 0.4998
# Epoch 39/50
# 492/492 [==============================] - 8s 15ms/step - loss: 0.6932 - accuracy: 0.5080 - auc: 0.5001 - val_loss: 0.6932 - val_accuracy: 0.5056 - val_auc: 0.5001
# Epoch 40/50
# 492/492 [==============================] - 8s 15ms/step - loss: 0.6934 - accuracy: 0.5049 - auc: 0.5010 - val_loss: 0.6933 - val_accuracy: 0.4944 - val_auc: 0.4999
# Epoch 41/50
# 492/492 [==============================] - 8s 16ms/step - loss: 0.6934 - accuracy: 0.5061 - auc: 0.5003 - val_loss: 0.6931 - val_accuracy: 0.5059 - val_auc: 0.5005
# Epoch 42/50
# 492/492 [==============================] - 8s 16ms/step - loss: 0.6933 - accuracy: 0.5056 - auc: 0.4988 - val_loss: 0.6932 - val_accuracy: 0.5057 - val_auc: 0.5003
# Epoch 43/50
# 492/492 [==============================] - 8s 15ms/step - loss: 0.6937 - accuracy: 0.5078 - auc: 0.5021 - val_loss: 0.6946 - val_accuracy: 0.5056 - val_auc: 0.4997
# Epoch 44/50
# 492/492 [==============================] - 8s 15ms/step - loss: 0.6939 - accuracy: 0.5064 - auc: 0.4997 - val_loss: 0.6931 - val_accuracy: 0.5057 - val_auc: 0.5002
# Epoch 45/50
# 492/492 [==============================] - 8s 15ms/step - loss: 0.6936 - accuracy: 0.5066 - auc: 0.4993 - val_loss: 0.6937 - val_accuracy: 0.5058 - val_auc: 0.5001
# Epoch 46/50
# 492/492 [==============================] - 8s 15ms/step - loss: 0.6935 - accuracy: 0.5075 - auc: 0.4982 - val_loss: 0.6937 - val_accuracy: 0.5057 - val_auc: 0.4999
# Epoch 47/50
# 492/492 [==============================] - 7s 15ms/step - loss: 0.6932 - accuracy: 0.5081 - auc: 0.5022 - val_loss: 0.6948 - val_accuracy: 0.5057 - val_auc: 0.4999
# Epoch 48/50
# 492/492 [==============================] - 7s 15ms/step - loss: 0.6934 - accuracy: 0.5087 - auc: 0.5021 - val_loss: 0.6934 - val_accuracy: 0.4943 - val_auc: 0.5000
# Epoch 49/50
# 492/492 [==============================] - 7s 15ms/step - loss: 0.6937 - accuracy: 0.5042 - auc: 0.4998 - val_loss: 0.6933 - val_accuracy: 0.5057 - val_auc: 0.5000
# Epoch 50/50
# 492/492 [==============================] - 8s 15ms/step - loss: 0.6935 - accuracy: 0.5056 - auc: 0.4983 - val_loss: 0.6935 - val_accuracy: 0.5057 - val_auc: 0.5000
# History saved
# History loaded
# training model fold 10
# Epoch 1/50
# 492/492 [==============================] - 10s 16ms/step - loss: 1.0019 - accuracy: 0.5012 - auc: 0.5006 - val_loss: 0.7698 - val_accuracy: 0.5098 - val_auc: 0.5116
# Epoch 2/50
# 492/492 [==============================] - 8s 16ms/step - loss: 0.7015 - accuracy: 0.5022 - auc: 0.5029 - val_loss: 0.7465 - val_accuracy: 0.5066 - val_auc: 0.5128
# Epoch 3/50
# 492/492 [==============================] - 8s 16ms/step - loss: 0.7022 - accuracy: 0.5040 - auc: 0.5021 - val_loss: 0.7770 - val_accuracy: 0.5110 - val_auc: 0.5180
# Epoch 4/50
# 492/492 [==============================] - 8s 15ms/step - loss: 0.7034 - accuracy: 0.5085 - auc: 0.5091 - val_loss: 0.6922 - val_accuracy: 0.5232 - val_auc: 0.5213
# Epoch 5/50
# 492/492 [==============================] - 8s 15ms/step - loss: 0.6937 - accuracy: 0.5135 - auc: 0.5173 - val_loss: 0.6916 - val_accuracy: 0.5220 - val_auc: 0.5313
# Epoch 6/50
# 492/492 [==============================] - 8s 15ms/step - loss: 0.6916 - accuracy: 0.5259 - auc: 0.5328 - val_loss: 0.6907 - val_accuracy: 0.5271 - val_auc: 0.5380
# Epoch 7/50
# 492/492 [==============================] - 8s 15ms/step - loss: 0.6912 - accuracy: 0.5268 - auc: 0.5354 - val_loss: 0.6920 - val_accuracy: 0.5202 - val_auc: 0.5297
# Epoch 8/50
# 492/492 [==============================] - 8s 16ms/step - loss: 0.6910 - accuracy: 0.5280 - auc: 0.5382 - val_loss: 0.6907 - val_accuracy: 0.5311 - val_auc: 0.5399
# Epoch 9/50
# 492/492 [==============================] - 8s 15ms/step - loss: 0.6914 - accuracy: 0.5260 - auc: 0.5332 - val_loss: 0.6916 - val_accuracy: 0.5201 - val_auc: 0.5299
# Epoch 10/50
# 492/492 [==============================] - 8s 15ms/step - loss: 0.6918 - accuracy: 0.5224 - auc: 0.5322 - val_loss: 0.6921 - val_accuracy: 0.5139 - val_auc: 0.5325
# Epoch 11/50
# 492/492 [==============================] - 8s 16ms/step - loss: 0.6922 - accuracy: 0.5198 - auc: 0.5242 - val_loss: 0.6913 - val_accuracy: 0.5290 - val_auc: 0.5318
# Epoch 12/50
# 492/492 [==============================] - 8s 15ms/step - loss: 0.6923 - accuracy: 0.5197 - auc: 0.5218 - val_loss: 0.6944 - val_accuracy: 0.4994 - val_auc: 0.5227
# Epoch 13/50
# 492/492 [==============================] - 8s 16ms/step - loss: 0.6928 - accuracy: 0.5173 - auc: 0.5197 - val_loss: 0.6939 - val_accuracy: 0.5200 - val_auc: 0.5197
# Epoch 14/50
# 492/492 [==============================] - 8s 15ms/step - loss: 0.6927 - accuracy: 0.5135 - auc: 0.5147 - val_loss: 0.6942 - val_accuracy: 0.5139 - val_auc: 0.5223
# Epoch 15/50
# 492/492 [==============================] - 8s 15ms/step - loss: 0.6931 - accuracy: 0.5117 - auc: 0.5122 - val_loss: 0.6943 - val_accuracy: 0.5098 - val_auc: 0.5235
# Epoch 16/50
# 492/492 [==============================] - 8s 15ms/step - loss: 0.6928 - accuracy: 0.5137 - auc: 0.5158 - val_loss: 0.6930 - val_accuracy: 0.5157 - val_auc: 0.5050
# Epoch 17/50
# 492/492 [==============================] - 8s 15ms/step - loss: 0.6932 - accuracy: 0.5096 - auc: 0.5034 - val_loss: 0.6928 - val_accuracy: 0.5139 - val_auc: 0.5032
# Epoch 18/50
# 492/492 [==============================] - 8s 15ms/step - loss: 0.6933 - accuracy: 0.5063 - auc: 0.4989 - val_loss: 0.6942 - val_accuracy: 0.5139 - val_auc: 0.5028
# Epoch 19/50
# 492/492 [==============================] - 8s 15ms/step - loss: 0.6932 - accuracy: 0.5074 - auc: 0.4986 - val_loss: 0.6928 - val_accuracy: 0.5103 - val_auc: 0.5066
# Epoch 20/50
# 492/492 [==============================] - 7s 15ms/step - loss: 0.6934 - accuracy: 0.5054 - auc: 0.5000 - val_loss: 0.6928 - val_accuracy: 0.5139 - val_auc: 0.5038
# Epoch 21/50
# 492/492 [==============================] - 8s 15ms/step - loss: 0.6933 - accuracy: 0.5080 - auc: 0.5031 - val_loss: 0.7147 - val_accuracy: 0.5139 - val_auc: 0.5024
# Epoch 22/50
# 492/492 [==============================] - 8s 15ms/step - loss: 0.6939 - accuracy: 0.5043 - auc: 0.5018 - val_loss: 0.6928 - val_accuracy: 0.5139 - val_auc: 0.5001
# Epoch 23/50
# 492/492 [==============================] - 8s 15ms/step - loss: 0.6931 - accuracy: 0.5069 - auc: 0.5022 - val_loss: 0.9446 - val_accuracy: 0.5139 - val_auc: 0.5042
# Epoch 24/50
# 492/492 [==============================] - 8s 15ms/step - loss: 0.6934 - accuracy: 0.5082 - auc: 0.5032 - val_loss: 0.6928 - val_accuracy: 0.5139 - val_auc: 0.5000
# Epoch 25/50
# 492/492 [==============================] - 8s 15ms/step - loss: 0.6932 - accuracy: 0.5085 - auc: 0.4988 - val_loss: 0.6929 - val_accuracy: 0.5140 - val_auc: 0.5001
# Epoch 26/50
# 492/492 [==============================] - 8s 15ms/step - loss: 0.6932 - accuracy: 0.5052 - auc: 0.4992 - val_loss: 0.6930 - val_accuracy: 0.5139 - val_auc: 0.5001
# Epoch 27/50
# 492/492 [==============================] - 8s 15ms/step - loss: 0.6936 - accuracy: 0.5052 - auc: 0.5005 - val_loss: 0.6943 - val_accuracy: 0.5139 - val_auc: 0.5000
# Epoch 28/50
# 492/492 [==============================] - 8s 15ms/step - loss: 0.6936 - accuracy: 0.5047 - auc: 0.4979 - val_loss: 0.6928 - val_accuracy: 0.5139 - val_auc: 0.5000
# Epoch 29/50
# 492/492 [==============================] - 8s 15ms/step - loss: 0.6933 - accuracy: 0.5057 - auc: 0.5003 - val_loss: 0.6936 - val_accuracy: 0.4861 - val_auc: 0.5000
# Epoch 30/50
# 492/492 [==============================] - 8s 15ms/step - loss: 0.6937 - accuracy: 0.5027 - auc: 0.4980 - val_loss: 0.6937 - val_accuracy: 0.5139 - val_auc: 0.5000
# Epoch 31/50
# 492/492 [==============================] - 8s 16ms/step - loss: 0.6936 - accuracy: 0.5050 - auc: 0.4984 - val_loss: 0.6930 - val_accuracy: 0.5139 - val_auc: 0.5001
# Epoch 32/50
# 492/492 [==============================] - 8s 15ms/step - loss: 0.6936 - accuracy: 0.5039 - auc: 0.4988 - val_loss: 0.6954 - val_accuracy: 0.4861 - val_auc: 0.5000
# Epoch 33/50
# 492/492 [==============================] - 8s 15ms/step - loss: 0.6934 - accuracy: 0.5062 - auc: 0.5005 - val_loss: 0.6950 - val_accuracy: 0.4861 - val_auc: 0.5001
# Epoch 34/50
# 492/492 [==============================] - 7s 15ms/step - loss: 0.6935 - accuracy: 0.5056 - auc: 0.4962 - val_loss: 0.6931 - val_accuracy: 0.5139 - val_auc: 0.5000
# Epoch 35/50
# 492/492 [==============================] - 8s 15ms/step - loss: 0.6936 - accuracy: 0.5066 - auc: 0.4983 - val_loss: 0.6937 - val_accuracy: 0.5139 - val_auc: 0.5000
# Epoch 36/50
# 492/492 [==============================] - 7s 15ms/step - loss: 0.6936 - accuracy: 0.5050 - auc: 0.5005 - val_loss: 0.6935 - val_accuracy: 0.4861 - val_auc: 0.5000
# Epoch 37/50
# 492/492 [==============================] - 7s 15ms/step - loss: 0.6934 - accuracy: 0.5051 - auc: 0.5014 - val_loss: 0.6929 - val_accuracy: 0.5139 - val_auc: 0.5000
# Epoch 38/50
# 492/492 [==============================] - 8s 15ms/step - loss: 0.6935 - accuracy: 0.5061 - auc: 0.5013 - val_loss: 0.6928 - val_accuracy: 0.5139 - val_auc: 0.5000
# Epoch 39/50
# 492/492 [==============================] - 8s 15ms/step - loss: 0.6932 - accuracy: 0.5059 - auc: 0.5022 - val_loss: 0.6928 - val_accuracy: 0.5139 - val_auc: 0.5000
# Epoch 40/50
# 492/492 [==============================] - 7s 15ms/step - loss: 0.6933 - accuracy: 0.5035 - auc: 0.4977 - val_loss: 0.6985 - val_accuracy: 0.4861 - val_auc: 0.5000
# Epoch 41/50
# 492/492 [==============================] - 8s 15ms/step - loss: 0.6940 - accuracy: 0.5042 - auc: 0.5000 - val_loss: 0.6929 - val_accuracy: 0.5139 - val_auc: 0.5000
# Epoch 42/50
# 492/492 [==============================] - 7s 15ms/step - loss: 0.6934 - accuracy: 0.5055 - auc: 0.5019 - val_loss: 0.6941 - val_accuracy: 0.5139 - val_auc: 0.5000
# Epoch 43/50
# 492/492 [==============================] - 8s 15ms/step - loss: 0.6933 - accuracy: 0.5063 - auc: 0.5021 - val_loss: 0.6928 - val_accuracy: 0.5139 - val_auc: 0.5000
# Epoch 44/50
# 492/492 [==============================] - 7s 15ms/step - loss: 0.6935 - accuracy: 0.5056 - auc: 0.5001 - val_loss: 0.6930 - val_accuracy: 0.5139 - val_auc: 0.5000
# Epoch 45/50
# 492/492 [==============================] - 8s 15ms/step - loss: 0.6935 - accuracy: 0.5045 - auc: 0.4997 - val_loss: 0.6933 - val_accuracy: 0.4861 - val_auc: 0.5000
# Epoch 46/50
# 492/492 [==============================] - 8s 15ms/step - loss: 0.6934 - accuracy: 0.5053 - auc: 0.5019 - val_loss: 0.6944 - val_accuracy: 0.4861 - val_auc: 0.5000
# Epoch 47/50
# 492/492 [==============================] - 8s 15ms/step - loss: 0.6935 - accuracy: 0.5054 - auc: 0.5013 - val_loss: 0.6931 - val_accuracy: 0.5139 - val_auc: 0.4999
# Epoch 48/50
# 492/492 [==============================] - 8s 15ms/step - loss: 0.6935 - accuracy: 0.5044 - auc: 0.4983 - val_loss: 0.6928 - val_accuracy: 0.5139 - val_auc: 0.5000
# Epoch 49/50
# 492/492 [==============================] - 8s 15ms/step - loss: 0.6933 - accuracy: 0.5066 - auc: 0.5013 - val_loss: 0.6928 - val_accuracy: 0.5139 - val_auc: 0.5000
# Epoch 50/50
# 492/492 [==============================] - 8s 15ms/step - loss: 0.6934 - accuracy: 0.5061 - auc: 0.4978 - val_loss: 0.6928 - val_accuracy: 0.5139 - val_auc: 0.5000
# History saved
# History loaded
# cv_scores key: utility, accuracy, logit_roc_auc, true_pos, true_neg, false_pos, false_neg
# cv_scores_ave:  [10.688525096615558, 0.5046235123915489, 0.5001513869064709, 9995.3, 4100.4, 9579.8, 4257.6]
# saved model metrics
#
# model_name:  mlp2_learning_rates_0.0001
# model_params:  batch_size=512, hidden_unit=[200, 400, 800, 400], activation=<function tanh at 0x7fc3beb8e680>, dropout_rate=[0.2, 0.2, 0.2, 0.2], learning_rate=0.0001, epoch=50
# training model fold 1
# Epoch 1/50
# 492/492 [==============================] - 10s 17ms/step - loss: 0.8032 - accuracy: 0.5063 - auc: 0.5077 - val_loss: 0.7029 - val_accuracy: 0.5270 - val_auc: 0.5373
# Epoch 2/50
# 492/492 [==============================] - 8s 15ms/step - loss: 0.7484 - accuracy: 0.5127 - auc: 0.5170 - val_loss: 0.6945 - val_accuracy: 0.5354 - val_auc: 0.5518
# Epoch 3/50
# 492/492 [==============================] - 8s 15ms/step - loss: 0.7332 - accuracy: 0.5173 - auc: 0.5221 - val_loss: 0.6896 - val_accuracy: 0.5455 - val_auc: 0.5651
# Epoch 4/50
# 492/492 [==============================] - 8s 16ms/step - loss: 0.7189 - accuracy: 0.5208 - auc: 0.5301 - val_loss: 0.6855 - val_accuracy: 0.5482 - val_auc: 0.5699
# Epoch 5/50
# 492/492 [==============================] - 8s 16ms/step - loss: 0.7101 - accuracy: 0.5245 - auc: 0.5346 - val_loss: 0.6848 - val_accuracy: 0.5480 - val_auc: 0.5717
# Epoch 6/50
# 492/492 [==============================] - 8s 16ms/step - loss: 0.7038 - accuracy: 0.5265 - auc: 0.5389 - val_loss: 0.6818 - val_accuracy: 0.5572 - val_auc: 0.5815
# Epoch 7/50
# 492/492 [==============================] - 8s 15ms/step - loss: 0.6984 - accuracy: 0.5317 - auc: 0.5456 - val_loss: 0.6805 - val_accuracy: 0.5560 - val_auc: 0.5837
# Epoch 8/50
# 492/492 [==============================] - 8s 16ms/step - loss: 0.6953 - accuracy: 0.5346 - auc: 0.5486 - val_loss: 0.6804 - val_accuracy: 0.5568 - val_auc: 0.5840
# Epoch 9/50
# 492/492 [==============================] - 8s 15ms/step - loss: 0.6910 - accuracy: 0.5412 - auc: 0.5569 - val_loss: 0.6785 - val_accuracy: 0.5595 - val_auc: 0.5897
# Epoch 10/50
# 492/492 [==============================] - 8s 16ms/step - loss: 0.6882 - accuracy: 0.5449 - auc: 0.5638 - val_loss: 0.6780 - val_accuracy: 0.5626 - val_auc: 0.5917
# Epoch 11/50
# 492/492 [==============================] - 8s 15ms/step - loss: 0.6875 - accuracy: 0.5452 - auc: 0.5638 - val_loss: 0.6776 - val_accuracy: 0.5598 - val_auc: 0.5926
# Epoch 12/50
# 492/492 [==============================] - 8s 15ms/step - loss: 0.6855 - accuracy: 0.5483 - auc: 0.5702 - val_loss: 0.6768 - val_accuracy: 0.5639 - val_auc: 0.5955
# Epoch 13/50
# 492/492 [==============================] - 8s 15ms/step - loss: 0.6846 - accuracy: 0.5498 - auc: 0.5730 - val_loss: 0.6762 - val_accuracy: 0.5653 - val_auc: 0.5974
# Epoch 14/50
# 492/492 [==============================] - 8s 16ms/step - loss: 0.6833 - accuracy: 0.5541 - auc: 0.5766 - val_loss: 0.6766 - val_accuracy: 0.5629 - val_auc: 0.5948
# Epoch 15/50
# 492/492 [==============================] - 8s 15ms/step - loss: 0.6816 - accuracy: 0.5572 - auc: 0.5831 - val_loss: 0.6756 - val_accuracy: 0.5640 - val_auc: 0.5981
# Epoch 16/50
# 492/492 [==============================] - 8s 15ms/step - loss: 0.6816 - accuracy: 0.5568 - auc: 0.5826 - val_loss: 0.6738 - val_accuracy: 0.5700 - val_auc: 0.6041
# Epoch 17/50
# 492/492 [==============================] - 8s 15ms/step - loss: 0.6792 - accuracy: 0.5625 - auc: 0.5899 - val_loss: 0.6733 - val_accuracy: 0.5693 - val_auc: 0.6046
# Epoch 18/50
# 492/492 [==============================] - 8s 16ms/step - loss: 0.6792 - accuracy: 0.5640 - auc: 0.5905 - val_loss: 0.6723 - val_accuracy: 0.5732 - val_auc: 0.6074
# Epoch 19/50
# 492/492 [==============================] - 8s 16ms/step - loss: 0.6780 - accuracy: 0.5654 - auc: 0.5936 - val_loss: 0.6701 - val_accuracy: 0.5751 - val_auc: 0.6138
# Epoch 20/50
# 492/492 [==============================] - ETA: 0s - loss: 0.6775 - accuracy: 0.5652 - auc: 0.5946

# %%
# '''
# predict on the test set. load best weights from checkpoints
# '''
# # model.load_weights(str(PATH_CHECKPOINTS / (model_name + '.hdf5')))

# test_metrics = model.evaluate(x_test, steps=3)

# test_metrics_dict = {
#     'test_loss': test_metrics[0]
# }

# np.save(PATH_PREDICTIONS/str(model_name + "_prediction_score"), test_metrics_dict)

# %%
# y_pred = (model.predict(x_test) > 0.5).astype(int)
# utility_score(test, y_pred)

# %% [markdown]
# # Conclusion
